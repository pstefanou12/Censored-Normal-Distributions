# %%
import sys 
sys.path.append('/Users/patroklos/Desktop/delphi_')

import torch as ch
from torch import Tensor
from torch.distributions import Uniform
from torch.distributions.multivariate_normal import MultivariateNormal
from torch.distributions.kl import kl_divergence

import seaborn as sns
import matplotlib.pyplot as plt
import IPython 

from delphi.distributions.normal import CensoredNormal
from delphi import oracle
from delphi.utils import constants as consts
from delphi.utils.helpers import setup_store_with_metadata
from cox.utils import Parameters
from cox.store import Store
from cox.readers import CollectionReader

# %%
args = Parameters({ 
    'samples': 1000, 
    'batch_size': 1, 
    'tol': 1e-1, 
    'lr': 1e-1, 
    'out_dir': '/Users/patroklos/Desktop/exp/censored',
    'exp': 'test', 
    'trials': 20,
    'var': 10,
    'table_name': 'logs',
})

# %% [markdown]
# Synthetic Data Experiment for 1 Dimensional Censored Gaussian Distributions

# %%
M = MultivariateNormal(Tensor([0.0]), 1.0*ch.ones(1, 1))
samples = M.sample([args.samples])

plt.hist(samples.flatten(), bins=100)
plt.show()

# %% [markdown]
# Truncate the Dataset

# %%
phi = oracle.Right_Distribution(Tensor([0.0]))
# phi = oracle.Identity()
indices = phi(samples).nonzero()[:,0]
S = samples[indices]
alpha = S.size(0) / samples.size(0)
print("alpha: {}".format(alpha))

plt.hist(S.flatten(), bins=100)
plt.show()
# Out:
# alpha: 0.488

# %%
emp_loc = S.mean(0)
print("empirical mean: ", emp_loc)
emp_var = S.var(0)[...,None]
emp_scale = ch.sqrt(emp_var)
print("empirical scale: ", emp_scale)

emp = MultivariateNormal(emp_loc, emp_var)

S_norm = (S - emp_loc) / emp_scale
# phi_norm = oracle.Right_Distribution((phi.right - emp_loc) / emp_scale)
# Out:
# empirical mean:  tensor([-0.8065])
# empirical scale:  tensor([[0.6399]])

# %% [markdown]
# Run algorithm to Remove Bias from the Dataset

# %%
censored = CensoredNormal(phi, 
                          alpha, 
                          kwargs={'epochs': 2, 
                          'batch_size': 1, 
                          'num_samples': 10,
                          'step_lr': 500,
                          'lr': 1e-1})
censored.fit(S)
m = MultivariateNormal(censored.loc, censored.variance)
print("estimated mean: ", censored.loc)
print("estimated variance: ", censored.variance)
# Out:
# sigma:  tensor([[0.4187]])
# mu:  tensor([-0.8086])
# z:  tensor([[-1.9950]])
# 1
# sigma:  tensor([[0.3884]])
# mu:  tensor([-0.6919])
# z:  tensor([[-1.0759]])
# 1
# sigma:  tensor([[0.3798]])
# mu:  tensor([-0.6362])
# z:  tensor([[-0.3015]])
# 1
# sigma:  tensor([[0.3793]])
# mu:  tensor([-0.6290])
# z:  tensor([[-1.9527]])
# 1
# sigma:  tensor([[0.3537]])
# mu:  tensor([-0.5187])
# z:  tensor([[-0.6000]])
# 1
# sigma:  tensor([[0.3639]])
# mu:  tensor([-0.5624])
# z:  tensor([[-0.8246]])
# 1
# sigma:  tensor([[0.3639]])
# mu:  tensor([-0.5623])
# z:  tensor([[-0.5849]])
# 1
# sigma:  tensor([[0.3617]])
# mu:  tensor([-0.5409])
# z:  tensor([[-0.4614]])
# 1
# sigma:  tensor([[0.4184]])
# mu:  tensor([-0.7226])
# z:  tensor([[-0.4930]])
# 1
# sigma:  tensor([[0.4168]])
# mu:  tensor([-0.7099])
# z:  tensor([[-1.1948]])
# 1
# sigma:  tensor([[0.4051]])
# mu:  tensor([-0.6490])
# z:  tensor([[-0.3723]])
# 1
# sigma:  tensor([[0.4081]])
# mu:  tensor([-0.6675])
# z:  tensor([[-0.5106]])
# 1
# sigma:  tensor([[0.4119]])
# mu:  tensor([-0.6875])
# z:  tensor([[-1.4801]])
# 1
# sigma:  tensor([[0.3941]])
# mu:  tensor([-0.6002])
# z:  tensor([[-1.2314]])
# 1
# sigma:  tensor([[0.3827]])
# mu:  tensor([-0.5377])
# z:  tensor([[-1.3669]])
# 1
# sigma:  tensor([[0.3710]])
# mu:  tensor([-0.4882])
# z:  tensor([[-0.8284]])
# 1
# sigma:  tensor([[0.3708]])
# mu:  tensor([-0.4873])
# z:  tensor([[-1.4440]])
# 1
# sigma:  tensor([[0.3573]])
# mu:  tensor([-0.4259])
# z:  tensor([[-0.9445]])
# 1
# sigma:  tensor([[0.3518]])
# mu:  tensor([-0.3887])
# z:  tensor([[-0.1892]])
# 1
# sigma:  tensor([[0.3673]])
# mu:  tensor([-0.4564])
# z:  tensor([[-0.0145]])
# 1
# sigma:  tensor([[0.3765]])
# mu:  tensor([-0.5107])
# z:  tensor([[-1.1133]])
# 1
# sigma:  tensor([[0.3694]])
# mu:  tensor([-0.4772])
# z:  tensor([[-0.6091]])
# 1
# sigma:  tensor([[0.3671]])
# mu:  tensor([-0.4585])
# z:  tensor([[-1.1646]])
# 1
# sigma:  tensor([[0.3663]])
# mu:  tensor([-0.4553])
# z:  tensor([[-1.1079]])
# 1
# sigma:  tensor([[0.3640]])
# mu:  tensor([-0.4464])
# z:  tensor([[-0.3398]])
# 1
# sigma:  tensor([[0.3634]])
# mu:  tensor([-0.4399])
# z:  tensor([[-0.8485]])
# 1
# sigma:  tensor([[0.3589]])
# mu:  tensor([-0.4094])
# z:  tensor([[-1.4078]])
# 1
# sigma:  tensor([[0.3575]])
# mu:  tensor([-0.4051])
# z:  tensor([[-1.3884]])
# 1
# sigma:  tensor([[0.3459]])
# mu:  tensor([-0.3505])
# z:  tensor([[-0.4514]])
# 1
# sigma:  tensor([[0.3512]])
# mu:  tensor([-0.3765])
# z:  tensor([[-1.4524]])
# 1
# sigma:  tensor([[0.3388]])
# mu:  tensor([-0.3197])
# z:  tensor([[-0.8072]])
# 1
# sigma:  tensor([[0.3723]])
# mu:  tensor([-0.4123])
# z:  tensor([[-0.4671]])
# 1
# sigma:  tensor([[0.3723]])
# mu:  tensor([-0.4121])
# z:  tensor([[-1.3337]])
# 1
# sigma:  tensor([[0.3606]])
# mu:  tensor([-0.3574])
# z:  tensor([[-0.7867]])
# 1
# sigma:  tensor([[0.3624]])
# mu:  tensor([-0.3649])
# z:  tensor([[-0.2690]])
# 1
# sigma:  tensor([[0.3712]])
# mu:  tensor([-0.4075])
# z:  tensor([[-0.0199]])
# 1
# sigma:  tensor([[0.3910]])
# mu:  tensor([-0.4932])
# z:  tensor([[-0.6473]])
# 1
# sigma:  tensor([[0.3880]])
# mu:  tensor([-0.4693])
# z:  tensor([[-0.8214]])
# 1
# sigma:  tensor([[0.3868]])
# mu:  tensor([-0.4638])
# z:  tensor([[-0.8568]])
# 1
# sigma:  tensor([[0.3816]])
# mu:  tensor([-0.4315])
# z:  tensor([[-0.4271]])
# 1
# sigma:  tensor([[0.3819]])
# mu:  tensor([-0.4341])
# z:  tensor([[-1.0994]])
# 1
# sigma:  tensor([[0.4003]])
# mu:  tensor([-0.4869])
# z:  tensor([[-1.4635]])
# 1
# sigma:  tensor([[0.3882]])
# mu:  tensor([-0.4450])
# z:  tensor([[-0.8114]])
# 1
# sigma:  tensor([[0.3981]])
# mu:  tensor([-0.4796])
# z:  tensor([[-0.0103]])
# 1
# sigma:  tensor([[0.4239]])
# mu:  tensor([-0.5843])
# z:  tensor([[-1.2493]])
# 1
# sigma:  tensor([[0.4521]])
# mu:  tensor([-0.6628])
# z:  tensor([[-0.5031]])
# 1
# sigma:  tensor([[0.4582]])
# mu:  tensor([-0.6907])
# z:  tensor([[-0.4519]])
# 1
# sigma:  tensor([[0.4579]])
# mu:  tensor([-0.6883])
# z:  tensor([[-0.2795]])
# 1
# sigma:  tensor([[0.4577]])
# mu:  tensor([-0.6870])
# z:  tensor([[-0.6492]])
# 1
# sigma:  tensor([[0.4620]])
# mu:  tensor([-0.7053])
# z:  tensor([[-1.7850]])
# 1
# sigma:  tensor([[0.4354]])
# mu:  tensor([-0.6191])
# z:  tensor([[-1.0866]])
# 1
# sigma:  tensor([[0.4359]])
# mu:  tensor([-0.6209])
# z:  tensor([[-0.2532]])
# 1
# sigma:  tensor([[0.4353]])
# mu:  tensor([-0.6110])
# z:  tensor([[-0.1043]])
# 1
# sigma:  tensor([[0.4362]])
# mu:  tensor([-0.6221])
# z:  tensor([[-0.3263]])
# 1
# sigma:  tensor([[0.4496]])
# mu:  tensor([-0.6809])
# z:  tensor([[-0.6095]])
# 1
# sigma:  tensor([[0.4458]])
# mu:  tensor([-0.6486])
# z:  tensor([[-0.3313]])
# 1
# sigma:  tensor([[0.4793]])
# mu:  tensor([-0.7678])
# z:  tensor([[-0.6609]])
# 1
# sigma:  tensor([[0.4761]])
# mu:  tensor([-0.7498])
# z:  tensor([[-0.0738]])
# 1
# sigma:  tensor([[0.4853]])
# mu:  tensor([-0.8042])
# z:  tensor([[-1.8111]])
# 1
# sigma:  tensor([[0.4499]])
# mu:  tensor([-0.6730])
# z:  tensor([[-0.8013]])
# 1
# sigma:  tensor([[0.4547]])
# mu:  tensor([-0.6914])
# z:  tensor([[-2.4509]])
# 1
# sigma:  tensor([[0.4032]])
# mu:  tensor([-0.5394])
# z:  tensor([[-1.0250]])
# 1
# sigma:  tensor([[0.4050]])
# mu:  tensor([-0.5460])
# z:  tensor([[-1.1772]])
# 1
# sigma:  tensor([[0.4014]])
# mu:  tensor([-0.5330])
# z:  tensor([[-0.7140]])
# 1
# sigma:  tensor([[0.4462]])
# mu:  tensor([-0.6654])
# z:  tensor([[-0.9364]])
# 1
# sigma:  tensor([[0.4378]])
# mu:  tensor([-0.6160])
# z:  tensor([[-0.3744]])
# 1
# sigma:  tensor([[0.4459]])
# mu:  tensor([-0.6546])
# z:  tensor([[-0.1222]])
# 1
# sigma:  tensor([[0.4492]])
# mu:  tensor([-0.6808])
# z:  tensor([[-0.9927]])
# 1
# sigma:  tensor([[0.4397]])
# mu:  tensor([-0.6284])
# z:  tensor([[-0.2597]])
# 1
# sigma:  tensor([[0.4471]])
# mu:  tensor([-0.6678])
# z:  tensor([[-1.3539]])
# 1
# sigma:  tensor([[0.4320]])
# mu:  tensor([-0.6093])
# z:  tensor([[-0.2203]])
# 1
# sigma:  tensor([[0.5264]])
# mu:  tensor([-0.8831])
# z:  tensor([[-0.8227]])
# 1
# sigma:  tensor([[0.5597]])
# mu:  tensor([-0.9886])
# z:  tensor([[-2.1681]])
# 1
# sigma:  tensor([[0.4946]])
# mu:  tensor([-0.7677])
# z:  tensor([[-1.2752]])
# 1
# sigma:  tensor([[0.4763]])
# mu:  tensor([-0.6913])
# z:  tensor([[-0.9614]])
# 1
# sigma:  tensor([[0.4717]])
# mu:  tensor([-0.6732])
# z:  tensor([[-0.5377]])
# 1
# sigma:  tensor([[0.4699]])
# mu:  tensor([-0.6618])
# z:  tensor([[-1.0063]])
# 1
# sigma:  tensor([[0.4600]])
# mu:  tensor([-0.6162])
# z:  tensor([[-1.1553]])
# 1
# sigma:  tensor([[0.4566]])
# mu:  tensor([-0.6049])
# z:  tensor([[-0.6433]])
# 1
# sigma:  tensor([[0.4561]])
# mu:  tensor([-0.6024])
# z:  tensor([[-0.2369]])
# 1
# sigma:  tensor([[0.5009]])
# mu:  tensor([-0.7496])
# z:  tensor([[-0.6530]])
# 1
# sigma:  tensor([[0.5167]])
# mu:  tensor([-0.8058])
# z:  tensor([[-2.3389]])
# 1
# sigma:  tensor([[0.4528]])
# mu:  tensor([-0.6035])
# z:  tensor([[-1.6222]])
# 1
# sigma:  tensor([[0.4427]])
# mu:  tensor([-0.5746])
# z:  tensor([[-0.8228]])
# 1
# sigma:  tensor([[0.4417]])
# mu:  tensor([-0.5704])
# z:  tensor([[-1.1650]])
# 1
# sigma:  tensor([[0.4451]])
# mu:  tensor([-0.5810])
# z:  tensor([[-0.1756]])
# 1
# sigma:  tensor([[0.4844]])
# mu:  tensor([-0.7169])
# z:  tensor([[-1.7259]])
# 1
# sigma:  tensor([[0.4568]])
# mu:  tensor([-0.6286])
# z:  tensor([[-0.5776]])
# 1
# sigma:  tensor([[0.4564]])
# mu:  tensor([-0.6267])
# z:  tensor([[-1.8872]])
# 1
# sigma:  tensor([[0.4236]])
# mu:  tensor([-0.5193])
# z:  tensor([[-0.6426]])
# 1
# sigma:  tensor([[0.4205]])
# mu:  tensor([-0.4990])
# z:  tensor([[-0.6997]])
# 1
# sigma:  tensor([[0.4182]])
# mu:  tensor([-0.4868])
# z:  tensor([[-0.3226]])
# 1
# sigma:  tensor([[0.4174]])
# mu:  tensor([-0.4770])
# z:  tensor([[-0.2194]])
# 1
# sigma:  tensor([[0.4198]])
# mu:  tensor([-0.4947])
# z:  tensor([[-0.3044]])
# 1
# sigma:  tensor([[0.4259]])
# mu:  tensor([-0.5264])
# z:  tensor([[-1.0222]])
# 1
# sigma:  tensor([[0.4170]])
# mu:  tensor([-0.4815])
# z:  tensor([[-1.4426]])
# 1
# sigma:  tensor([[0.4002]])
# mu:  tensor([-0.4144])
# z:  tensor([[-0.1166]])
# 1
# sigma:  tensor([[0.4026]])
# mu:  tensor([-0.4347])
# z:  tensor([[-0.2321]])
# 1
# sigma:  tensor([[0.4036]])
# mu:  tensor([-0.4434])
# z:  tensor([[-0.6584]])
# 1
# sigma:  tensor([[0.4025]])
# mu:  tensor([-0.4375])
# z:  tensor([[-0.5224]])
# 1
# sigma:  tensor([[0.4097]])
# mu:  tensor([-0.4679])
# z:  tensor([[-0.6646]])
# 1
# sigma:  tensor([[0.4125]])
# mu:  tensor([-0.4800])
# z:  tensor([[-0.1353]])
# 1
# sigma:  tensor([[0.4220]])
# mu:  tensor([-0.5297])
# z:  tensor([[-0.5373]])
# 1
# sigma:  tensor([[0.4717]])
# mu:  tensor([-0.6751])
# z:  tensor([[-0.6928]])
# 1
# sigma:  tensor([[0.4764]])
# mu:  tensor([-0.6938])
# z:  tensor([[-0.9267]])
# 1
# sigma:  tensor([[0.4759]])
# mu:  tensor([-0.6920])
# z:  tensor([[-0.5883]])
# 1
# sigma:  tensor([[0.4745]])
# mu:  tensor([-0.6849])
# z:  tensor([[-0.7874]])
# 1
# sigma:  tensor([[0.4735]])
# mu:  tensor([-0.6806])
# z:  tensor([[-0.7044]])
# 1
# sigma:  tensor([[0.4715]])
# mu:  tensor([-0.6708])
# z:  tensor([[-0.4350]])
# 1
# sigma:  tensor([[0.4704]])
# mu:  tensor([-0.6634])
# z:  tensor([[-1.9737]])
# 1
# sigma:  tensor([[0.4702]])
# mu:  tensor([-0.6627])
# z:  tensor([[-1.0212]])
# 1
# sigma:  tensor([[0.4589]])
# mu:  tensor([-0.6014])
# z:  tensor([[-0.3007]])
# 1
# sigma:  tensor([[0.4604]])
# mu:  tensor([-0.6116])
# z:  tensor([[-1.4287]])
# 1
# sigma:  tensor([[0.4436]])
# mu:  tensor([-0.5540])
# z:  tensor([[-0.3877]])
# 1
# sigma:  tensor([[0.4723]])
# mu:  tensor([-0.6517])
# z:  tensor([[-1.3181]])
# 1
# sigma:  tensor([[0.5441]])
# mu:  tensor([-0.8264])
# z:  tensor([[-1.1198]])
# 1
# sigma:  tensor([[0.5264]])
# mu:  tensor([-0.7469])
# z:  tensor([[-1.1809]])
# 1
# sigma:  tensor([[0.5411]])
# mu:  tensor([-0.7882])
# z:  tensor([[-1.1480]])
# 1
# sigma:  tensor([[0.5245]])
# mu:  tensor([-0.7239])
# z:  tensor([[-0.6759]])
# 1
# sigma:  tensor([[0.5337]])
# mu:  tensor([-0.7570])
# z:  tensor([[-0.5316]])
# 1
# sigma:  tensor([[0.5352]])
# mu:  tensor([-0.7636])
# z:  tensor([[-0.0827]])
# 1
# sigma:  tensor([[0.5358]])
# mu:  tensor([-0.7725])
# z:  tensor([[-0.3179]])
# 1
# sigma:  tensor([[0.5347]])
# mu:  tensor([-0.7616])
# z:  tensor([[-0.8015]])
# 1
# sigma:  tensor([[0.5259]])
# mu:  tensor([-0.7138])
# z:  tensor([[-1.0575]])
# 1
# sigma:  tensor([[0.5203]])
# mu:  tensor([-0.6950])
# z:  tensor([[-0.5751]])
# 1
# sigma:  tensor([[0.5189]])
# mu:  tensor([-0.6881])
# z:  tensor([[-0.3918]])
# 1
# sigma:  tensor([[0.5220]])
# mu:  tensor([-0.7042])
# z:  tensor([[-0.0037]])
# 1
# sigma:  tensor([[0.5530]])
# mu:  tensor([-0.8268])
# z:  tensor([[-0.1679]])
# 1
# sigma:  tensor([[0.5816]])
# mu:  tensor([-0.9378])
# z:  tensor([[-1.2631]])
# 1
# sigma:  tensor([[0.5890]])
# mu:  tensor([-0.9594])
# z:  tensor([[-1.5400]])
# 1
# sigma:  tensor([[0.6023]])
# mu:  tensor([-0.9947])
# z:  tensor([[-0.5113]])
# 1
# sigma:  tensor([[0.6281]])
# mu:  tensor([-1.0853])
# z:  tensor([[-1.1135]])
# 1
# sigma:  tensor([[0.6066]])
# mu:  tensor([-1.0004])
# z:  tensor([[-0.6487]])
# 1
# sigma:  tensor([[0.6326]])
# mu:  tensor([-1.0866])
# z:  tensor([[-1.1857]])
# 1
# sigma:  tensor([[0.6087]])
# mu:  tensor([-0.9983])
# z:  tensor([[-0.2676]])
# 1
# sigma:  tensor([[0.6325]])
# mu:  tensor([-1.0925])
# z:  tensor([[-1.2673]])
# 1
# sigma:  tensor([[0.7025]])
# mu:  tensor([-1.2778])
# z:  tensor([[-1.9213]])
# 1
# sigma:  tensor([[0.6429]])
# mu:  tensor([-1.1117])
# z:  tensor([[-2.1503]])
# 1
# sigma:  tensor([[0.5598]])
# mu:  tensor([-0.8509])
# z:  tensor([[-2.1497]])
# 1
# sigma:  tensor([[0.4973]])
# mu:  tensor([-0.6673])
# z:  tensor([[-0.1958]])
# 1
# sigma:  tensor([[0.5079]])
# mu:  tensor([-0.7190])
# z:  tensor([[-1.6522]])
# 1
# sigma:  tensor([[0.4843]])
# mu:  tensor([-0.6492])
# z:  tensor([[-0.3585]])
# 1
# sigma:  tensor([[0.4953]])
# mu:  tensor([-0.6969])
# z:  tensor([[-0.3289]])
# 1
# sigma:  tensor([[0.4991]])
# mu:  tensor([-0.7179])
# z:  tensor([[-1.3725]])
# 1
# sigma:  tensor([[0.4903]])
# mu:  tensor([-0.6910])
# z:  tensor([[-0.8485]])
# 1
# sigma:  tensor([[0.4863]])
# mu:  tensor([-0.6743])
# z:  tensor([[-0.8206]])
# 1
# sigma:  tensor([[0.4829]])
# mu:  tensor([-0.6599])
# z:  tensor([[-1.1742]])
# 1
# sigma:  tensor([[0.4759]])
# mu:  tensor([-0.6363])
# z:  tensor([[-0.5474]])
# 1
# sigma:  tensor([[0.4774]])
# mu:  tensor([-0.6434])
# z:  tensor([[-1.3823]])
# 1
# sigma:  tensor([[0.5047]])
# mu:  tensor([-0.7135])
# z:  tensor([[-0.3539]])
# 1
# sigma:  tensor([[0.5092]])
# mu:  tensor([-0.7370])
# z:  tensor([[-0.3571]])
# 1
# sigma:  tensor([[0.5187]])
# mu:  tensor([-0.7800])
# z:  tensor([[-0.3357]])
# 1
# sigma:  tensor([[0.5707]])
# mu:  tensor([-0.9477])
# z:  tensor([[-0.8316]])
# 1
# sigma:  tensor([[0.5706]])
# mu:  tensor([-0.9472])
# z:  tensor([[-2.3360]])
# 1
# sigma:  tensor([[0.5074]])
# mu:  tensor([-0.7768])
# z:  tensor([[-1.3234]])
# 1
# sigma:  tensor([[0.5097]])
# mu:  tensor([-0.7838])
# z:  tensor([[-1.0211]])
# 1
# sigma:  tensor([[0.5447]])
# mu:  tensor([-0.8847])
# z:  tensor([[-0.5352]])
# 1
# sigma:  tensor([[0.5509]])
# mu:  tensor([-0.9113])
# z:  tensor([[-0.4422]])
# 1
# sigma:  tensor([[0.5625]])
# mu:  tensor([-0.9603])
# z:  tensor([[-0.4773]])
# 1
# sigma:  tensor([[0.5673]])
# mu:  tensor([-0.9830])
# z:  tensor([[-1.2989]])
# 1
# sigma:  tensor([[0.5414]])
# mu:  tensor([-0.8686])
# z:  tensor([[-0.4550]])
# 1
# sigma:  tensor([[0.5390]])
# mu:  tensor([-0.8514])
# z:  tensor([[-0.9573]])
# 1
# sigma:  tensor([[0.6038]])
# mu:  tensor([-1.0293])
# z:  tensor([[-3.1331]])
# 1
# sigma:  tensor([[0.4758]])
# mu:  tensor([-0.7076])
# z:  tensor([[-0.1170]])
# 1
# sigma:  tensor([[0.4757]])
# mu:  tensor([-0.7034])
# z:  tensor([[-0.3808]])
# 1
# sigma:  tensor([[0.5139]])
# mu:  tensor([-0.8334])
# z:  tensor([[-0.2499]])
# 1
# sigma:  tensor([[0.5589]])
# mu:  tensor([-0.9921])
# z:  tensor([[-0.6399]])
# 1
# sigma:  tensor([[0.6005]])
# mu:  tensor([-1.1297])
# z:  tensor([[-0.4924]])
# 1
# sigma:  tensor([[0.5988]])
# mu:  tensor([-1.1202])
# z:  tensor([[-0.4372]])
# 1
# sigma:  tensor([[0.7286]])
# mu:  tensor([-1.5116])
# z:  tensor([[-1.5962]])
# 1
# sigma:  tensor([[0.6719]])
# mu:  tensor([-1.3188])
# z:  tensor([[-1.2105]])
# 1
# sigma:  tensor([[0.6421]])
# mu:  tensor([-1.2013])
# z:  tensor([[-0.2707]])
# 1
# sigma:  tensor([[0.6846]])
# mu:  tensor([-1.3592])
# z:  tensor([[-2.3268]])
# 1
# sigma:  tensor([[0.6017]])
# mu:  tensor([-1.1256])
# z:  tensor([[-0.9681]])
# 1
# sigma:  tensor([[0.5854]])
# mu:  tensor([-1.0453])
# z:  tensor([[-0.0675]])
# 1
# sigma:  tensor([[0.6363]])
# mu:  tensor([-1.2371])
# z:  tensor([[-1.7088]])
# 1
# sigma:  tensor([[0.5972]])
# mu:  tensor([-1.1144])
# z:  tensor([[-0.6645]])
# 1
# sigma:  tensor([[0.5933]])
# mu:  tensor([-1.0958])
# z:  tensor([[-1.0212]])
# 1
# sigma:  tensor([[0.5984]])
# mu:  tensor([-1.1132])
# z:  tensor([[-1.2721]])
# 1
# sigma:  tensor([[0.5722]])
# mu:  tensor([-1.0087])
# z:  tensor([[-0.9410]])
# 1
# sigma:  tensor([[0.5698]])
# mu:  tensor([-0.9997])
# z:  tensor([[-2.4294]])
# 1
# sigma:  tensor([[0.4879]])
# mu:  tensor([-0.7426])
# z:  tensor([[-1.5803]])
# 1
# sigma:  tensor([[0.4601]])
# mu:  tensor([-0.6347])
# z:  tensor([[-1.0122]])
# 1
# sigma:  tensor([[0.4527]])
# mu:  tensor([-0.6036])
# z:  tensor([[-0.5093]])
# 1
# sigma:  tensor([[0.4523]])
# mu:  tensor([-0.6014])
# z:  tensor([[-0.9677]])
# 1
# sigma:  tensor([[0.4691]])
# mu:  tensor([-0.6528])
# z:  tensor([[-1.0809]])
# 1
# sigma:  tensor([[0.4615]])
# mu:  tensor([-0.6238])
# z:  tensor([[-0.8761]])
# 1
# sigma:  tensor([[0.4806]])
# mu:  tensor([-0.6834])
# z:  tensor([[-1.5992]])
# 1
# sigma:  tensor([[0.4910]])
# mu:  tensor([-0.7107])
# z:  tensor([[-0.2541]])
# 1
# sigma:  tensor([[0.5156]])
# mu:  tensor([-0.8063])
# z:  tensor([[-0.4665]])
# 1
# sigma:  tensor([[0.5128]])
# mu:  tensor([-0.7816])
# z:  tensor([[-0.4980]])
# 1
# sigma:  tensor([[0.5112]])
# mu:  tensor([-0.7722])
# z:  tensor([[-0.7972]])
# 1
# sigma:  tensor([[0.5031]])
# mu:  tensor([-0.7234])
# z:  tensor([[-1.1166]])
# 1
# sigma:  tensor([[0.4953]])
# mu:  tensor([-0.6957])
# z:  tensor([[-0.3903]])
# 1
# sigma:  tensor([[0.4993]])
# mu:  tensor([-0.7165])
# z:  tensor([[-0.2977]])
# 1
# sigma:  tensor([[0.5147]])
# mu:  tensor([-0.7817])
# z:  tensor([[-0.1568]])
# 1
# sigma:  tensor([[0.5157]])
# mu:  tensor([-0.7913])
# z:  tensor([[-1.0962]])
# 1
# sigma:  tensor([[0.5318]])
# mu:  tensor([-0.8396])
# z:  tensor([[-1.0032]])
# 1
# sigma:  tensor([[0.5326]])
# mu:  tensor([-0.8423])
# z:  tensor([[-0.5559]])
# 1
# sigma:  tensor([[0.5355]])
# mu:  tensor([-0.8554])
# z:  tensor([[-0.1108]])
# 1
# sigma:  tensor([[0.5704]])
# mu:  tensor([-0.9913])
# z:  tensor([[-1.3925]])
# 1
# sigma:  tensor([[0.5405]])
# mu:  tensor([-0.8655])
# z:  tensor([[-1.1409]])
# 1
# sigma:  tensor([[0.5271]])
# mu:  tensor([-0.8157])
# z:  tensor([[-1.5275]])
# 1
# sigma:  tensor([[0.4972]])
# mu:  tensor([-0.7045])
# z:  tensor([[-0.5222]])
# 1
# sigma:  tensor([[0.5076]])
# mu:  tensor([-0.7457])
# z:  tensor([[-0.1336]])
# 1
# sigma:  tensor([[0.5089]])
# mu:  tensor([-0.7587])
# z:  tensor([[-1.3720]])
# 1
# sigma:  tensor([[0.4929]])
# mu:  tensor([-0.7055])
# z:  tensor([[-0.0832]])
# 1
# sigma:  tensor([[0.4935]])
# mu:  tensor([-0.7145])
# z:  tensor([[-0.2914]])
# 1
# sigma:  tensor([[0.5045]])
# mu:  tensor([-0.7654])
# z:  tensor([[-1.1639]])
# 1
# sigma:  tensor([[0.4879]])
# mu:  tensor([-0.6834])
# z:  tensor([[-0.1139]])
# 1
# sigma:  tensor([[0.4903]])
# mu:  tensor([-0.7039])
# z:  tensor([[-0.8889]])
# 1
# sigma:  tensor([[0.4840]])
# mu:  tensor([-0.6763])
# z:  tensor([[-0.1461]])
# 1
# sigma:  tensor([[0.5975]])
# mu:  tensor([-0.9940])
# z:  tensor([[-1.3297]])
# 1
# sigma:  tensor([[0.5703]])
# mu:  tensor([-0.8964])
# z:  tensor([[-0.0584]])
# 1
# sigma:  tensor([[0.5950]])
# mu:  tensor([-1.0036])
# z:  tensor([[-0.8566]])
# 1
# sigma:  tensor([[0.5921]])
# mu:  tensor([-0.9928])
# z:  tensor([[-1.4080]])
# 1
# sigma:  tensor([[0.5709]])
# mu:  tensor([-0.9256])
# z:  tensor([[-0.7171]])
# 1
# sigma:  tensor([[0.5627]])
# mu:  tensor([-0.8752])
# z:  tensor([[-1.1854]])
# 1
# sigma:  tensor([[0.5536]])
# mu:  tensor([-0.8456])
# z:  tensor([[-0.3382]])
# 1
# sigma:  tensor([[0.5556]])
# mu:  tensor([-0.8574])
# z:  tensor([[-0.2258]])
# 1
# sigma:  tensor([[0.5555]])
# mu:  tensor([-0.8559])
# z:  tensor([[-2.6215]])
# 1
# sigma:  tensor([[0.4736]])
# mu:  tensor([-0.6436])
# z:  tensor([[-1.3927]])
# 1
# sigma:  tensor([[0.4770]])
# mu:  tensor([-0.6533])
# z:  tensor([[-1.2050]])
# 1
# sigma:  tensor([[0.4614]])
# mu:  tensor([-0.5846])
# z:  tensor([[-1.3359]])
# 1
# sigma:  tensor([[0.4854]])
# mu:  tensor([-0.6464])
# z:  tensor([[-1.3679]])
# 1
# sigma:  tensor([[0.4668]])
# mu:  tensor([-0.5803])
# z:  tensor([[-0.4488]])
# 1
# sigma:  tensor([[0.4649]])
# mu:  tensor([-0.5641])
# z:  tensor([[-1.2515]])
# 1
# sigma:  tensor([[0.5701]])
# mu:  tensor([-0.7961])
# z:  tensor([[-1.2383]])
# 1
# sigma:  tensor([[0.5741]])
# mu:  tensor([-0.8072])
# z:  tensor([[-1.3875]])
# 1
# sigma:  tensor([[0.5458]])
# mu:  tensor([-0.7106])
# z:  tensor([[-0.5808]])
# 1
# sigma:  tensor([[0.5434]])
# mu:  tensor([-0.6987])
# z:  tensor([[-0.7601]])
# 1
# sigma:  tensor([[0.5360]])
# mu:  tensor([-0.6625])
# z:  tensor([[-0.8095]])
# 1
# sigma:  tensor([[0.5811]])
# mu:  tensor([-0.7807])
# z:  tensor([[-0.6281]])
# 1
# sigma:  tensor([[0.5745]])
# mu:  tensor([-0.7366])
# z:  tensor([[-2.0832]])
# 1
# sigma:  tensor([[0.5934]])
# mu:  tensor([-0.7757])
# z:  tensor([[-1.2424]])
# 1
# sigma:  tensor([[0.5927]])
# mu:  tensor([-0.7740])
# z:  tensor([[-0.5082]])
# 1
# sigma:  tensor([[0.5908]])
# mu:  tensor([-0.7641])
# z:  tensor([[-0.6227]])
# 1
# sigma:  tensor([[0.5841]])
# mu:  tensor([-0.7208])
# z:  tensor([[-1.2257]])
# 1
# sigma:  tensor([[0.6071]])
# mu:  tensor([-0.7764])
# z:  tensor([[-0.6225]])
# 1
# sigma:  tensor([[0.6296]])
# mu:  tensor([-0.8447])
# z:  tensor([[-0.8662]])
# 1
# sigma:  tensor([[0.6151]])
# mu:  tensor([-0.7754])
# z:  tensor([[-0.2138]])
# 1
# sigma:  tensor([[0.6326]])
# mu:  tensor([-0.8455])
# z:  tensor([[-0.4519]])
# 1
# sigma:  tensor([[0.6322]])
# mu:  tensor([-0.8433])
# z:  tensor([[-1.7796]])
# 1
# sigma:  tensor([[0.5956]])
# mu:  tensor([-0.7544])
# z:  tensor([[-2.3885]])
# 1
# sigma:  tensor([[0.5167]])
# mu:  tensor([-0.5703])
# z:  tensor([[-1.5226]])
# 1
# sigma:  tensor([[0.5024]])
# mu:  tensor([-0.5336])
# z:  tensor([[-0.3372]])
# 1
# sigma:  tensor([[0.5094]])
# mu:  tensor([-0.5653])
# z:  tensor([[-0.2057]])
# 1
# sigma:  tensor([[0.5122]])
# mu:  tensor([-0.5835])
# z:  tensor([[-0.8212]])
# 1
# sigma:  tensor([[0.5038]])
# mu:  tensor([-0.5408])
# z:  tensor([[-0.2094]])
# 1
# sigma:  tensor([[0.5139]])
# mu:  tensor([-0.5873])
# z:  tensor([[-0.3688]])
# 1
# sigma:  tensor([[0.5449]])
# mu:  tensor([-0.6863])
# z:  tensor([[-1.1473]])
# 1
# sigma:  tensor([[0.5261]])
# mu:  tensor([-0.6067])
# z:  tensor([[-1.9330]])
# 1
# sigma:  tensor([[0.4901]])
# mu:  tensor([-0.5181])
# z:  tensor([[-1.6134]])
# 1
# sigma:  tensor([[0.4672]])
# mu:  tensor([-0.4545])
# z:  tensor([[-0.1364]])
# 1
# sigma:  tensor([[0.4681]])
# mu:  tensor([-0.4643])
# z:  tensor([[-0.4826]])
# 1
# sigma:  tensor([[0.4848]])
# mu:  tensor([-0.5207])
# z:  tensor([[-0.8658]])
# 1
# sigma:  tensor([[0.4827]])
# mu:  tensor([-0.5130])
# z:  tensor([[-0.8524]])
# 1
# sigma:  tensor([[0.4758]])
# mu:  tensor([-0.4823])
# z:  tensor([[-1.0162]])
# 1
# sigma:  tensor([[0.4649]])
# mu:  tensor([-0.4335])
# z:  tensor([[-0.5277]])
# 1
# sigma:  tensor([[0.4621]])
# mu:  tensor([-0.4129])
# z:  tensor([[-1.4676]])
# 1
# sigma:  tensor([[0.4554]])
# mu:  tensor([-0.3963])
# z:  tensor([[-0.5456]])
# 1
# sigma:  tensor([[0.4544]])
# mu:  tensor([-0.3909])
# z:  tensor([[-1.4089]])
# 1
# sigma:  tensor([[0.4527]])
# mu:  tensor([-0.3868])
# z:  tensor([[-0.6865]])
# 1
# sigma:  tensor([[0.4673]])
# mu:  tensor([-0.4308])
# z:  tensor([[-0.9868]])
# 1
# sigma:  tensor([[0.4572]])
# mu:  tensor([-0.3831])
# z:  tensor([[-0.5635]])
# 1
# sigma:  tensor([[0.4664]])
# mu:  tensor([-0.4153])
# z:  tensor([[-1.0143]])
# 1
# sigma:  tensor([[0.4566]])
# mu:  tensor([-0.3754])
# z:  tensor([[-0.2788]])
# 1
# sigma:  tensor([[0.4791]])
# mu:  tensor([-0.4505])
# z:  tensor([[-0.3867]])
# 1
# sigma:  tensor([[0.4775]])
# mu:  tensor([-0.4356])
# z:  tensor([[-0.8304]])
# 1
# sigma:  tensor([[0.4741]])
# mu:  tensor([-0.4224])
# z:  tensor([[-0.5252]])
# 1
# sigma:  tensor([[0.4713]])
# mu:  tensor([-0.4031])
# z:  tensor([[-0.2345]])
# 1
# sigma:  tensor([[0.4714]])
# mu:  tensor([-0.4043])
# z:  tensor([[-0.5849]])
# 1
# sigma:  tensor([[0.4828]])
# mu:  tensor([-0.4418])
# z:  tensor([[-1.1721]])
# 1
# sigma:  tensor([[0.4728]])
# mu:  tensor([-0.4105])
# z:  tensor([[-1.8096]])
# 1
# sigma:  tensor([[0.4402]])
# mu:  tensor([-0.3187])
# z:  tensor([[-0.8313]])
# 1
# sigma:  tensor([[0.4628]])
# mu:  tensor([-0.3756])
# z:  tensor([[-0.3308]])
# 1
# sigma:  tensor([[0.4649]])
# mu:  tensor([-0.3878])
# z:  tensor([[-0.6587]])
# 1
# sigma:  tensor([[0.4627]])
# mu:  tensor([-0.3776])
# z:  tensor([[-0.8855]])
# 1
# sigma:  tensor([[0.4553]])
# mu:  tensor([-0.3437])
# z:  tensor([[-0.1307]])
# 1
# sigma:  tensor([[0.4591]])
# mu:  tensor([-0.3693])
# z:  tensor([[-1.2310]])
# 1
# sigma:  tensor([[0.4499]])
# mu:  tensor([-0.3419])
# z:  tensor([[-0.5514]])
# 1
# sigma:  tensor([[0.4675]])
# mu:  tensor([-0.3951])
# z:  tensor([[-0.5333]])
# 1
# sigma:  tensor([[0.4714]])
# mu:  tensor([-0.4111])
# z:  tensor([[-1.4539]])
# 1
# sigma:  tensor([[0.4671]])
# mu:  tensor([-0.4007])
# z:  tensor([[-1.8583]])
# 1
# sigma:  tensor([[0.4354]])
# mu:  tensor([-0.3178])
# z:  tensor([[-0.7824]])
# 1
# sigma:  tensor([[0.4619]])
# mu:  tensor([-0.3843])
# z:  tensor([[-0.6631]])
# 1
# sigma:  tensor([[0.4620]])
# mu:  tensor([-0.3847])
# z:  tensor([[-0.0747]])
# 1
# sigma:  tensor([[0.4663]])
# mu:  tensor([-0.4146])
# z:  tensor([[-0.2056]])
# 1
# sigma:  tensor([[0.4660]])
# mu:  tensor([-0.4088])
# z:  tensor([[-0.3330]])
# 1
# sigma:  tensor([[0.5003]])
# mu:  tensor([-0.5097])
# z:  tensor([[-1.0500]])
# 1
# sigma:  tensor([[0.4871]])
# mu:  tensor([-0.4513])
# z:  tensor([[-0.7135]])
# 1
# sigma:  tensor([[0.4828]])
# mu:  tensor([-0.4313])
# z:  tensor([[-0.0971]])
# 1
# sigma:  tensor([[0.4867]])
# mu:  tensor([-0.4587])
# z:  tensor([[-0.9619]])
# 1
# sigma:  tensor([[0.4781]])
# mu:  tensor([-0.4252])
# z:  tensor([[-1.3280]])
# 1
# sigma:  tensor([[0.4597]])
# mu:  tensor([-0.3609])
# z:  tensor([[-0.5371]])
# 1
# sigma:  tensor([[0.4568]])
# mu:  tensor([-0.3403])
# z:  tensor([[-0.4604]])
# 1
# sigma:  tensor([[0.4552]])
# mu:  tensor([-0.3287])
# z:  tensor([[-1.0906]])
# 1
# sigma:  tensor([[0.4648]])
# mu:  tensor([-0.3523])
# z:  tensor([[-0.2949]])
# 1
# sigma:  tensor([[0.4640]])
# mu:  tensor([-0.3433])
# z:  tensor([[-0.7538]])
# 1
# sigma:  tensor([[0.4584]])
# mu:  tensor([-0.3145])
# z:  tensor([[-0.7468]])
# 1
# sigma:  tensor([[0.4788]])
# mu:  tensor([-0.3670])
# z:  tensor([[-0.9730]])
# 1
# sigma:  tensor([[0.4691]])
# mu:  tensor([-0.3274])
# z:  tensor([[-0.1847]])
# 1
# sigma:  tensor([[0.4739]])
# mu:  tensor([-0.3543])
# z:  tensor([[-0.2403]])
# 1
# sigma:  tensor([[0.4817]])
# mu:  tensor([-0.3900])
# z:  tensor([[-0.8027]])
# 1
# sigma:  tensor([[0.4753]])
# mu:  tensor([-0.3613])
# z:  tensor([[-0.2213]])
# 1
# sigma:  tensor([[0.4750]])
# mu:  tensor([-0.3565])
# z:  tensor([[-1.4191]])
# 1
# sigma:  tensor([[0.4654]])
# mu:  tensor([-0.3330])
# z:  tensor([[-0.6363]])
# 1
# sigma:  tensor([[0.4638]])
# mu:  tensor([-0.3259])
# z:  tensor([[-1.2856]])
# 1
# sigma:  tensor([[0.4513]])
# mu:  tensor([-0.2897])
# z:  tensor([[-0.5367]])
# 1
# sigma:  tensor([[0.4485]])
# mu:  tensor([-0.2694])
# z:  tensor([[-1.4469]])
# 1
# sigma:  tensor([[0.4319]])
# mu:  tensor([-0.2234])
# z:  tensor([[-0.7484]])
# 1
# sigma:  tensor([[0.4269]])
# mu:  tensor([-0.1940])
# z:  tensor([[-0.3178]])
# 1
# sigma:  tensor([[0.4260]])
# mu:  tensor([-0.1834])
# z:  tensor([[-1.3609]])
# 1
# sigma:  tensor([[0.4221]])
# mu:  tensor([-0.1745])
# z:  tensor([[-1.2457]])
# 1
# sigma:  tensor([[0.4087]])
# mu:  tensor([-0.1209])
# z:  tensor([[-0.8109]])
# 1
# sigma:  tensor([[0.4044]])
# mu:  tensor([-0.1018])
# z:  tensor([[-0.1569]])
# 1
# sigma:  tensor([[0.4044]])
# mu:  tensor([-0.1018])
# z:  tensor([[-0.0761]])
# 1
# sigma:  tensor([[0.4083]])
# mu:  tensor([-0.1277])
# z:  tensor([[-0.2625]])
# 1
# sigma:  tensor([[0.4292]])
# mu:  tensor([-0.1903])
# z:  tensor([[-1.1222]])
# 1
# sigma:  tensor([[0.4183]])
# mu:  tensor([-0.1474])
# z:  tensor([[-1.1999]])
# 1
# sigma:  tensor([[0.4067]])
# mu:  tensor([-0.1057])
# z:  tensor([[-0.1879]])
# 1
# sigma:  tensor([[0.4139]])
# mu:  tensor([-0.1388])
# z:  tensor([[-0.1222]])
# 1
# sigma:  tensor([[0.4154]])
# mu:  tensor([-0.1520])
# z:  tensor([[-0.4762]])
# 1
# sigma:  tensor([[0.4152]])
# mu:  tensor([-0.1511])
# z:  tensor([[-0.3168]])
# 1
# sigma:  tensor([[0.4172]])
# mu:  tensor([-0.1624])
# z:  tensor([[-0.3299]])
# 1
# sigma:  tensor([[0.4240]])
# mu:  tensor([-0.1910])
# z:  tensor([[-0.5755]])
# 1
# sigma:  tensor([[0.4240]])
# mu:  tensor([-0.1907])
# z:  tensor([[-0.9814]])
# 1
# sigma:  tensor([[0.4350]])
# mu:  tensor([-0.2169])
# z:  tensor([[-0.0363]])
# 1
# sigma:  tensor([[0.4869]])
# mu:  tensor([-0.3488])
# z:  tensor([[-1.3631]])
# 1
# sigma:  tensor([[0.4724]])
# mu:  tensor([-0.3106])
# z:  tensor([[-0.9350]])
# 1
# sigma:  tensor([[0.4648]])
# mu:  tensor([-0.2820])
# z:  tensor([[-0.6234]])
# 1
# sigma:  tensor([[0.4699]])
# mu:  tensor([-0.2991])
# z:  tensor([[-0.2783]])
# 1
# sigma:  tensor([[0.4698]])
# mu:  tensor([-0.2987])
# z:  tensor([[-0.8666]])
# 1
# sigma:  tensor([[0.4691]])
# mu:  tensor([-0.2964])
# z:  tensor([[-0.5981]])
# 1
# sigma:  tensor([[0.4829]])
# mu:  tensor([-0.3368])
# z:  tensor([[-0.8848]])
# 1
# sigma:  tensor([[0.4983]])
# mu:  tensor([-0.3752])
# z:  tensor([[-0.0424]])
# 1
# sigma:  tensor([[0.4990]])
# mu:  tensor([-0.3853])
# z:  tensor([[-0.9932]])
# 1
# sigma:  tensor([[0.5028]])
# mu:  tensor([-0.3953])
# z:  tensor([[-0.5593]])
# 1
# sigma:  tensor([[0.5330]])
# mu:  tensor([-0.4747])
# z:  tensor([[-0.5060]])
# 1
# sigma:  tensor([[0.5432]])
# mu:  tensor([-0.5094])
# z:  tensor([[-0.7487]])
# 1
# sigma:  tensor([[0.8244]])
# mu:  tensor([-1.0100])
# z:  tensor([[-1.0359]])
# 1
# sigma:  tensor([[0.8220]])
# mu:  tensor([-1.0042])
# z:  tensor([[-1.1867]])
# 1
# sigma:  tensor([[0.7781]])
# mu:  tensor([-0.8730])
# z:  tensor([[-1.2402]])
# 1
# sigma:  tensor([[0.7401]])
# mu:  tensor([-0.7735])
# z:  tensor([[-1.5989]])
# 1
# sigma:  tensor([[0.6762]])
# mu:  tensor([-0.6001])
# z:  tensor([[-2.0966]])
# 1
# sigma:  tensor([[0.6200]])
# mu:  tensor([-0.5015])
# z:  tensor([[-1.7908]])
# 1
# sigma:  tensor([[0.5669]])
# mu:  tensor([-0.3814])
# z:  tensor([[-1.2149]])
# 1
# sigma:  tensor([[0.8086]])
# mu:  tensor([-0.7261])
# z:  tensor([[-1.3610]])
# 1
# sigma:  tensor([[0.7604]])
# mu:  tensor([-0.6198])
# z:  tensor([[-1.1625]])
# 1
# sigma:  tensor([[0.7401]])
# mu:  tensor([-0.5761])
# z:  tensor([[-0.2234]])
# 1
# sigma:  tensor([[0.7403]])
# mu:  tensor([-0.5773])
# z:  tensor([[-1.7017]])
# 1
# sigma:  tensor([[0.6729]])
# mu:  tensor([-0.4396])
# z:  tensor([[-1.6260]])
# 1
# sigma:  tensor([[0.6197]])
# mu:  tensor([-0.3229])
# z:  tensor([[-0.8808]])
# 1
# sigma:  tensor([[0.6101]])
# mu:  tensor([-0.2957])
# z:  tensor([[-0.3427]])
# 1
# sigma:  tensor([[0.6085]])
# mu:  tensor([-0.2847])
# z:  tensor([[-0.2736]])
# 1
# sigma:  tensor([[0.6220]])
# mu:  tensor([-0.3292])
# z:  tensor([[-0.4618]])
# 1
# sigma:  tensor([[0.6208]])
# mu:  tensor([-0.3244])
# z:  tensor([[-0.5260]])
# 1
# sigma:  tensor([[0.6358]])
# mu:  tensor([-0.3634])
# z:  tensor([[-1.4878]])
# 1
# sigma:  tensor([[0.6208]])
# mu:  tensor([-0.3374])
# z:  tensor([[-0.8261]])
# 1
# sigma:  tensor([[0.6090]])
# mu:  tensor([-0.2952])
# z:  tensor([[-0.1849]])
# 1
# sigma:  tensor([[0.6405]])
# mu:  tensor([-0.3808])
# z:  tensor([[-0.5935]])
# 1
# sigma:  tensor([[0.7285]])
# mu:  tensor([-0.5378])
# z:  tensor([[-1.1282]])
# 1
# sigma:  tensor([[0.7287]])
# mu:  tensor([-0.5382])
# z:  tensor([[-1.7420]])
# 1
# sigma:  tensor([[0.8039]])
# mu:  tensor([-0.6440])
# z:  tensor([[-0.5338]])
# 1
# sigma:  tensor([[0.8043]])
# mu:  tensor([-0.6453])
# z:  tensor([[-0.0550]])
# 1
# sigma:  tensor([[0.8043]])
# mu:  tensor([-0.6459])
# z:  tensor([[-0.3383]])
# 1
# sigma:  tensor([[0.8062]])
# mu:  tensor([-0.6537])
# z:  tensor([[-1.0432]])
# 1
# sigma:  tensor([[0.7787]])
# mu:  tensor([-0.5857])
# z:  tensor([[-0.9121]])
# 1
# sigma:  tensor([[0.8953]])
# mu:  tensor([-0.7749])
# z:  tensor([[-1.0412]])
# 1
# sigma:  tensor([[0.8602]])
# mu:  tensor([-0.6905])
# z:  tensor([[-0.2424]])
# 1
# sigma:  tensor([[1.1332]])
# mu:  tensor([-1.1519])
# z:  tensor([[-2.0063]])
# 1
# sigma:  tensor([[0.9512]])
# mu:  tensor([-0.8527])
# z:  tensor([[-0.8790]])
# 1
# sigma:  tensor([[0.9180]])
# mu:  tensor([-0.7522])
# z:  tensor([[-1.0638]])
# 1
# sigma:  tensor([[0.8827]])
# mu:  tensor([-0.6743])
# z:  tensor([[-0.8576]])
# 1
# sigma:  tensor([[0.9034]])
# mu:  tensor([-0.7139])
# z:  tensor([[-1.4363]])
# 1
# sigma:  tensor([[0.8272]])
# mu:  tensor([-0.5470])
# z:  tensor([[-0.8690]])
# 1
# sigma:  tensor([[0.8022]])
# mu:  tensor([-0.4643])
# z:  tensor([[-0.0564]])
# 1
# sigma:  tensor([[0.8040]])
# mu:  tensor([-0.4806])
# z:  tensor([[-1.7796]])
# 1
# sigma:  tensor([[0.7140]])
# mu:  tensor([-0.3126])
# z:  tensor([[-0.6741]])
# 1
# sigma:  tensor([[0.7198]])
# mu:  tensor([-0.3260])
# z:  tensor([[-0.2401]])
# 1
# sigma:  tensor([[0.7185]])
# mu:  tensor([-0.3139])
# z:  tensor([[-0.8059]])
# 1
# sigma:  tensor([[0.7148]])
# mu:  tensor([-0.3055])
# z:  tensor([[-0.9942]])
# 1
# sigma:  tensor([[0.7219]])
# mu:  tensor([-0.3179])
# z:  tensor([[-1.4756]])
# 1
# sigma:  tensor([[0.6892]])
# mu:  tensor([-0.2657])
# z:  tensor([[-0.1666]])
# 1
# sigma:  tensor([[0.7227]])
# mu:  tensor([-0.3513])
# z:  tensor([[-0.2818]])
# 1
# sigma:  tensor([[0.7349]])
# mu:  tensor([-0.3906])
# z:  tensor([[-1.6583]])
# 1
# sigma:  tensor([[0.6847]])
# mu:  tensor([-0.3098])
# z:  tensor([[-0.4987]])
# 1
# sigma:  tensor([[0.6856]])
# mu:  tensor([-0.3128])
# z:  tensor([[-0.0519]])
# 1
# sigma:  tensor([[0.7012]])
# mu:  tensor([-0.3729])
# z:  tensor([[-0.1862]])
# 1
# sigma:  tensor([[0.7004]])
# mu:  tensor([-0.3606])
# z:  tensor([[-1.7198]])
# 1
# sigma:  tensor([[0.6641]])
# mu:  tensor([-0.3061])
# z:  tensor([[-0.1258]])
# 1
# sigma:  tensor([[0.6873]])
# mu:  tensor([-0.3781])
# z:  tensor([[-0.5606],
#         [-1.6416],
#         [-2.3264],
#         [-0.7929],
#         [-0.6803],
#         [-1.8845],
#         [-1.5380],
#         [-0.1532],
#         [-0.8676],
#         [-0.3048],
#         [-0.3218],
#         [-1.3122],
#         [-0.8998],
#         [-1.8535],
#         [-0.1525],
#         [-0.0095],
#         [-1.0603],
#         [-0.4425],
#         [-0.5303],
#         [-1.1894],
#         [-1.3185],
#         [-0.6305],
#         [-0.7779],
#         [-0.0905],
#         [-0.1508],
#         [-1.3701],
#         [-0.3111],
#         [-0.3198],
#         [-2.1131],
#         [-0.6983],
#         [-1.8593],
#         [-0.8788],
#         [-1.7008],
#         [-1.3344],
#         [-2.3286],
#         [-1.0448],
#         [-0.8327],
#         [-1.7165],
#         [-0.0591],
#         [-0.0825],
#         [-1.6657],
#         [-0.4408],
#         [-0.9903],
#         [-0.0319],
#         [-0.6760],
#         [-0.5936],
#         [-0.0584],
#         [-0.2670],
#         [-1.1623],
#         [-0.7490],
#         [-0.9173],
#         [-2.0701],
#         [-0.8535],
#         [-1.3393],
#         [-1.9517],
#         [-0.1296],
#         [-0.3055],
#         [-2.0678],
#         [-0.8925],
#         [-0.0263],
#         [-1.1575],
#         [-0.1499],
#         [-1.9409],
#         [-2.6490],
#         [-0.2907],
#         [-0.6268],
#         [-0.5438],
#         [-0.4973],
#         [-0.7660],
#         [-0.0710],
#         [-1.5071],
#         [-0.2704],
#         [-0.0146],
#         [-1.1280],
#         [-0.5257],
#         [-0.1259],
#         [-0.3851],
#         [-0.1693],
#         [-0.7018],
#         [-1.0118],
#         [-1.6575],
#         [-1.2309],
#         [-0.4649],
#         [-0.6156],
#         [-1.1989],
#         [-2.3638],
#         [-2.4909],
#         [-0.4336],
#         [-0.3610],
#         [-0.9254],
#         [-1.4055],
#         [-1.4532],
#         [-0.9445],
#         [-0.0520],
#         [-0.6413],
#         [-0.0960],
#         [-1.8360]])
# 97
# sigma:  tensor([[0.6873]])
# mu:  tensor([-0.3781])
# z:  tensor([[-1.8106]])
# 1
# sigma:  tensor([[0.6225]])
# mu:  tensor([-0.2608])
# z:  tensor([[-0.2003]])
# 1
# sigma:  tensor([[0.6217]])
# mu:  tensor([-0.2486])
# z:  tensor([[-0.6207]])
# 1
# sigma:  tensor([[0.6147]])
# mu:  tensor([-0.2159])
# z:  tensor([[-0.8981]])
# 1
# sigma:  tensor([[0.5999]])
# mu:  tensor([-0.1588])
# z:  tensor([[-0.8367]])
# 1
# sigma:  tensor([[0.6230]])
# mu:  tensor([-0.1995])
# z:  tensor([[-0.5010]])
# 1
# sigma:  tensor([[0.6314]])
# mu:  tensor([-0.2226])
# z:  tensor([[-0.2686]])
# 1
# sigma:  tensor([[0.6301]])
# mu:  tensor([-0.2106])
# z:  tensor([[-0.3329]])
# 1
# sigma:  tensor([[0.8285]])
# mu:  tensor([-0.4794])
# z:  tensor([[-0.4497]])
# 1
# sigma:  tensor([[0.8238]])
# mu:  tensor([-0.4603])
# z:  tensor([[-0.6879]])
# 1
# sigma:  tensor([[0.8092]])
# mu:  tensor([-0.4117])
# z:  tensor([[-0.7281]])
# 1
# sigma:  tensor([[0.8082]])
# mu:  tensor([-0.4096])
# z:  tensor([[-0.4065]])
# 1
# sigma:  tensor([[0.8265]])
# mu:  tensor([-0.4551])
# z:  tensor([[-1.4485]])
# 1
# sigma:  tensor([[0.7606]])
# mu:  tensor([-0.3099])
# z:  tensor([[-1.5531]])
# 1
# sigma:  tensor([[0.6967]])
# mu:  tensor([-0.1793])
# z:  tensor([[-0.1540]])
# 1
# sigma:  tensor([[0.7017]])
# mu:  tensor([-0.2032])
# z:  tensor([[-0.0442]])
# 1
# sigma:  tensor([[0.7182]])
# mu:  tensor([-0.2630])
# z:  tensor([[-1.1792]])
# 1
# sigma:  tensor([[0.6852]])
# mu:  tensor([-0.1853])
# z:  tensor([[-0.9075]])
# 1
# sigma:  tensor([[0.6665]])
# mu:  tensor([-0.1248])
# z:  tensor([[-0.4134]])
# 1
# sigma:  tensor([[0.7212]])
# mu:  tensor([-0.2180])
# z:  tensor([[-0.5651]])
# 1
# sigma:  tensor([[0.7485]])
# mu:  tensor([-0.2703])
# z:  tensor([[-1.5848]])
# 1
# sigma:  tensor([[0.6893]])
# mu:  tensor([-0.1720])
# z:  tensor([[-0.3640]])
# 1
# sigma:  tensor([[0.6870]])
# mu:  tensor([-0.1587])
# z:  tensor([[-0.6956]])
# 1
# sigma:  tensor([[0.7049]])
# mu:  tensor([-0.1919])
# z:  tensor([[-0.3593]])
# 1
# sigma:  tensor([[0.7243]])
# mu:  tensor([-0.2393])
# z:  tensor([[-0.5444]])
# 1
# sigma:  tensor([[0.7174]])
# mu:  tensor([-0.2107])
# z:  tensor([[-0.0778]])
# 1
# sigma:  tensor([[0.7178]])
# mu:  tensor([-0.2163])
# z:  tensor([[-1.9123]])
# 1
# sigma:  tensor([[0.6723]])
# mu:  tensor([-0.1634])
# z:  tensor([[-0.4405]])
# 1
# sigma:  tensor([[0.6688]])
# mu:  tensor([-0.1461])
# z:  tensor([[-1.1017]])
# 1
# sigma:  tensor([[0.6658]])
# mu:  tensor([-0.1412])
# z:  tensor([[-1.5871]])
# 1
# sigma:  tensor([[0.6148]])
# mu:  tensor([-0.0431])
# z:  tensor([[-0.8134]])
# 1
# sigma:  tensor([[0.7346]])
# mu:  tensor([-0.1713])
# z:  tensor([[-0.6696]])
# 1
# sigma:  tensor([[0.7284]])
# mu:  tensor([-0.1548])
# z:  tensor([[-1.2674]])
# 1
# sigma:  tensor([[0.6889]])
# mu:  tensor([-0.0712])
# z:  tensor([[-1.8206]])
# 1
# sigma:  tensor([[0.6358]])
# mu:  tensor([-0.0101])
# z:  tensor([[-0.7542]])
# 1
# sigma:  tensor([[0.6528]])
# mu:  tensor([-0.0379])
# z:  tensor([[-1.0628]])
# 1
# sigma:  tensor([[0.6888]])
# mu:  tensor([-0.0807])
# z:  tensor([[-2.0120]])
# 1
# sigma:  tensor([[0.6049]])
# mu:  tensor([0.0429])
# z:  tensor([[-0.4907]])
# 1
# sigma:  tensor([[0.6099]])
# mu:  tensor([0.0294])
# z:  tensor([[-1.3753]])
# 1
# sigma:  tensor([[0.5772]])
# mu:  tensor([0.0972])
# z:  tensor([[-0.2649]])
# 1
# sigma:  tensor([[0.5799]])
# mu:  tensor([0.0851])
# z:  tensor([[-0.9372]])
# 1
# sigma:  tensor([[0.6297]])
# mu:  tensor([0.0318])
# z:  tensor([[-0.5275]])
# 1
# sigma:  tensor([[0.6358]])
# mu:  tensor([0.0171])
# z:  tensor([[-0.4422]])
# 1
# sigma:  tensor([[0.6732]])
# mu:  tensor([-0.0460])
# z:  tensor([[-0.9528]])
# 1
# sigma:  tensor([[0.7257]])
# mu:  tensor([-0.1073])
# z:  tensor([[-0.9773]])
# 1
# sigma:  tensor([[0.8331]])
# mu:  tensor([-0.2187])
# z:  tensor([[-0.2972]])
# 1
# sigma:  tensor([[0.8601]])
# mu:  tensor([-0.2791])
# z:  tensor([[-0.0105]])
# 1
# sigma:  tensor([[0.8664]])
# mu:  tensor([-0.3159])
# z:  tensor([[-1.9378]])
# 1
# sigma:  tensor([[0.7470]])
# mu:  tensor([-0.1467])
# z:  tensor([[-0.2205]])
# 1
# sigma:  tensor([[0.7693]])
# mu:  tensor([-0.2040])
# z:  tensor([[-0.3280]])
# 1
# sigma:  tensor([[0.7824]])
# mu:  tensor([-0.2394])
# z:  tensor([[-1.4265]])
# 1
# sigma:  tensor([[0.7586]])
# mu:  tensor([-0.2082])
# z:  tensor([[-0.9881]])
# 1
# sigma:  tensor([[0.7315]])
# mu:  tensor([-0.1319])
# z:  tensor([[-1.0348]])
# 1
# sigma:  tensor([[0.7067]])
# mu:  tensor([-0.0775])
# z:  tensor([[-0.3914]])
# 1
# sigma:  tensor([[0.7411]])
# mu:  tensor([-0.1420])
# z:  tensor([[-1.4562]])
# 1
# sigma:  tensor([[0.6871]])
# mu:  tensor([-0.0324])
# z:  tensor([[-0.1099]])
# 1
# sigma:  tensor([[0.7729]])
# mu:  tensor([-0.1672])
# z:  tensor([[-1.2039]])
# 1
# sigma:  tensor([[0.7360]])
# mu:  tensor([-0.0994])
# z:  tensor([[-0.6067]])
# 1
# sigma:  tensor([[0.7480]])
# mu:  tensor([-0.1227])
# z:  tensor([[-0.0452]])
# 1
# sigma:  tensor([[0.7490]])
# mu:  tensor([-0.1343])
# z:  tensor([[-0.6315]])
# 1
# sigma:  tensor([[0.7694]])
# mu:  tensor([-0.1702])
# z:  tensor([[-0.0380]])
# 1
# sigma:  tensor([[0.7810]])
# mu:  tensor([-0.2184])
# z:  tensor([[-0.6862]])
# 1
# sigma:  tensor([[0.8062]])
# mu:  tensor([-0.2611])
# z:  tensor([[-1.5433]])
# 1
# sigma:  tensor([[0.7621]])
# mu:  tensor([-0.2034])
# z:  tensor([[-0.0933]])
# 1
# sigma:  tensor([[0.9645]])
# mu:  tensor([-0.4749])
# z:  tensor([[-0.8236]])
# 1
# sigma:  tensor([[0.9343]])
# mu:  tensor([-0.3920])
# z:  tensor([[-0.7546]])
# 1
# sigma:  tensor([[0.9522]])
# mu:  tensor([-0.4214])
# z:  tensor([[-0.6057]])
# 1
# sigma:  tensor([[0.9515]])
# mu:  tensor([-0.4200])
# z:  tensor([[-0.3001]])
# 1
# sigma:  tensor([[0.9482]])
# mu:  tensor([-0.4025])
# z:  tensor([[-0.3500]])
# 1
# sigma:  tensor([[0.9806]])
# mu:  tensor([-0.4706])
# z:  tensor([[-1.0281]])
# 1
# sigma:  tensor([[0.9442]])
# mu:  tensor([-0.4053])
# z:  tensor([[-1.8272]])
# 1
# sigma:  tensor([[1.2373]])
# mu:  tensor([-0.6627])
# z:  tensor([[-3.3568]])
# 1
# sigma:  tensor([[0.8163]])
# mu:  tensor([-0.3030])
# z:  tensor([[-1.4104]])
# 1
# sigma:  tensor([[0.7551]])
# mu:  tensor([-0.1757])
# z:  tensor([[-0.0621]])
# 1
# sigma:  tensor([[0.7570]])
# mu:  tensor([-0.1916])
# z:  tensor([[-0.0264]])
# 1
# sigma:  tensor([[0.7721]])
# mu:  tensor([-0.2489])
# z:  tensor([[-1.6905]])
# 1
# sigma:  tensor([[0.6983]])
# mu:  tensor([-0.1316])
# z:  tensor([[-0.5356]])
# 1
# sigma:  tensor([[0.6938]])
# mu:  tensor([-0.1156])
# z:  tensor([[-1.2913]])
# 1
# sigma:  tensor([[0.6784]])
# mu:  tensor([-0.0937])
# z:  tensor([[-1.2404]])
# 1
# sigma:  tensor([[0.6524]])
# mu:  tensor([-0.0486])
# z:  tensor([[-0.8492]])
# 1
# sigma:  tensor([[0.7300]])
# mu:  tensor([-0.1380])
# z:  tensor([[-1.6338]])
# 1
# sigma:  tensor([[0.7038]])
# mu:  tensor([-0.1083])
# z:  tensor([[-0.3495]])
# 1
# sigma:  tensor([[0.7009]])
# mu:  tensor([-0.0885])
# z:  tensor([[-0.1782]])
# 1
# sigma:  tensor([[0.7423]])
# mu:  tensor([-0.1751])
# z:  tensor([[-1.0493]])
# 1
# sigma:  tensor([[0.7280]])
# mu:  tensor([-0.1504])
# z:  tensor([[-1.1686]])
# 1
# sigma:  tensor([[0.7371]])
# mu:  tensor([-0.1623])
# z:  tensor([[-0.7919]])
# 1
# sigma:  tensor([[0.8306]])
# mu:  tensor([-0.2766])
# z:  tensor([[-0.1932]])
# 1
# sigma:  tensor([[0.8460]])
# mu:  tensor([-0.3237])
# z:  tensor([[-0.9504]])
# 1
# sigma:  tensor([[0.8249]])
# mu:  tensor([-0.2824])
# z:  tensor([[-0.2821]])
# 1
# sigma:  tensor([[0.8281]])
# mu:  tensor([-0.2945])
# z:  tensor([[-0.8397]])
# 1
# sigma:  tensor([[0.8066]])
# mu:  tensor([-0.2392])
# z:  tensor([[-0.3661]])
# 1
# sigma:  tensor([[0.8096]])
# mu:  tensor([-0.2490])
# z:  tensor([[-0.5368]])
# 1
# sigma:  tensor([[0.8007]])
# mu:  tensor([-0.2120])
# z:  tensor([[-0.3161]])
# 1
# sigma:  tensor([[0.8081]])
# mu:  tensor([-0.2348])
# z:  tensor([[-0.7626]])
# 1
# sigma:  tensor([[0.8144]])
# mu:  tensor([-0.2461])
# z:  tensor([[-0.2029]])
# 1
# sigma:  tensor([[0.8145]])
# mu:  tensor([-0.2468])
# z:  tensor([[-0.5698]])
# 1
# sigma:  tensor([[0.8059]])
# mu:  tensor([-0.2185])
# z:  tensor([[-1.6318]])
# 1
# sigma:  tensor([[0.7362]])
# mu:  tensor([-0.1206])
# z:  tensor([[-1.2135]])
# 1
# sigma:  tensor([[0.7027]])
# mu:  tensor([-0.0594])
# z:  tensor([[-1.2480]])
# 1
# sigma:  tensor([[0.6728]])
# mu:  tensor([-0.0094])
# z:  tensor([[-0.3006]])
# 1
# sigma:  tensor([[0.6977]])
# mu:  tensor([-0.0636])
# z:  tensor([[-0.0287]])
# 1
# sigma:  tensor([[0.7170]])
# mu:  tensor([-0.1264])
# z:  tensor([[-0.0448]])
# 1
# sigma:  tensor([[0.7466]])
# mu:  tensor([-0.2068])
# z:  tensor([[-0.5637]])
# 1
# sigma:  tensor([[0.9165]])
# mu:  tensor([-0.4129])
# z:  tensor([[-0.6821]])
# 1
# sigma:  tensor([[0.9348]])
# mu:  tensor([-0.4457])
# z:  tensor([[-2.0707]])
# 1
# sigma:  tensor([[0.8043]])
# mu:  tensor([-0.2895])
# z:  tensor([[-1.8447]])
# 1
# sigma:  tensor([[0.7132]])
# mu:  tensor([-0.1594])
# z:  tensor([[-0.5558]])
# 1
# sigma:  tensor([[0.7189]])
# mu:  tensor([-0.1730])
# z:  tensor([[-0.6943]])
# 1
# sigma:  tensor([[0.7146]])
# mu:  tensor([-0.1623])
# z:  tensor([[-0.0742]])
# 1
# sigma:  tensor([[0.7169]])
# mu:  tensor([-0.1796])
# z:  tensor([[-2.5372]])
# 1
# sigma:  tensor([[0.6620]])
# mu:  tensor([-0.1319])
# z:  tensor([[-0.9634]])
# 1
# sigma:  tensor([[0.6442]])
# mu:  tensor([-0.0744])
# z:  tensor([[-0.0530]])
# 1
# sigma:  tensor([[0.6485]])
# mu:  tensor([-0.0998])
# z:  tensor([[-0.1487]])
# 1
# sigma:  tensor([[0.6557]])
# mu:  tensor([-0.1294])
# z:  tensor([[-1.0057]])
# 1
# sigma:  tensor([[0.6941]])
# mu:  tensor([-0.1803])
# z:  tensor([[-1.4315]])
# 1
# sigma:  tensor([[0.8312]])
# mu:  tensor([-0.3113])
# z:  tensor([[-0.3804]])
# 1
# sigma:  tensor([[0.8272]])
# mu:  tensor([-0.2905])
# z:  tensor([[-0.2528]])
# 1
# sigma:  tensor([[0.9070]])
# mu:  tensor([-0.4250])
# z:  tensor([[-1.6305]])
# 1
# sigma:  tensor([[0.8226]])
# mu:  tensor([-0.2932])
# z:  tensor([[-0.8813]])
# 1
# sigma:  tensor([[0.8331]])
# mu:  tensor([-0.3101])
# z:  tensor([[-0.8792]])
# 1
# sigma:  tensor([[0.8211]])
# mu:  tensor([-0.2864])
# z:  tensor([[-0.5744]])
# 1
# sigma:  tensor([[0.8128]])
# mu:  tensor([-0.2583])
# z:  tensor([[-0.2977]])
# 1
# sigma:  tensor([[0.8108]])
# mu:  tensor([-0.2465])
# z:  tensor([[-1.9023]])
# 1
# sigma:  tensor([[0.7166]])
# mu:  tensor([-0.1036])
# z:  tensor([[-0.3688]])
# 1
# sigma:  tensor([[0.7301]])
# mu:  tensor([-0.1367])
# z:  tensor([[-0.1267]])
# 1
# sigma:  tensor([[0.7353]])
# mu:  tensor([-0.1609])
# z:  tensor([[-0.3868]])
# 1
# sigma:  tensor([[0.7410]])
# mu:  tensor([-0.1777])
# z:  tensor([[-1.9037]])
# 1
# sigma:  tensor([[0.7062]])
# mu:  tensor([-0.1415])
# z:  tensor([[-0.4779]])
# 1
# sigma:  tensor([[0.7434]])
# mu:  tensor([-0.2068])
# z:  tensor([[-0.8589]])
# 1
# sigma:  tensor([[0.7771]])
# mu:  tensor([-0.2558])
# z:  tensor([[-1.3671]])
# 1
# sigma:  tensor([[0.8126]])
# mu:  tensor([-0.2967])
# z:  tensor([[-0.7735]])
# 1
# sigma:  tensor([[0.8444]])
# mu:  tensor([-0.3464])
# z:  tensor([[-2.2061]])
# 1
# sigma:  tensor([[0.7151]])
# mu:  tensor([-0.1725])
# z:  tensor([[-0.1552]])
# 1
# sigma:  tensor([[0.7578]])
# mu:  tensor([-0.2632])
# z:  tensor([[-0.6576]])
# 1
# sigma:  tensor([[0.7510]])
# mu:  tensor([-0.2439])
# z:  tensor([[-0.6748]])
# 1
# sigma:  tensor([[0.7732]])
# mu:  tensor([-0.2836])
# z:  tensor([[-0.3944]])
# 1
# sigma:  tensor([[0.9207]])
# mu:  tensor([-0.4859])
# z:  tensor([[-1.1085]])
# 1
# sigma:  tensor([[0.9139]])
# mu:  tensor([-0.4754])
# z:  tensor([[-1.3181]])
# 1
# sigma:  tensor([[0.8531]])
# mu:  tensor([-0.3471])
# z:  tensor([[-0.9580]])
# 1
# sigma:  tensor([[0.8282]])
# mu:  tensor([-0.2930])
# z:  tensor([[-0.6652]])
# 1
# sigma:  tensor([[0.8417]])
# mu:  tensor([-0.3181])
# z:  tensor([[-1.0269]])
# 1
# sigma:  tensor([[0.8340]])
# mu:  tensor([-0.3058])
# z:  tensor([[-0.2611]])
# 1
# sigma:  tensor([[0.8658]])
# mu:  tensor([-0.3768])
# z:  tensor([[-0.4737]])
# 1
# sigma:  tensor([[0.8723]])
# mu:  tensor([-0.3929])
# z:  tensor([[-0.2954]])
# 1
# sigma:  tensor([[0.9109]])
# mu:  tensor([-0.4747])
# z:  tensor([[-2.5586]])
# 1
# sigma:  tensor([[0.7273]])
# mu:  tensor([-0.2522])
# z:  tensor([[-0.3618]])
# 1
# sigma:  tensor([[0.7333]])
# mu:  tensor([-0.2713])
# z:  tensor([[-2.3040]])
# 1
# sigma:  tensor([[0.6378]])
# mu:  tensor([-0.1541])
# z:  tensor([[-0.9364]])
# 1
# sigma:  tensor([[0.6297]])
# mu:  tensor([-0.1363])
# z:  tensor([[-0.1519]])
# 1
# sigma:  tensor([[0.7137]])
# mu:  tensor([-0.2759])
# z:  tensor([[-0.0722]])
# 1
# sigma:  tensor([[0.7247]])
# mu:  tensor([-0.3205])
# z:  tensor([[-0.6732]])
# 1
# sigma:  tensor([[0.7341]])
# mu:  tensor([-0.3409])
# z:  tensor([[-0.3642]])
# 1
# sigma:  tensor([[0.8299]])
# mu:  tensor([-0.5004])
# z:  tensor([[-0.5413]])
# 1
# sigma:  tensor([[0.8422]])
# mu:  tensor([-0.5296])
# z:  tensor([[-1.4702]])
# 1
# sigma:  tensor([[0.8094]])
# mu:  tensor([-0.4780])
# z:  tensor([[-0.7978]])
# 1
# sigma:  tensor([[0.8495]])
# mu:  tensor([-0.5469])
# z:  tensor([[-1.7485]])
# 1
# sigma:  tensor([[0.8661]])
# mu:  tensor([-0.5684])
# z:  tensor([[-1.8488]])
# 1
# sigma:  tensor([[0.7831]])
# mu:  tensor([-0.4425])
# z:  tensor([[-1.5719]])
# 1
# sigma:  tensor([[0.7431]])
# mu:  tensor([-0.3798])
# z:  tensor([[-0.1458]])
# 1
# sigma:  tensor([[0.7561]])
# mu:  tensor([-0.4263])
# z:  tensor([[-0.2614]])
# 1
# sigma:  tensor([[0.7543]])
# mu:  tensor([-0.4085])
# z:  tensor([[-0.5419]])
# 1
# sigma:  tensor([[0.7480]])
# mu:  tensor([-0.3825])
# z:  tensor([[-1.1308]])
# 1
# sigma:  tensor([[0.8516]])
# mu:  tensor([-0.5184])
# z:  tensor([[-0.9905]])
# 1
# sigma:  tensor([[0.8493]])
# mu:  tensor([-0.5143])
# z:  tensor([[-0.5559]])
# 1
# sigma:  tensor([[0.8395]])
# mu:  tensor([-0.4688])
# z:  tensor([[-1.0859]])
# 1
# sigma:  tensor([[0.9116]])
# mu:  tensor([-0.5684])
# z:  tensor([[-1.0149]])
# 1
# sigma:  tensor([[1.0002]])
# mu:  tensor([-0.6931])
# z:  tensor([[-0.7259]])
# 1
# sigma:  tensor([[1.1193]])
# mu:  tensor([-0.8739])
# z:  tensor([[-1.7766]])
# 1
# sigma:  tensor([[0.9721]])
# mu:  tensor([-0.6372])
# z:  tensor([[-1.6636]])
# 1
# sigma:  tensor([[1.1403]])
# mu:  tensor([-0.8311])
# z:  tensor([[-1.3970]])
# 1
# sigma:  tensor([[1.0477]])
# mu:  tensor([-0.6770])
# z:  tensor([[-0.5726]])
# 1
# sigma:  tensor([[1.0358]])
# mu:  tensor([-0.6430])
# z:  tensor([[-1.1396]])
# 1
# sigma:  tensor([[1.0712]])
# mu:  tensor([-0.6917])
# z:  tensor([[-1.5973]])
# 1
# sigma:  tensor([[1.0144]])
# mu:  tensor([-0.6168])
# z:  tensor([[-0.0925]])
# 1
# sigma:  tensor([[1.0146]])
# mu:  tensor([-0.6191])
# z:  tensor([[-1.9221]])
# 1
# sigma:  tensor([[0.9720]])
# mu:  tensor([-0.5697])
# z:  tensor([[-0.9572]])
# 1
# sigma:  tensor([[0.9697]])
# mu:  tensor([-0.5658])
# z:  tensor([[-0.6947]])
# 1
# sigma:  tensor([[0.9589]])
# mu:  tensor([-0.5402])
# z:  tensor([[-0.7916]])
# 1
# sigma:  tensor([[0.9890]])
# mu:  tensor([-0.5894])
# z:  tensor([[-0.0285]])
# 1
# sigma:  tensor([[0.9928]])
# mu:  tensor([-0.6158])
# z:  tensor([[-1.9113]])
# 1
# sigma:  tensor([[0.8784]])
# mu:  tensor([-0.4615])
# z:  tensor([[-0.6497]])
# 1
# sigma:  tensor([[0.8643]])
# mu:  tensor([-0.4118])
# z:  tensor([[-1.0359]])
# 1
# sigma:  tensor([[0.8304]])
# mu:  tensor([-0.3297])
# z:  tensor([[-0.1388]])
# 1
# sigma:  tensor([[0.8394]])
# mu:  tensor([-0.3646])
# z:  tensor([[-0.2864]])
# 1
# sigma:  tensor([[0.8439]])
# mu:  tensor([-0.3806])
# z:  tensor([[-0.6796]])
# 1
# sigma:  tensor([[0.9154]])
# mu:  tensor([-0.4876])
# z:  tensor([[-0.9604]])
# 1
# sigma:  tensor([[0.8985]])
# mu:  tensor([-0.4561])
# z:  tensor([[-1.0359]])
# 1
# sigma:  tensor([[0.9532]])
# mu:  tensor([-0.5305])
# z:  tensor([[-1.6942]])
# 1
# sigma:  tensor([[0.9770]])
# mu:  tensor([-0.5578])
# z:  tensor([[-0.4550]])
# 1
# sigma:  tensor([[1.0611]])
# mu:  tensor([-0.6977])
# z:  tensor([[-1.0977]])
# 1
# sigma:  tensor([[1.0036]])
# mu:  tensor([-0.5670])
# z:  tensor([[-1.7789]])
# 1
# sigma:  tensor([[0.8826]])
# mu:  tensor([-0.3860])
# z:  tensor([[-1.0775]])
# 1
# sigma:  tensor([[0.8439]])
# mu:  tensor([-0.2926])
# z:  tensor([[-1.0302]])
# 1
# sigma:  tensor([[0.8298]])
# mu:  tensor([-0.2694])
# z:  tensor([[-0.8565]])
# 1
# sigma:  tensor([[0.8221]])
# mu:  tensor([-0.2548])
# z:  tensor([[-2.2356]])
# 1
# sigma:  tensor([[0.7229]])
# mu:  tensor([-0.1524])
# z:  tensor([[-0.0028]])
# 1
# sigma:  tensor([[0.7252]])
# mu:  tensor([-0.1733])
# z:  tensor([[-1.4345]])
# 1
# sigma:  tensor([[0.7328]])
# mu:  tensor([-0.1821])
# z:  tensor([[-1.1003]])
# 1
# sigma:  tensor([[0.7292]])
# mu:  tensor([-0.1766])
# z:  tensor([[-0.2366]])
# 1
# sigma:  tensor([[0.7402]])
# mu:  tensor([-0.2111])
# z:  tensor([[-1.8047]])
# 1
# sigma:  tensor([[0.7173]])
# mu:  tensor([-0.1860])
# z:  tensor([[-0.2122]])
# 1
# sigma:  tensor([[0.7163]])
# mu:  tensor([-0.1737])
# z:  tensor([[-0.0283]])
# 1
# sigma:  tensor([[0.7248]])
# mu:  tensor([-0.2132])
# z:  tensor([[-0.3994]])
# 1
# sigma:  tensor([[0.7222]])
# mu:  tensor([-0.2010])
# z:  tensor([[-0.0703]])
# 1
# sigma:  tensor([[0.7486]])
# mu:  tensor([-0.2740])
# z:  tensor([[-1.2303]])
# 1
# sigma:  tensor([[0.7151]])
# mu:  tensor([-0.2051])
# z:  tensor([[-0.2555]])
# 1
# sigma:  tensor([[0.7277]])
# mu:  tensor([-0.2429])
# z:  tensor([[-0.5295]])
# 1
# sigma:  tensor([[0.7225]])
# mu:  tensor([-0.2227])
# z:  tensor([[-0.3686]])
# 1
# sigma:  tensor([[0.7427]])
# mu:  tensor([-0.2701])
# z:  tensor([[-0.6850]])
# 1
# sigma:  tensor([[0.7312]])
# mu:  tensor([-0.2210])
# z:  tensor([[-0.0468]])
# 1
# sigma:  tensor([[0.7364]])
# mu:  tensor([-0.2501])
# z:  tensor([[-0.4842]])
# 1
# sigma:  tensor([[0.7369]])
# mu:  tensor([-0.2518])
# z:  tensor([[-0.5554]])
# 1
# sigma:  tensor([[0.9838]])
# mu:  tensor([-0.5354])
# z:  tensor([[-0.2664]])
# 1
# sigma:  tensor([[0.9881]])
# mu:  tensor([-0.5508])
# z:  tensor([[-0.7751]])
# 1
# sigma:  tensor([[1.0273]])
# mu:  tensor([-0.6127])
# z:  tensor([[-0.6320]])
# 1
# sigma:  tensor([[1.0356]])
# ...
# mu:  tensor([-0.4369])
# z:  tensor([[-1.1843]])
# 1
# sigma:  tensor([[0.5916]])
# mu:  tensor([-0.4059])
# z:  tensor([[-0.2303]])
# 1
# sigma:  tensor([[0.5917]])
# mu:  tensor([-0.4069])
# z:  tensor([[-0.7273]])
# 1
# sigma:  tensor([[0.5988]])
# mu:  tensor([-0.4256])
# z:  tensor([[-0.6822]])
# 1
# sigma:  tensor([[0.5913]])
# mu:  tensor([-0.3841])
# z:  tensor([[-0.6783]])
# 1
# sigma:  tensor([[0.5875]])
# mu:  tensor([-0.3702])
# z:  tensor([[-0.3772]])
# 1
# sigma:  tensor([[0.5893]])
# mu:  tensor([-0.3782])
# z:  tensor([[-0.6101]])
# 1
# sigma:  tensor([[0.7357]])
# mu:  tensor([-0.6175])
# z:  tensor([[-0.7039]])
# 1
# sigma:  tensor([[0.7278]])
# mu:  tensor([-0.5919])
# z:  tensor([[-1.4869]])
# 1
# sigma:  tensor([[0.7103]])
# mu:  tensor([-0.5599])
# z:  tensor([[-0.5402]])
# 1
# sigma:  tensor([[0.7168]])
# mu:  tensor([-0.5788])
# z:  tensor([[-1.9278]])
# 1
# sigma:  tensor([[0.6537]])
# mu:  tensor([-0.4647])
# z:  tensor([[-1.6266]])
# 1
# sigma:  tensor([[0.6066]])
# mu:  tensor([-0.3455])
# z:  tensor([[-0.9517]])
# 1
# sigma:  tensor([[0.6052]])
# mu:  tensor([-0.3423])
# z:  tensor([[-2.5346]])
# 1
# sigma:  tensor([[0.5180]])
# mu:  tensor([-0.1979])
# z:  tensor([[-0.3912]])
# 1
# sigma:  tensor([[0.5167]])
# mu:  tensor([-0.1886])
# z:  tensor([[-0.2225]])
# 1
# sigma:  tensor([[0.5239]])
# mu:  tensor([-0.2187])
# z:  tensor([[-1.1517]])
# 1
# sigma:  tensor([[0.5355]])
# mu:  tensor([-0.2402])
# z:  tensor([[-2.1551]])
# 1
# sigma:  tensor([[0.4819]])
# mu:  tensor([-0.1305])
# z:  tensor([[-0.6849]])
# 1
# sigma:  tensor([[0.5210]])
# mu:  tensor([-0.2019])
# z:  tensor([[-0.1647]])
# 1
# sigma:  tensor([[0.5235]])
# mu:  tensor([-0.2179])
# z:  tensor([[-1.0977]])
# 1
# sigma:  tensor([[0.5094]])
# mu:  tensor([-0.1686])
# z:  tensor([[-0.5858]])
# 1
# sigma:  tensor([[0.6448]])
# mu:  tensor([-0.3583])
# z:  tensor([[-1.6737]])
# 1
# sigma:  tensor([[0.6262]])
# mu:  tensor([-0.3288])
# z:  tensor([[-0.8733]])
# 1
# sigma:  tensor([[0.6150]])
# mu:  tensor([-0.2938])
# z:  tensor([[-1.2691]])
# 1
# sigma:  tensor([[0.5915]])
# mu:  tensor([-0.2374])
# z:  tensor([[-1.2424]])
# 1
# sigma:  tensor([[0.5692]])
# mu:  tensor([-0.1782])
# z:  tensor([[-0.1429]])
# 1
# sigma:  tensor([[0.6258]])
# mu:  tensor([-0.2940])
# z:  tensor([[-2.0287]])
# 1
# sigma:  tensor([[0.5608]])
# mu:  tensor([-0.1618])
# z:  tensor([[-0.1962]])
# 1
# sigma:  tensor([[0.6494]])
# mu:  tensor([-0.3123])
# z:  tensor([[-0.1874]])
# 1
# sigma:  tensor([[0.6786]])
# mu:  tensor([-0.3899])
# z:  tensor([[-0.5017]])
# 1
# sigma:  tensor([[0.6764]])
# mu:  tensor([-0.3815])
# z:  tensor([[-0.5216]])
# 1
# sigma:  tensor([[0.6709]])
# mu:  tensor([-0.3487])
# z:  tensor([[-0.1591]])
# 1
# sigma:  tensor([[0.7322]])
# mu:  tensor([-0.4803])
# z:  tensor([[-0.1232]])
# 1
# sigma:  tensor([[0.7716]])
# mu:  tensor([-0.5845])
# z:  tensor([[-1.0555]])
# 1
# sigma:  tensor([[0.7429]])
# mu:  tensor([-0.4959])
# z:  tensor([[-0.5828]])
# 1
# sigma:  tensor([[0.7583]])
# mu:  tensor([-0.5328])
# z:  tensor([[-1.7766]])
# 1
# sigma:  tensor([[0.6884]])
# mu:  tensor([-0.4000])
# z:  tensor([[-1.4433]])
# 1
# sigma:  tensor([[0.6706]])
# mu:  tensor([-0.3693])
# z:  tensor([[-0.7650]])
# 1
# sigma:  tensor([[0.6704]])
# mu:  tensor([-0.3690])
# z:  tensor([[-0.1828]])
# 1
# sigma:  tensor([[0.6953]])
# mu:  tensor([-0.4403])
# z:  tensor([[-1.3965]])
# 1
# sigma:  tensor([[0.6684]])
# mu:  tensor([-0.3882])
# z:  tensor([[-0.6035]])
# 1
# sigma:  tensor([[0.6661]])
# mu:  tensor([-0.3808])
# z:  tensor([[-0.3308]])
# 1
# sigma:  tensor([[0.6645]])
# mu:  tensor([-0.3698])
# z:  tensor([[-0.5991]])
# 1
# sigma:  tensor([[0.6737]])
# mu:  tensor([-0.3935])
# z:  tensor([[-0.4625]])
# 1
# sigma:  tensor([[0.7205]])
# mu:  tensor([-0.4902])
# z:  tensor([[-0.4813]])
# 1
# sigma:  tensor([[0.7153]])
# mu:  tensor([-0.4611])
# z:  tensor([[-0.4747]])
# 1
# sigma:  tensor([[0.7322]])
# mu:  tensor([-0.5049])
# z:  tensor([[-1.2420]])
# 1
# sigma:  tensor([[0.7101]])
# mu:  tensor([-0.4596])
# z:  tensor([[-1.9509]])
# 1
# sigma:  tensor([[0.6350]])
# mu:  tensor([-0.3181])
# z:  tensor([[-1.5380]])
# 1
# sigma:  tensor([[0.6232]])
# mu:  tensor([-0.2991])
# z:  tensor([[-1.9765]])
# 1
# sigma:  tensor([[0.5698]])
# mu:  tensor([-0.2108])
# z:  tensor([[-1.2102]])
# 1
# sigma:  tensor([[0.5510]])
# mu:  tensor([-0.1617])
# z:  tensor([[-0.7580]])
# 1
# sigma:  tensor([[0.5438]])
# mu:  tensor([-0.1325])
# z:  tensor([[-0.5231]])
# 1
# sigma:  tensor([[0.5404]])
# mu:  tensor([-0.1129])
# z:  tensor([[-1.2592]])
# 1
# sigma:  tensor([[0.5396]])
# mu:  tensor([-0.1115])
# z:  tensor([[-0.7143]])
# 1
# sigma:  tensor([[0.5356]])
# mu:  tensor([-0.0977])
# z:  tensor([[-1.4812]])
# 1
# sigma:  tensor([[0.5308]])
# mu:  tensor([-0.0906])
# z:  tensor([[-1.0283]])
# 1
# sigma:  tensor([[0.5411]])
# mu:  tensor([-0.1086])
# z:  tensor([[-0.0664]])
# 1
# sigma:  tensor([[0.5413]])
# mu:  tensor([-0.1126])
# z:  tensor([[-1.7718]])
# 1
# sigma:  tensor([[0.5167]])
# mu:  tensor([-0.0757])
# z:  tensor([[-0.3449]])
# 1
# sigma:  tensor([[0.5166]])
# mu:  tensor([-0.0750])
# z:  tensor([[-0.8428]])
# 1
# sigma:  tensor([[0.5343]])
# mu:  tensor([-0.1073])
# z:  tensor([[-0.7125]])
# 1
# sigma:  tensor([[0.5280]])
# mu:  tensor([-0.0772])
# z:  tensor([[-0.7540]])
# 1
# sigma:  tensor([[0.5257]])
# mu:  tensor([-0.0705])
# z:  tensor([[-0.2064]])
# 1
# sigma:  tensor([[0.5255]])
# mu:  tensor([-0.0686])
# z:  tensor([[-0.3470]])
# 1
# sigma:  tensor([[0.5248]])
# mu:  tensor([-0.0643])
# z:  tensor([[-0.2752]])
# 1
# sigma:  tensor([[0.5410]])
# mu:  tensor([-0.1094])
# z:  tensor([[-0.8873]])
# 1
# sigma:  tensor([[0.5372]])
# mu:  tensor([-0.0998])
# z:  tensor([[-0.6578]])
# 1
# sigma:  tensor([[0.5334]])
# mu:  tensor([-0.0851])
# z:  tensor([[-0.0677]])
# 1
# sigma:  tensor([[0.5734]])
# mu:  tensor([-0.1761])
# z:  tensor([[-0.3493]])
# 1
# sigma:  tensor([[0.5762]])
# mu:  tensor([-0.1877])
# z:  tensor([[-0.4297]])
# 1
# sigma:  tensor([[0.5768]])
# mu:  tensor([-0.1904])
# z:  tensor([[-0.1381]])
# 1
# sigma:  tensor([[0.5777]])
# mu:  tensor([-0.1977])
# z:  tensor([[-1.6848]])
# 1
# sigma:  tensor([[0.5431]])
# mu:  tensor([-0.1340])
# z:  tensor([[-0.4378]])
# 1
# sigma:  tensor([[0.5489]])
# mu:  tensor([-0.1527])
# z:  tensor([[-0.3342]])
# 1
# sigma:  tensor([[0.5753]])
# mu:  tensor([-0.2155])
# z:  tensor([[-0.6505]])
# 1
# sigma:  tensor([[0.5786]])
# mu:  tensor([-0.2247])
# z:  tensor([[-0.4749]])
# 1
# sigma:  tensor([[0.6020]])
# mu:  tensor([-0.2791])
# z:  tensor([[-0.8413]])
# 1
# sigma:  tensor([[0.5960]])
# mu:  tensor([-0.2622])
# z:  tensor([[-0.9893]])
# 1
# sigma:  tensor([[0.6347]])
# mu:  tensor([-0.3258])
# z:  tensor([[-0.3306]])
# 1
# sigma:  tensor([[0.6409]])
# mu:  tensor([-0.3485])
# z:  tensor([[-0.5821]])
# 1
# sigma:  tensor([[0.6422]])
# mu:  tensor([-0.3524])
# z:  tensor([[-0.2343]])
# 1
# sigma:  tensor([[0.6413]])
# mu:  tensor([-0.3435])
# z:  tensor([[-0.4325]])
# 1
# sigma:  tensor([[0.6992]])
# mu:  tensor([-0.4573])
# z:  tensor([[-0.6173]])
# 1
# sigma:  tensor([[0.6913]])
# mu:  tensor([-0.4217])
# z:  tensor([[-0.1846]])
# 1
# sigma:  tensor([[0.6937]])
# mu:  tensor([-0.4354])
# z:  tensor([[-1.0661]])
# 1
# sigma:  tensor([[0.6770]])
# mu:  tensor([-0.3957])
# z:  tensor([[-1.4138]])
# 1
# sigma:  tensor([[0.6416]])
# mu:  tensor([-0.3183])
# z:  tensor([[-1.5838]])
# 1
# sigma:  tensor([[0.5996]])
# mu:  tensor([-0.2275])
# z:  tensor([[-0.2171]])
# 1
# sigma:  tensor([[0.5991]])
# mu:  tensor([-0.2229])
# z:  tensor([[-0.5541]])
# 1
# sigma:  tensor([[0.5950]])
# mu:  tensor([-0.2042])
# z:  tensor([[-0.3576]])
# 1
# sigma:  tensor([[0.6282]])
# mu:  tensor([-0.2772])
# z:  tensor([[-0.4497]])
# 1
# sigma:  tensor([[0.6248]])
# mu:  tensor([-0.2569])
# z:  tensor([[-0.2136]])
# 1
# sigma:  tensor([[0.6248]])
# mu:  tensor([-0.2569])
# z:  tensor([[-1.3217]])
# 1
# sigma:  tensor([[0.6367]])
# mu:  tensor([-0.2750])
# z:  tensor([[-0.1661]])
# 1
# sigma:  tensor([[0.6377]])
# mu:  tensor([-0.2824])
# z:  tensor([[-0.1984]])
# 1
# sigma:  tensor([[0.6456]])
# mu:  tensor([-0.3140])
# z:  tensor([[-1.7686]])
# 1
# sigma:  tensor([[0.6037]])
# mu:  tensor([-0.2443])
# z:  tensor([[-2.4743]])
# 1
# sigma:  tensor([[0.5188]])
# mu:  tensor([-0.1086])
# z:  tensor([[-0.5730]])
# 1
# sigma:  tensor([[0.5150]])
# mu:  tensor([-0.0872])
# z:  tensor([[-1.3011]])
# 1
# sigma:  tensor([[0.5085]])
# mu:  tensor([-0.0755])
# z:  tensor([[-0.4779]])
# 1
# sigma:  tensor([[0.5089]])
# mu:  tensor([-0.0769])
# z:  tensor([[-1.5887]])
# 1
# sigma:  tensor([[0.4859]])
# mu:  tensor([-0.0336])
# z:  tensor([[-0.5526]])
# 1
# sigma:  tensor([[0.4829]])
# mu:  tensor([-0.0147])
# z:  tensor([[-0.0481]])
# 1
# sigma:  tensor([[0.4868]])
# mu:  tensor([-0.0396])
# z:  tensor([[-0.1072]])
# 1
# sigma:  tensor([[0.4868]])
# mu:  tensor([-0.0402])
# z:  tensor([[-0.1443]])
# 1
# sigma:  tensor([[0.4867]])
# mu:  tensor([-0.0373])
# z:  tensor([[-0.4360]])
# 1
# sigma:  tensor([[0.5001]])
# mu:  tensor([-0.0722])
# z:  tensor([[-1.0875]])
# 1
# sigma:  tensor([[0.4872]])
# mu:  tensor([-0.0258])
# z:  tensor([[-0.4220]])
# 1
# sigma:  tensor([[0.4867]])
# mu:  tensor([-0.0235])
# z:  tensor([[-0.5414]])
# 1
# sigma:  tensor([[0.4839]])
# mu:  tensor([-0.0065])
# z:  tensor([[-0.3389]])
# 1
# sigma:  tensor([[0.4877]])
# mu:  tensor([-0.0219])
# z:  tensor([[-0.6809]])
# 1
# sigma:  tensor([[0.5101]])
# mu:  tensor([-0.0637])
# z:  tensor([[-0.6245]])
# 1
# sigma:  tensor([[0.5060]])
# mu:  tensor([-0.0443])
# z:  tensor([[-1.4872]])
# 1
# sigma:  tensor([[0.4826]])
# mu:  tensor([0.0104])
# z:  tensor([[-0.0718]])
# 1
# sigma:  tensor([[0.4920]])
# mu:  tensor([-0.0280])
# z:  tensor([[-0.6132]])
# 1
# sigma:  tensor([[0.4899]])
# mu:  tensor([-0.0197])
# z:  tensor([[-0.2577]])
# 1
# sigma:  tensor([[0.4915]])
# mu:  tensor([-0.0286])
# z:  tensor([[-1.5208]])
# 1
# sigma:  tensor([[0.4708]])
# mu:  tensor([0.0129])
# z:  tensor([[-0.6812]])
# 1
# sigma:  tensor([[0.4750]])
# mu:  tensor([0.0019])
# z:  tensor([[-0.9095]])
# 1
# sigma:  tensor([[0.4700]])
# mu:  tensor([0.0163])
# z:  tensor([[-0.0245]])
# 1
# sigma:  tensor([[0.4925]])
# mu:  tensor([-0.0470])
# z:  tensor([[-0.4662]])
# 1
# sigma:  tensor([[0.5495]])
# mu:  tensor([-0.1388])
# z:  tensor([[-0.9258]])
# 1
# sigma:  tensor([[0.5460]])
# mu:  tensor([-0.1305])
# z:  tensor([[-0.6146]])
# 1
# sigma:  tensor([[0.5434]])
# mu:  tensor([-0.1207])
# z:  tensor([[-0.9600]])
# 1
# sigma:  tensor([[0.5425]])
# mu:  tensor([-0.1186])
# z:  tensor([[-0.2621]])
# 1
# sigma:  tensor([[0.5425]])
# mu:  tensor([-0.1190])
# z:  tensor([[-1.4941]])
# 1
# sigma:  tensor([[0.5228]])
# mu:  tensor([-0.0834])
# z:  tensor([[-0.1085]])
# 1
# sigma:  tensor([[0.5427]])
# mu:  tensor([-0.1426])
# z:  tensor([[-0.4263]])
# 1
# sigma:  tensor([[0.5689]])
# mu:  tensor([-0.2012])
# z:  tensor([[-0.0335]])
# 1
# sigma:  tensor([[0.5697]])
# mu:  tensor([-0.2118])
# z:  tensor([[-1.0137]])
# 1
# sigma:  tensor([[0.5735]])
# mu:  tensor([-0.2195])
# z:  tensor([[-0.1477]])
# 1
# sigma:  tensor([[0.6139]])
# mu:  tensor([-0.3154])
# z:  tensor([[-0.3071]])
# 1
# sigma:  tensor([[0.6289]])
# mu:  tensor([-0.3611])
# z:  tensor([[-0.2526]])
# 1
# sigma:  tensor([[0.9974]])
# mu:  tensor([-0.8751])
# z:  tensor([[-1.4005]])
# 1
# sigma:  tensor([[0.9563]])
# mu:  tensor([-0.8047])
# z:  tensor([[-0.5671]])
# 1
# sigma:  tensor([[0.9447]])
# mu:  tensor([-0.7628])
# z:  tensor([[-0.9444]])
# 1
# sigma:  tensor([[0.9185]])
# mu:  tensor([-0.7024])
# z:  tensor([[-0.6664]])
# 1
# sigma:  tensor([[0.9019]])
# mu:  tensor([-0.6377])
# z:  tensor([[-0.7130]])
# 1
# sigma:  tensor([[0.9484]])
# mu:  tensor([-0.7215])
# z:  tensor([[-1.3577]])
# 1
# sigma:  tensor([[0.8857]])
# mu:  tensor([-0.5998])
# z:  tensor([[-0.7031]])
# 1
# sigma:  tensor([[1.6386]])
# mu:  tensor([-1.5173])
# z:  tensor([[-1.1587]])
# 1
# sigma:  tensor([[1.5199]])
# mu:  tensor([-1.3218])
# z:  tensor([[-1.8874]])
# 1
# sigma:  tensor([[1.2661]])
# mu:  tensor([-0.9765])
# z:  tensor([[-1.6694]])
# 1
# sigma:  tensor([[1.0956]])
# mu:  tensor([-0.7039])
# z:  tensor([[-1.7814]])
# 1
# sigma:  tensor([[0.9552]])
# mu:  tensor([-0.4980])
# z:  tensor([[-1.8602]])
# 1
# sigma:  tensor([[0.8344]])
# mu:  tensor([-0.3181])
# z:  tensor([[-0.1730]])
# 1
# sigma:  tensor([[0.8419]])
# mu:  tensor([-0.3471])
# z:  tensor([[-0.5184]])
# 1
# sigma:  tensor([[0.8344]])
# mu:  tensor([-0.3182])
# z:  tensor([[-0.6615]])
# 1
# sigma:  tensor([[0.8454]])
# mu:  tensor([-0.3396])
# z:  tensor([[-1.2884]])
# 1
# sigma:  tensor([[0.7997]])
# mu:  tensor([-0.2568])
# z:  tensor([[-1.3744]])
# 1
# sigma:  tensor([[0.7758]])
# mu:  tensor([-0.2242])
# z:  tensor([[-0.1871]])
# 1
# sigma:  tensor([[0.8163]])
# mu:  tensor([-0.3108])
# z:  tensor([[-0.9379]])
# 1
# sigma:  tensor([[0.7923]])
# mu:  tensor([-0.2518])
# z:  tensor([[-1.2852]])
# 1
# sigma:  tensor([[0.7922]])
# mu:  tensor([-0.2516])
# z:  tensor([[-1.0665]])
# 1
# sigma:  tensor([[0.8867]])
# mu:  tensor([-0.3586])
# z:  tensor([[-1.8922]])
# 1
# sigma:  tensor([[0.8121]])
# mu:  tensor([-0.2728])
# z:  tensor([[-0.5137]])
# 1
# sigma:  tensor([[1.0090]])
# mu:  tensor([-0.5072])
# z:  tensor([[-0.6398]])
# 1
# sigma:  tensor([[1.0039]])
# mu:  tensor([-0.4963])
# z:  tensor([[-1.6983]])
# 1
# sigma:  tensor([[0.8883]])
# mu:  tensor([-0.3083])
# z:  tensor([[-1.4659]])
# 1
# sigma:  tensor([[0.8233]])
# mu:  tensor([-0.2079])
# z:  tensor([[-0.6172]])
# 1
# sigma:  tensor([[0.8181]])
# mu:  tensor([-0.1949])
# z:  tensor([[-0.7591]])
# 1
# sigma:  tensor([[0.9432]])
# mu:  tensor([-0.3338])
# z:  tensor([[-2.5270]])
# 1
# sigma:  tensor([[0.7463]])
# mu:  tensor([-0.1222])
# z:  tensor([[-0.8911]])
# 1
# sigma:  tensor([[0.8922]])
# mu:  tensor([-0.2656])
# z:  tensor([[-0.6503]])
# 1
# sigma:  tensor([[0.9003]])
# mu:  tensor([-0.2806])
# z:  tensor([[-1.8286]])
# 1
# sigma:  tensor([[0.7933]])
# mu:  tensor([-0.1245])
# z:  tensor([[-1.2489]])
# 1
# sigma:  tensor([[0.7581]])
# mu:  tensor([-0.0685])
# z:  tensor([[-0.7078]])
# 1
# sigma:  tensor([[0.7781]])
# mu:  tensor([-0.0992])
# z:  tensor([[-0.0405]])
# 1
# sigma:  tensor([[0.7787]])
# mu:  tensor([-0.1067])
# z:  tensor([[-0.8626]])
# 1
# sigma:  tensor([[0.7589]])
# mu:  tensor([-0.0481])
# z:  tensor([[-0.9982]])
# 1
# sigma:  tensor([[0.7354]])
# mu:  tensor([0.0032])
# z:  tensor([[-1.0351]])
# 1
# sigma:  tensor([[0.7110]])
# mu:  tensor([0.0578])
# z:  tensor([[-0.9244]])
# 1
# sigma:  tensor([[0.7070]])
# mu:  tensor([0.0638])
# z:  tensor([[-0.8007]])
# 1
# sigma:  tensor([[0.6930]])
# mu:  tensor([0.1075])
# z:  tensor([[-0.6871]])
# 1
# sigma:  tensor([[0.6938]])
# mu:  tensor([0.1061])
# z:  tensor([[-0.4811]])
# 1
# sigma:  tensor([[0.7169]])
# mu:  tensor([0.0682])
# z:  tensor([[-0.7436]])
# 1
# sigma:  tensor([[0.7241]])
# mu:  tensor([0.0568])
# z:  tensor([[-0.9646]])
# 1
# sigma:  tensor([[0.7346]])
# mu:  tensor([0.0440])
# z:  tensor([[-1.0029]])
# 1
# sigma:  tensor([[0.7235]])
# mu:  tensor([0.0607])
# z:  tensor([[-0.0699]])
# 1
# sigma:  tensor([[0.7416]])
# mu:  tensor([0.0090])
# z:  tensor([[-0.0193]])
# 1
# sigma:  tensor([[0.7488]])
# mu:  tensor([-0.0258])
# z:  tensor([[-0.8524]])
# 1
# sigma:  tensor([[0.7469]])
# mu:  tensor([-0.0227])
# z:  tensor([[-0.9933]])
# 1
# sigma:  tensor([[0.7230]])
# mu:  tensor([0.0416])
# z:  tensor([[-0.0722]])
# 1
# sigma:  tensor([[0.7572]])
# mu:  tensor([-0.0321])
# z:  tensor([[-0.3805]])
# 1
# sigma:  tensor([[0.7809]])
# mu:  tensor([-0.0778])
# z:  tensor([[-0.2078],
#         [-0.1680],
#         [-0.0333],
#         [-0.8125],
#         [-0.4679],
#         [-1.3713],
#         [-0.0993],
#         [-0.7909],
#         [-0.5722],
#         [-1.7152],
#         [-1.3181],
#         [-0.4734],
#         [-0.2129],
#         [-0.4370],
#         [-1.3010],
#         [-0.6039],
#         [-0.7340],
#         [-1.0257],
#         [-1.0852],
#         [-0.3794],
#         [-0.1520],
#         [-0.6406],
#         [-1.4143],
#         [-0.8742],
#         [-1.7867],
#         [-0.4541],
#         [-0.8675],
#         [-1.2824],
#         [-0.0526],
#         [-0.2493],
#         [-0.1160],
#         [-2.1696],
#         [-0.0164],
#         [-1.7282],
#         [-0.9460],
#         [-0.8053],
#         [-0.0997],
#         [-0.1249],
#         [-0.7229],
#         [-0.3064],
#         [-0.5721],
#         [-0.1215],
#         [-1.0440],
#         [-0.5288],
#         [-0.4105],
#         [-0.0222],
#         [-0.6644],
#         [-1.0314],
#         [-1.1753],
#         [-0.1113],
#         [-0.4408],
#         [-0.4291],
#         [-0.8053],
#         [-2.0720],
#         [-0.9018],
#         [-0.0740],
#         [-0.6691],
#         [-0.3003],
#         [-1.1145],
#         [-0.4966],
#         [-0.6181],
#         [-0.2763],
#         [-0.5189],
#         [-0.3681],
#         [-1.1191],
#         [-0.1310],
#         [-0.8545],
#         [-0.8918],
#         [-0.3080],
#         [-0.2664],
#         [-0.9162],
#         [-0.2219],
#         [-0.6744],
#         [-1.8758],
#         [-0.9938],
#         [-0.2650],
#         [-1.7848],
#         [-0.5614],
#         [-0.0934],
#         [-1.6051],
#         [-0.8331],
#         [-0.4487],
#         [-0.0810],
#         [-0.3358],
#         [-0.4544],
#         [-1.5076],
#         [-0.2154],
#         [-0.4412],
#         [-0.0752],
#         [-0.3347],
#         [-0.0878],
#         [-1.2802],
#         [-1.4716],
#         [-0.6612],
#         [-0.1180],
#         [-0.4268],
#         [-0.8678]])
# 97

# %%
print("censored kl divergence: ", kl_divergence(m, M))
# Out:
# censored kl divergence:  tensor(0.0171)

# %%
print("empirical kl divergence: ", kl_divergence(emp, M))
# Out:
# empirical kl divergence:  tensor(0.4764)

# %%
store = Store(args.out_dir + '/' + args.exp)

schema = { 
    'kl_div_emp': float, 
    'kl_div_censored': float,
    'var': int,
    'alpha': float,
}

store.add_table(args.table_name, schema)

for i in range(args.trials): 
    gt_loc = Uniform(-1, 1).sample([1,])
    for var in range(1, args.var + 1):
        # create new dataset
        gt_scale = var * ch.ones(1, 1)
        gt_dist = MultivariateNormal(gt_loc, gt_scale)
        samples = gt_dist.sample([args.samples])

        # right truncate at 0
        phi = oracle.Right_Distribution(Tensor([0.0]))
        indices = phi(samples).nonzero()[:,0]
        S = samples[indices]
        alpha = S.size(0) / samples.size(0)

        emp_dist = MultivariateNormal(S.mean(0), S.var(0) * ch.ones(1, 1))

        S_norm = (S - emp_dist.loc) / ch.sqrt(emp_dist.covariance_matrix) 
        phi_norm = oracle.Right_Distribution((phi.right - emp_dist.loc) / ch.sqrt(emp_dist.covariance_matrix))


        censored = CensoredNormal(phi=phi_norm, 
                              alpha=alpha, 
                              epochs=2, 
                              bs=10, 
                              num_samples=100,
                              lr=1e-1)
        censored.fit(S_norm)


        loc_ = (censored.loc * ch.sqrt(emp_dist.covariance_matrix)) + emp_dist.loc
        scale_ = censored.variance * emp_dist.covariance_matrix

        censor_dist = MultivariateNormal(loc_, scale_)

        kl_censor = float(kl_divergence(gt_dist, censor_dist))
        kl_emp = float(kl_divergence(gt_dist, emp_dist))


        store[args.table_name].update_row({ 
            'kl_div_emp': kl_emp, 
            'kl_div_censored': kl_censor,
            'var': var,
            'alpha': alpha,
        })
        store[args.table_name].flush_row()
        
        IPython.display.clear_output()

    
store.close()

# %%
reader = CollectionReader(args.out_dir + '/' + args.exp)
logs = reader.df(args.table_name)
reader.close()
logs.head(10)
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 85.35it/s]
#    kl_div_emp  kl_div_censored  var  alpha  \
# 0    2.122517         0.225934    1  0.418
# 1    1.829372         0.176762    2  0.440
# 2    1.560743         0.052302    3  0.447
# 3    1.639066         0.056943    4  0.428
# 4    1.578573         0.036990    5  0.470
# 5    1.535295         0.020403    6  0.441
# 6    1.481841         0.212609    7  0.455
# 7    1.534712         0.113776    8  0.489
# 8    1.556620         0.001576    9  0.485
# 9    1.501354         0.037289   10  0.481
#
#                                  exp_id
# 0  55eb3e14-5797-442f-9c3a-4c46e7b24ea5
# 1  55eb3e14-5797-442f-9c3a-4c46e7b24ea5
# 2  55eb3e14-5797-442f-9c3a-4c46e7b24ea5
# 3  55eb3e14-5797-442f-9c3a-4c46e7b24ea5
# 4  55eb3e14-5797-442f-9c3a-4c46e7b24ea5
# 5  55eb3e14-5797-442f-9c3a-4c46e7b24ea5
# 6  55eb3e14-5797-442f-9c3a-4c46e7b24ea5
# 7  55eb3e14-5797-442f-9c3a-4c46e7b24ea5
# 8  55eb3e14-5797-442f-9c3a-4c46e7b24ea5
# 9  55eb3e14-5797-442f-9c3a-4c46e7b24ea5

# %%
print("kl emp div: {}".format(logs.kl_div_emp.mean()))
print("kl censor div: {}".format(logs.kl_div_censored.mean()))
# Out:
# kl emp div: 1.5869651687145234
# kl censor div: 0.3485716214531567

# %%
sns.lineplot(data=logs, x='var', y='kl_div_emp', color='red', label='Empirical Estimate')
ax = sns.lineplot(data=logs, x='var', y='kl_div_censored', color='blue', label='Censored Estimate')
ax.set_title('Censored Normal Varying Distribution Variance')
ax.set_xlabel('$\Sigma$')
ax.set_ylabel('$D_{KL}(\mathcal{N}(\widetilde{\mu}, \widetilde{\Sigma}) || \mathcal{N}(\mu^{*}, \Sigma^{*}))$')
ax.set_title('Variance 10 - 1D Censored')
ax.legend()
plt.show()

# %%
gt_dist = MultivariateNormal(ch.zeros(1) + .5, ch.ones(1, 1))

# %%
gt_loc
# Out:
# tensor(0.1174)

# %%
censored.scale
# Out:
# tensor([[0.5863]])
