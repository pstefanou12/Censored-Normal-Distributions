# %%
import sys 
sys.path.append('/Users/patroklos/Desktop/delphi_')

import torch as ch
from torch import Tensor
from torch.distributions.multivariate_normal import MultivariateNormal
from torch.distributions.kl import kl_divergence

import seaborn as sns
import matplotlib.pyplot as plt
import IPython 

from delphi.distributions.normal import CensoredNormal
from delphi import oracle
from delphi.utils import constants as consts
from delphi.utils.helpers import setup_store_with_metadata
from cox.utils import Parameters
from cox.store import Store
from cox.readers import CollectionReader

TABLE_NAME = 'logs'

# %%
args = Parameters({ 
    'samples': 1000, 
    'batch_size': 1, 
    'tol': 1e-1, 
    'lr': 1e-1, 
    'out_dir': '/Users/patroklos/Desktop/exp',
    'exp': 'censoredVaryingVar', 
    'trials': 20,
    'var': 10,
})

# %% [markdown]
# Synthetic Data Experiment for 1 Dimensional Censored Gaussian Distributions

# %%
M = MultivariateNormal(Tensor([0.0]), 1.0*ch.ones(1, 1))
samples = M.sample([args.samples])

plt.hist(samples.flatten(), bins=100)
plt.show()

# %% [markdown]
# Truncate the Dataset

# %%
phi = oracle.Right(Tensor([1.0]))
# phi = oracle.Identity()
indices = phi(samples).nonzero()[:,0]
S = samples[indices]
alpha = S.size(0) / samples.size(0)
print("alpha: {}".format(alpha))

plt.hist(S.flatten(), bins=100)
plt.show()
# Out:
# alpha: 0.84

# %%
emp_loc = S.mean(0)
print("empirical mean: ", emp_loc)
emp_scale = ch.sqrt(S.var(0))
print("empirical scale: ", emp_scale)

S_norm = (S - emp_loc) / emp_scale
phi_norm = oracle.Right((phi.right - emp_loc) / emp_scale)
# Out:
# empirical mean:  tensor([-0.2501])
# empirical scale:  tensor([0.8030])

# %% [markdown]
# Run algorithm to Remove Bias from the Dataset

# %%
censored = CensoredNormal(phi=phi_norm, 
                          alpha=alpha, 
                          iter_=1, 
                          bs=10, 
                          num_samples=10,
#                           step_lr=100,
#                           step_lr=50,
                          lr=1e-1)
#                           custom_lr_multiplier='adam')
censored.fit(S_norm)
# Out:
# mu: tensor([0.0135])
# cov: tensor([[1.0021]])
# cov grad: tensor([[-0.0314]])
# loc grad: tensor([-1.0675])
# mu: tensor([0.1201])
# cov: tensor([[0.9989]])
# cov grad: tensor([[-0.3492]])
# loc grad: tensor([-0.2918])
# mu: tensor([0.1442])
# cov: tensor([[0.9653]])
# cov grad: tensor([[0.4053]])
# loc grad: tensor([0.5500])
# mu: tensor([0.0948])
# cov: tensor([[1.0046]])
# cov grad: tensor([[0.0071]])
# loc grad: tensor([-0.0047])
# mu: tensor([0.0954])
# cov: tensor([[1.0053]])
# cov grad: tensor([[0.5001]])
# loc grad: tensor([0.9882])
# mu: tensor([-0.0042])
# cov: tensor([[1.0585]])
# cov grad: tensor([[0.3840]])
# loc grad: tensor([0.4735])
# mu: tensor([-0.0566])
# cov: tensor([[1.1034]])
# cov grad: tensor([[-0.4164]])
# loc grad: tensor([-0.3097])
# mu: tensor([-0.0215])
# cov: tensor([[1.0549]])
# cov grad: tensor([[-0.6106]])
# loc grad: tensor([-0.6220])
# mu: tensor([0.0415])
# cov: tensor([[0.9911]])
# cov grad: tensor([[0.7855]])
# loc grad: tensor([0.4862])
# mu: tensor([-0.0073])
# cov: tensor([[1.0747]])
# cov grad: tensor([[-0.2470]])
# loc grad: tensor([-0.7494])
# mu: tensor([0.0714])
# cov: tensor([[1.0469]])
# cov grad: tensor([[0.9352]])
# loc grad: tensor([0.8684])
# mu: tensor([-0.0217])
# cov: tensor([[1.1606]])
# cov grad: tensor([[0.2125]])
# loc grad: tensor([-0.4446])
# mu: tensor([0.0307])
# cov: tensor([[1.1899]])
# cov grad: tensor([[0.4191]])
# loc grad: tensor([-0.3264])
# mu: tensor([0.0732])
# cov: tensor([[1.2524]])
# cov grad: tensor([[0.4434]])
# loc grad: tensor([0.5865])
# mu: tensor([-0.0003])
# cov: tensor([[1.3260]])
# cov grad: tensor([[0.4333]])
# loc grad: tensor([-0.1237])
# mu: tensor([0.0171])
# cov: tensor([[1.4068]])
# cov grad: tensor([[-0.3032]])
# loc grad: tensor([-0.7893])
# mu: tensor([0.1229])
# cov: tensor([[1.3493]])
# cov grad: tensor([[-0.0609]])
# loc grad: tensor([-0.3319])
# mu: tensor([0.1663])
# cov: tensor([[1.3383]])
# cov grad: tensor([[0.2532]])
# loc grad: tensor([-0.0323])
# mu: tensor([0.1766])
# cov: tensor([[1.3852]])
# cov grad: tensor([[0.1168]])
# loc grad: tensor([0.1430])
# mu: tensor([0.1594])
# cov: tensor([[1.4080]])
# cov grad: tensor([[0.0539]])
# loc grad: tensor([-0.8750])
# mu: tensor([0.2847])
# cov: tensor([[1.4188]])
# cov grad: tensor([[0.1249]])
# loc grad: tensor([-0.6415])
# mu: tensor([0.3825])
# cov: tensor([[1.4444]])
# cov grad: tensor([[0.4397]])
# loc grad: tensor([-0.4503])
# mu: tensor([0.4779])
# cov: tensor([[1.5423]])
# cov grad: tensor([[0.2147]])
# loc grad: tensor([0.5637])
# mu: tensor([0.4044])
# cov: tensor([[1.5952]])
# cov grad: tensor([[-0.1355]])
# loc grad: tensor([0.2724])
# mu: tensor([0.3533])
# cov: tensor([[1.5614]])
# cov grad: tensor([[-0.0468]])
# loc grad: tensor([0.1113])
# mu: tensor([0.3335])
# cov: tensor([[1.5501]])
# cov grad: tensor([[0.2857]])
# loc grad: tensor([0.6504])
# mu: tensor([0.2435])
# cov: tensor([[1.6219]])
# cov grad: tensor([[-0.0591]])
# loc grad: tensor([-0.2643])
# mu: tensor([0.2836])
# cov: tensor([[1.6065]])
# cov grad: tensor([[0.0436]])
# loc grad: tensor([0.1596])
# mu: tensor([0.2598])
# cov: tensor([[1.6178]])
# cov grad: tensor([[-0.2021]])
# loc grad: tensor([-0.4266])
# mu: tensor([0.3184])
# cov: tensor([[1.5666]])
# cov grad: tensor([[0.2439]])
# loc grad: tensor([0.1585])
# mu: tensor([0.3052])
# cov: tensor([[1.6289]])
# cov grad: tensor([[0.0050]])
# loc grad: tensor([0.1763])
# mu: tensor([0.2767])
# cov: tensor([[1.6302]])
# cov grad: tensor([[-0.3432]])
# loc grad: tensor([-0.1647])
# mu: tensor([0.2875])
# cov: tensor([[1.5438]])
# cov grad: tensor([[-0.3818]])
# loc grad: tensor([0.0099])
# mu: tensor([0.2701])
# cov: tensor([[1.4579]])
# cov grad: tensor([[0.2351]])
# loc grad: tensor([0.1721])
# mu: tensor([0.2536])
# cov: tensor([[1.5096]])
# cov grad: tensor([[0.2762]])
# loc grad: tensor([0.3355])
# mu: tensor([0.2118])
# cov: tensor([[1.5753]])
# cov grad: tensor([[-0.0567]])
# loc grad: tensor([0.5185])
# mu: tensor([0.1290])
# cov: tensor([[1.5614]])
# cov grad: tensor([[-0.0899]])
# loc grad: tensor([0.5581])
# mu: tensor([0.0413])
# cov: tensor([[1.5397]])
# cov grad: tensor([[-0.1880]])
# loc grad: tensor([-0.4951])
# mu: tensor([0.1142])
# cov: tensor([[1.4964]])
# cov grad: tensor([[-0.3167]])
# loc grad: tensor([-0.2083])
# mu: tensor([0.1388])
# cov: tensor([[1.4287]])
# cov grad: tensor([[-0.3380]])
# loc grad: tensor([-0.3282])
# mu: tensor([0.1771])
# cov: tensor([[1.3629]])
# cov grad: tensor([[-0.4234]])
# loc grad: tensor([-0.6019])
# mu: tensor([0.2450])
# cov: tensor([[1.2886]])
# cov grad: tensor([[-0.4024]])
# loc grad: tensor([-0.8768])
# mu: tensor([0.3404])
# cov: tensor([[1.2250]])
# cov grad: tensor([[0.2629]])
# loc grad: tensor([1.0162])
# mu: tensor([0.2230])
# cov: tensor([[1.2658]])
# cov grad: tensor([[0.0489]])
# loc grad: tensor([-0.0457])
# mu: tensor([0.2303])
# cov: tensor([[1.2737]])
# cov grad: tensor([[-0.0705]])
# loc grad: tensor([-0.6866])
# mu: tensor([0.3149])
# cov: tensor([[1.2623]])
# cov grad: tensor([[-0.1489]])
# loc grad: tensor([0.0178])
# mu: tensor([0.3069])
# cov: tensor([[1.2391]])
# cov grad: tensor([[-0.0977]])
# loc grad: tensor([0.4142])
# mu: tensor([0.2525])
# cov: tensor([[1.2242]])
# cov grad: tensor([[-0.1805]])
# loc grad: tensor([0.1775])
# mu: tensor([0.2258])
# cov: tensor([[1.1978]])
# cov grad: tensor([[-0.0776]])
# loc grad: tensor([-0.0604])
# mu: tensor([0.2309])
# cov: tensor([[1.1867]])
# cov grad: tensor([[0.6595]])
# loc grad: tensor([-0.2752])
# mu: tensor([0.2859])
# cov: tensor([[1.2875]])
# cov grad: tensor([[-0.1052]])
# loc grad: tensor([-0.5499])
# mu: tensor([0.3519])
# cov: tensor([[1.2703]])
# cov grad: tensor([[-0.3541]])
# loc grad: tensor([-0.6896])
# mu: tensor([0.4206])
# cov: tensor([[1.2156]])
# cov grad: tensor([[-0.4954]])
# loc grad: tensor([0.0682])
# mu: tensor([0.3889])
# cov: tensor([[1.1466]])
# cov grad: tensor([[0.1818]])
# loc grad: tensor([0.0713])
# mu: tensor([0.3888])
# cov: tensor([[1.1710]])
# cov grad: tensor([[-0.1206]])
# loc grad: tensor([-0.6533])
# mu: tensor([0.4589])
# cov: tensor([[1.1547]])
# cov grad: tensor([[-0.0369]])
# loc grad: tensor([-0.2380])
# mu: tensor([0.4843])
# cov: tensor([[1.1498]])
# cov grad: tensor([[-0.2964]])
# loc grad: tensor([0.0473])
# mu: tensor([0.4631])
# cov: tensor([[1.1119]])
# cov grad: tensor([[0.3013]])
# loc grad: tensor([0.3429])
# mu: tensor([0.4397])
# cov: tensor([[1.1504]])
# cov grad: tensor([[0.7207]])
# loc grad: tensor([0.0521])
# mu: tensor([0.4729])
# cov: tensor([[1.2544]])
# cov grad: tensor([[0.1684]])
# loc grad: tensor([0.0649])
# mu: tensor([0.4748])
# cov: tensor([[1.2815]])
# cov grad: tensor([[0.1237]])
# loc grad: tensor([-0.2956])
# mu: tensor([0.5209])
# cov: tensor([[1.3022]])
# cov grad: tensor([[1.6287]])
# loc grad: tensor([0.9641])
# mu: tensor([0.5018])
# cov: tensor([[1.6527]])
# cov grad: tensor([[0.1426]])
# loc grad: tensor([0.1221])
# mu: tensor([0.4932])
# cov: tensor([[1.6926]])
# cov grad: tensor([[0.6452]])
# loc grad: tensor([0.3821])
# mu: tensor([0.4811])
# cov: tensor([[1.9001]])
# cov grad: tensor([[0.1137]])
# loc grad: tensor([0.0158])
# mu: tensor([0.4886])
# cov: tensor([[1.9420]])
# cov grad: tensor([[0.2129]])
# loc grad: tensor([0.1173])
# mu: tensor([0.4859])
# cov: tensor([[2.0258]])
# cov grad: tensor([[-0.6847]])
# loc grad: tensor([-0.7272])
# mu: tensor([0.5561])
# cov: tensor([[1.7790]])
# cov grad: tensor([[-0.1889]])
# loc grad: tensor([0.0176])
# mu: tensor([0.5350])
# cov: tensor([[1.7212]])
# cov grad: tensor([[-0.3713]])
# loc grad: tensor([0.6245])
# mu: tensor([0.4018])
# cov: tensor([[1.6178]])
# cov grad: tensor([[0.0272]])
# loc grad: tensor([0.5251])
# mu: tensor([0.3183])
# cov: tensor([[1.6250]])
# cov grad: tensor([[0.2896]])
# loc grad: tensor([-0.0455])
# mu: tensor([0.3418])
# cov: tensor([[1.7052]])
# cov grad: tensor([[-0.1549]])
# loc grad: tensor([-0.0916])
# mu: tensor([0.3482])
# cov: tensor([[1.6613]])
# cov grad: tensor([[-0.0643]])
# loc grad: tensor([0.2468])
# mu: tensor([0.3039])
# cov: tensor([[1.6437]])
# cov grad: tensor([[0.0873]])
# loc grad: tensor([0.1065])
# mu: tensor([0.2906])
# cov: tensor([[1.6677]])
# cov grad: tensor([[0.1038]])
# loc grad: tensor([0.3944])
# mu: tensor([0.2288])
# cov: tensor([[1.6971]])
# cov grad: tensor([[0.5234]])
# loc grad: tensor([-0.3556])
# mu: tensor([0.3173])
# cov: tensor([[1.8625]])
# cov grad: tensor([[-0.1469]])
# loc grad: tensor([0.4480])
# mu: tensor([0.2276])
# cov: tensor([[1.8129]])
# cov grad: tensor([[-0.0391]])
# loc grad: tensor([-0.2657])
# mu: tensor([0.2739])
# cov: tensor([[1.8001]])
# cov grad: tensor([[0.1253]])
# loc grad: tensor([0.0027])
# mu: tensor([0.2797])
# cov: tensor([[1.8417]])
# Iteration 1 | Log Likelihood: 0.002

# %%
censored.loc * emp_scale+ emp_loc
# Out:
# tensor([-0.1281])

# %%
(censored.censored_normal.loc_est * emp_scale + emp_loc).mean()
# Out:
# tensor(-0.1021, grad_fn=<MeanBackward0>)

# %%
(censored.censored_normal.cov_est * emp_scale.pow(2)).mean()
# Out:
# tensor(0.4740, grad_fn=<MeanBackward0>)

# %%
store = Store(args.out_dir + '/' + args.exp)

schema = { 
    'kl_div_emp': float, 
    'kl_div_censored': float,
    'kl_div_censored_avg': float,
    'var': int,
}

store.add_table(TABLE_NAME, schema)

for i in range(args.trials): 
    for var in range(1, args.var + 1):
        # create new dataset
        gt_loc, gt_scale = Tensor([0.0]), args.var * ch.ones(1, 1)
        gt_dist = MultivariateNormal(gt_loc, gt_scale)
        samples = gt_dist.sample([args.samples])

        # right truncate at 0
        phi = oracle.Right(Tensor([0.0]))
        indices = phi(samples).nonzero()[:,0]
        S = samples[indices]
        alpha = S.size(0) / samples.size(0)

        emp_dist = MultivariateNormal(S.mean(0), S.var(0) * ch.ones(1, 1))

        S_norm = (S - emp_dist.loc) / ch.sqrt(emp_dist.covariance_matrix) 
        phi_norm = oracle.Right((phi.right - emp_dist.loc) / ch.sqrt(emp_dist.covariance_matrix))


        censored = CensoredNormal(phi=phi_norm, 
                              alpha=alpha, 
                              iter_=1, 
                              bs=10, 
                              num_samples=100,
                              lr=1e-1)
        censored.fit(S_norm)


        loc_ = (censored.loc * censored.scale.inverse() * ch.sqrt(emp_dist.covariance_matrix)) + emp_dist.loc
        scale_ = censored.scale.inverse() * emp_dist.covariance_matrix

        censor_dist = MultivariateNormal(loc_, scale_)

        loc_avg_ = (censored.censored_normal.loc_est.mean() * censored.censored_normal.cov_est.mean(1)[None,...].inverse() * ch.sqrt(emp_dist.covariance_matrix)) + emp_dist.loc
        scale_avg_ = censored.censored_normal.cov_est.mean(1)[None,...].inverse() * emp_dist.covariance_matrix


        censor_dist_avg = MultivariateNormal(loc_avg_, scale_avg_)

        kl_censor = float(kl_divergence(gt_dist, censor_dist))
        kl_censor_avg = float(kl_divergence(gt_dist, censor_dist_avg))
        kl_emp = float(kl_divergence(gt_dist, emp_dist))


        store[TABLE_NAME].update_row({ 
            'kl_div_emp': kl_emp, 
            'kl_div_censored_avg': kl_censor_avg, 
            'kl_div_censored': kl_censor,
            'var': var,
        })
        store[TABLE_NAME].flush_row()
    
store.close()
# Out:
# Logging in: /Users/patroklos/Desktop/exp/censoredVaryingVar/aed999c2-9e70-4121-8e72-67f51fd615dc
# Iteration 1 | Log Likelihood: 0.025
# Iteration 1 | Log Likelihood: 0.109
# Iteration 1 | Log Likelihood: 0.058
# Iteration 1 | Log Likelihood: 0.057
# Iteration 1 | Log Likelihood: 0.283
# Iteration 1 | Log Likelihood: 0.102
# Iteration 1 | Log Likelihood: 0.112
# Iteration 1 | Log Likelihood: 0.185
# Iteration 1 | Log Likelihood: 0.091
# Iteration 1 | Log Likelihood: 0.062
# Iteration 1 | Log Likelihood: 0.183
# Iteration 1 | Log Likelihood: 0.075
# Iteration 1 | Log Likelihood: 0.112
# Iteration 1 | Log Likelihood: 0.213
# Iteration 1 | Log Likelihood: 0.042
# Iteration 1 | Log Likelihood: 0.008
# Iteration 1 | Log Likelihood: 0.374
# Iteration 1 | Log Likelihood: 0.14
# Iteration 1 | Log Likelihood: 0.027
# Iteration 1 | Log Likelihood: 0.332
# Iteration 1 | Log Likelihood: 0.23
# Iteration 1 | Log Likelihood: 0.252
# Iteration 1 | Log Likelihood: 0.023
# Iteration 1 | Log Likelihood: 0.048
# Iteration 1 | Log Likelihood: 0.078
# Iteration 1 | Log Likelihood: 0.228
# Iteration 1 | Log Likelihood: 0.28
# Iteration 1 | Log Likelihood: 0.05
# Iteration 1 | Log Likelihood: 0.168
# Iteration 1 | Log Likelihood: 0.014
# Iteration 1 | Log Likelihood: 0.081
# Iteration 1 | Log Likelihood: 0.027
# Iteration 1 | Log Likelihood: 0.005
# Iteration 1 | Log Likelihood: 0.3
# Iteration 1 | Log Likelihood: 0.33
# Iteration 1 | Log Likelihood: 0.202
# Iteration 1 | Log Likelihood: 0.042
# Iteration 1 | Log Likelihood: 0.114
# Iteration 1 | Log Likelihood: 0.16
# Iteration 1 | Log Likelihood: 0.126
# Iteration 1 | Log Likelihood: 0.116
# Iteration 1 | Log Likelihood: 0.277
# Iteration 1 | Log Likelihood: 0.166
# Iteration 1 | Log Likelihood: 0.083
# Iteration 1 | Log Likelihood: 0.027
# Iteration 1 | Log Likelihood: 0.232
# Iteration 1 | Log Likelihood: 0.21
# Iteration 1 | Log Likelihood: 0.148
# Iteration 1 | Log Likelihood: 0.182
# Iteration 1 | Log Likelihood: 0.07
# Iteration 1 | Log Likelihood: 0.035
# Iteration 1 | Log Likelihood: 0.252
# Iteration 1 | Log Likelihood: 0.011

# %%
reader = CollectionReader(args.out_dir + '/' + args.exp)
logs = reader.df(TABLE_NAME)
reader.close()
logs.head(10)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 89.88it/s]
#    kl_div_emp  kl_div_censored  kl_div_censored_avg  var  \
# 0    1.174708         0.460537             0.611963    1
# 1    1.075057         0.108959             0.276494    2
# 2    1.247214         0.025133             0.450703    3
# 3    1.577210         0.174982             0.704818    4
# 4    1.246332         0.446618             0.648063    5
# 5    1.201355         0.265025             0.628949    6
# 6    1.344470         0.270126             0.669156    7
# 7    1.645901         0.486886             0.894390    8
# 8    1.329585         0.380412             0.650820    9
# 9    1.260292         0.138383             0.454154   10
#
#                                  exp_id
# 0  aed999c2-9e70-4121-8e72-67f51fd615dc
# 1  aed999c2-9e70-4121-8e72-67f51fd615dc
# 2  aed999c2-9e70-4121-8e72-67f51fd615dc
# 3  aed999c2-9e70-4121-8e72-67f51fd615dc
# 4  aed999c2-9e70-4121-8e72-67f51fd615dc
# 5  aed999c2-9e70-4121-8e72-67f51fd615dc
# 6  aed999c2-9e70-4121-8e72-67f51fd615dc
# 7  aed999c2-9e70-4121-8e72-67f51fd615dc
# 8  aed999c2-9e70-4121-8e72-67f51fd615dc
# 9  aed999c2-9e70-4121-8e72-67f51fd615dc

# %%
print("kl emp div: {}".format(logs.kl_div_emp.mean()))
print("kl censor avg div: {}".format(logs.kl_div_censored_avg.mean()))
print("kl censor div: {}".format(logs.kl_div_censored.mean()))
# Out:
# kl emp div: 1.2693012553453444
# kl censor avg div: 0.6030760595202446
# kl censor div: 0.24440078929066658

# %%
sns.lineplot(data=logs, x='var', y='kl_div_emp', color='red')
sns.lineplot(data=logs, x='var', y='kl_div_censored', color='blue')
ax = sns.lineplot(data=logs, x='var', y='kl_div_censored_avg', color='yellow')
ax.set_title('Censored Normal Varying Distribution Variance')
ax.set_xlabel('Variance')
ax.set_ylabel('KL Divergence')
# Out:
# Text(0, 0.5, 'KL Divergence')

# %%
emp_dist = MultivariateNormal(ch.zeros(1), ch.ones(1, 1))

# %%
gt_dist = MultivariateNormal(ch.zeros(1) + .5, ch.ones(1, 1))

# %%
kl_divergence(emp_dist, gt_dist)
# Out:
# tensor(0.1250)

# %%
censored.scale
# Out:
# tensor([[0.5863]])
