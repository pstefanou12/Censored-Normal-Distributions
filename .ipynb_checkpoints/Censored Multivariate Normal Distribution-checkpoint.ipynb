# %%
import sys 
sys.path.append('/Users/patroklos/Desktop/delphi_')

import torch as ch
from torch import Tensor
from torch.distributions.multivariate_normal import MultivariateNormal
from torch.distributions.kl import kl_divergence
import seaborn as sns
import matplotlib.pyplot as plt
import IPython 

from delphi.distributions.multivariate_normal import CensoredMultivariateNormal
from delphi import oracle
from delphi.utils import constants as consts
from delphi.utils.helpers import setup_store_with_metadata, cov
from cox.utils import Parameters
from cox.store import Store
from cox.readers import CollectionReader

TABLE_NAME = 'logs'

# %%
args = Parameters({ 
    'samples': 1000, 
    'batch_size': 1, 
    'tol': 1e-1, 
    'lr': 1e-1, 
    'out_dir': '/Users/patroklos/Desktop/exp/multi_censor',
    'exp': 'multiCensoredVaryingVar', 
    'trials': 20,
    'var': 10,
    'd': 2,
})

# %% [markdown]
# Synthetic Data Experiment for 2 Dimensional Censored Gaussian Distributions

# %%
M = MultivariateNormal(ch.zeros(2), ch.eye(2))
samples = M.sample([args.samples])

plt.scatter(samples[:,0], samples[:,1])
plt.show()

# %% [markdown]
# Truncate the Dataset

# %%
phi = oracle.Right(Tensor([0, float('inf')]))
indices = phi(samples).nonzero(as_tuple=False).flatten()
S = samples[indices]
alpha = S.size(0) / samples.size(0)
print("alpha: {}".format(alpha))

plt.scatter(S[:,0], S[:,1])
plt.show()
# Out:
# alpha: 0.498

# %%
emp_loc = S.mean(0)
print("empirical mean: ", emp_loc)
emp_cov = cov(S)
print("empirical covariance: ", emp_cov)
# Out:
# empirical mean:  tensor([-0.7785,  0.0758])
# empirical covariance:  tensor([[ 0.3337, -0.0226],
#         [-0.0226,  0.9142]])

# %% [markdown]
# Run algorithm to Remove Bias from the Dataset

# %%
censored_multi = CensoredMultivariateNormal(phi=phi, 
                                            alpha=alpha,
                                            bs=1,
                                            iter_=5, 
                                            step_lr=1500, 
                                            step_lr_gamma=.95)
censored_multi.fit(S)
# Out:
# mu: tensor([-0.7592,  0.0550])
# cov: tensor([[ 0.3283, -0.0242],
#         [-0.0242,  0.8895]])
# mu: tensor([-0.7797,  0.2285])
# cov: tensor([[ 0.3306, -0.0355],
#         [-0.0355,  0.8787]])
# mu: tensor([-0.8588,  0.4227])
# cov: tensor([[ 0.3435, -0.0690],
#         [-0.0690,  0.9643]])
# mu: tensor([-0.8705,  0.2014])
# cov: tensor([[ 0.3472, -0.0379],
#         [-0.0379,  0.9510]])
# mu: tensor([-0.8270,  0.3678])
# cov: tensor([[ 0.3386, -0.0653],
#         [-0.0653,  0.8727]])
# mu: tensor([-0.7491,  0.2746])
# cov: tensor([[ 0.3257, -0.0506],
#         [-0.0506,  0.8559]])
# mu: tensor([-0.7932,  0.3050])
# cov: tensor([[ 0.3300, -0.0347],
#         [-0.0347,  0.7545]])
# mu: tensor([-0.7814,  0.3755])
# cov: tensor([[ 0.3275, -0.0433],
#         [-0.0433,  0.7439]])
# mu: tensor([-0.6966,  0.3533])
# cov: tensor([[ 0.3122, -0.0447],
#         [-0.0447,  0.7498]])
# mu: tensor([-0.6486,  0.0724])
# cov: tensor([[ 0.3035, -0.0022],
#         [-0.0022,  0.6659]])
# mu: tensor([-0.6562,  0.1766])
# cov: tensor([[ 0.3042, -0.0096],
#         [-0.0096,  0.7353]])
# mu: tensor([-0.6729,  0.0704])
# cov: tensor([[0.3076, 0.0052],
#         [0.0052, 0.7772]])
# mu: tensor([-0.7487, -0.3277])
# cov: tensor([[0.3258, 0.0835],
#         [0.0835, 1.0216]])
# mu: tensor([-0.7118, -0.2339])
# cov: tensor([[0.3195, 0.0777],
#         [0.0777, 1.0682]])
# mu: tensor([-0.6833, -0.3050])
# cov: tensor([[0.3174, 0.0901],
#         [0.0901, 1.0284]])
# mu: tensor([-0.6672, -0.1512])
# cov: tensor([[0.3149, 0.0729],
#         [0.0729, 0.9649]])
# mu: tensor([-0.7012,  0.0940])
# cov: tensor([[0.3190, 0.0484],
#         [0.0484, 1.0945]])
# mu: tensor([-0.6736,  0.2276])
# cov: tensor([[0.3146, 0.0410],
#         [0.0410, 1.1456]])
# mu: tensor([-0.8166,  0.0980])
# cov: tensor([[0.3484, 0.0493],
#         [0.0493, 1.0976]])
# mu: tensor([-0.7881,  0.2708])
# cov: tensor([[0.3425, 0.0191],
#         [0.0191, 0.9525]])
# mu: tensor([-0.7606,  0.2542])
# cov: tensor([[0.3393, 0.0133],
#         [0.0133, 0.9841]])
# mu: tensor([-0.7630, -0.1184])
# cov: tensor([[0.3406, 0.0517],
#         [0.0517, 0.9927]])
# mu: tensor([-0.7478, -0.0639])
# cov: tensor([[0.3387, 0.0502],
#         [0.0502, 1.0181]])
# mu: tensor([-0.7429, -0.1814])
# cov: tensor([[0.3377, 0.0652],
#         [0.0652, 1.1307]])
# mu: tensor([-0.7351, -0.0749])
# cov: tensor([[0.3372, 0.0631],
#         [0.0631, 1.1813]])
# mu: tensor([-0.7226,  0.0875])
# cov: tensor([[0.3350, 0.0515],
#         [0.0515, 1.2887]])
# mu: tensor([-0.6630,  0.3006])
# cov: tensor([[ 0.3177, -0.0152],
#         [-0.0152,  1.0359]])
# mu: tensor([-0.6583,  0.2969])
# cov: tensor([[ 0.3168, -0.0147],
#         [-0.0147,  1.0356]])
# mu: tensor([-0.6790,  0.0123])
# cov: tensor([[0.3193, 0.0061],
#         [0.0061, 1.1356]])
# mu: tensor([-0.7184, -0.2779])
# cov: tensor([[0.3276, 0.0482],
#         [0.0482, 1.0647]])
# mu: tensor([-0.7048, -0.0472])
# cov: tensor([[0.3254, 0.0205],
#         [0.0205, 1.1515]])
# mu: tensor([-0.7046, -0.0025])
# cov: tensor([[0.3254, 0.0196],
#         [0.0196, 1.0801]])
# mu: tensor([-0.6823, -0.0925])
# cov: tensor([[0.3202, 0.0331],
#         [0.0331, 1.0905]])
# mu: tensor([-0.7028, -0.3266])
# cov: tensor([[0.3224, 0.0527],
#         [0.0527, 1.2200]])
# mu: tensor([-0.7308, -0.2806])
# cov: tensor([[0.3296, 0.0318],
#         [0.0318, 1.2222]])
# mu: tensor([-0.7347, -0.2490])
# cov: tensor([[0.3305, 0.0281],
#         [0.0281, 1.2077]])
# mu: tensor([-0.7821, -0.2953])
# cov: tensor([[0.3400, 0.0306],
#         [0.0306, 1.1889]])
# mu: tensor([-0.7983, -0.2794])
# cov: tensor([[0.3428, 0.0280],
#         [0.0280, 1.1913]])
# mu: tensor([-0.7954, -0.3229])
# cov: tensor([[0.3423, 0.0316],
#         [0.0316, 1.1832]])
# mu: tensor([-0.7766, -0.5225])
# cov: tensor([[0.3399, 0.0478],
#         [0.0478, 1.1093]])
# mu: tensor([-0.8457, -0.6826])
# cov: tensor([[0.3520, 0.0732],
#         [0.0732, 1.1592]])
# mu: tensor([-0.7273, -0.3670])
# cov: tensor([[0.3323, 0.0165],
#         [0.0165, 1.0000]])
# mu: tensor([-0.7516, -0.3090])
# cov: tensor([[0.3364, 0.0079],
#         [0.0079, 1.0173]])
# mu: tensor([-0.9183, -0.7090])
# cov: tensor([[0.3711, 0.0785],
#         [0.0785, 1.0344]])
# mu: tensor([-0.8928, -0.7198])
# cov: tensor([[0.3687, 0.0798],
#         [0.0798, 1.0337]])
# mu: tensor([-0.8277, -0.4959])
# cov: tensor([[0.3596, 0.0515],
#         [0.0515, 0.9525]])
# mu: tensor([-0.9222,  0.0017])
# cov: tensor([[ 0.3863, -0.0014],
#         [-0.0014,  0.5457]])
# mu: tensor([-1.0554,  0.0118])
# cov: tensor([[ 0.4173, -0.0022],
#         [-0.0022,  0.5452]])
# mu: tensor([-0.9979,  0.3266])
# cov: tensor([[ 0.4037, -0.0353],
#         [-0.0353,  0.7201]])
# mu: tensor([-0.9605,  0.2502])
# cov: tensor([[ 0.3959, -0.0214],
#         [-0.0214,  0.6994]])
# mu: tensor([-0.9544,  0.2992])
# cov: tensor([[ 0.3954, -0.0247],
#         [-0.0247,  0.6804]])
# mu: tensor([-0.9296,  0.1732])
# cov: tensor([[ 0.3913, -0.0068],
#         [-0.0068,  0.6542]])
# mu: tensor([-0.8963,  0.2997])
# cov: tensor([[ 0.3858, -0.0159],
#         [-0.0159,  0.6753]])
# mu: tensor([-0.8674,  0.1869])
# cov: tensor([[0.3805, 0.0021],
#         [0.0021, 0.6370]])
# mu: tensor([-0.8195,  0.0447])
# cov: tensor([[0.3737, 0.0042],
#         [0.0042, 0.7975]])
# mu: tensor([-0.7812,  0.1632])
# cov: tensor([[ 0.3669, -0.0098],
#         [-0.0098,  0.7842]])
# mu: tensor([-0.7473,  0.2420])
# cov: tensor([[ 0.3590, -0.0250],
#         [-0.0250,  0.7577]])
# mu: tensor([-0.7236,  0.2685])
# cov: tensor([[ 0.3542, -0.0332],
#         [-0.0332,  0.7479]])
# mu: tensor([-0.7755,  0.2376])
# cov: tensor([[ 0.3661, -0.0266],
#         [-0.0266,  0.7515]])
# mu: tensor([-0.7748,  0.3101])
# cov: tensor([[ 0.3657, -0.0330],
#         [-0.0330,  0.7334]])
# mu: tensor([-0.8282,  0.4684])
# cov: tensor([[ 0.3720, -0.0493],
#         [-0.0493,  0.7735]])
# mu: tensor([-0.8287,  0.4872])
# cov: tensor([[ 0.3719, -0.0515],
#         [-0.0515,  0.7662]])
# mu: tensor([-0.8475,  0.3256])
# cov: tensor([[ 0.3784, -0.0235],
#         [-0.0235,  0.8167]])
# mu: tensor([-0.8615,  0.3755])
# cov: tensor([[ 0.3793, -0.0261],
#         [-0.0261,  0.8240]])
# mu: tensor([-0.8749,  0.2667])
# cov: tensor([[ 0.3833, -0.0094],
#         [-0.0094,  0.8389]])
# mu: tensor([-0.8004,  0.3319])
# cov: tensor([[ 0.3704, -0.0123],
#         [-0.0123,  0.8501]])
# mu: tensor([-0.8082,  0.2314])
# cov: tensor([[ 0.3722, -0.0030],
#         [-0.0030,  0.8315]])
# mu: tensor([-0.7590,  0.2771])
# cov: tensor([[ 0.3647, -0.0096],
#         [-0.0096,  0.8259]])
# mu: tensor([-0.7893,  0.6286])
# cov: tensor([[ 0.3670, -0.0328],
#         [-0.0328,  1.0110]])
# mu: tensor([-0.6975,  0.4468])
# cov: tensor([[0.3466, 0.0026],
#         [0.0026, 0.9761]])
# mu: tensor([-0.7303,  0.6148])
# cov: tensor([[ 0.3498, -0.0282],
#         [-0.0282,  0.8252]])
# mu: tensor([-0.7284,  0.4408])
# cov: tensor([[ 0.3515, -0.0088],
#         [-0.0088,  0.8225]])
# mu: tensor([-0.6967,  0.2641])
# cov: tensor([[0.3471, 0.0148],
#         [0.0148, 0.8496]])
# mu: tensor([-0.7491,  0.4290])
# cov: tensor([[ 0.3557, -0.0170],
#         [-0.0170,  0.9567]])
# mu: tensor([-0.7439,  0.5413])
# cov: tensor([[ 0.3535, -0.0275],
#         [-0.0275,  1.0163]])
# mu: tensor([-0.8427,  0.3739])
# cov: tensor([[0.3773, 0.0119],
#         [0.0119, 1.0815]])
# mu: tensor([-0.7037,  0.4692])
# cov: tensor([[ 0.3423, -0.0107],
#         [-0.0107,  1.0671]])
# mu: tensor([-0.6861,  0.4411])
# cov: tensor([[ 0.3405, -0.0191],
#         [-0.0191,  1.2881]])
# mu: tensor([-0.6467,  0.5206])
# cov: tensor([[ 0.3343, -0.0220],
#         [-0.0220,  1.3090]])
# mu: tensor([-0.6147,  0.2084])
# cov: tensor([[0.3305, 0.0056],
#         [0.0056, 1.4095]])
# mu: tensor([-0.5596,  0.1135])
# cov: tensor([[ 0.3210, -0.0030],
#         [-0.0030,  1.5690]])
# mu: tensor([-0.5423,  0.2934])
# cov: tensor([[ 0.3194, -0.0148],
#         [-0.0148,  1.4935]])
# mu: tensor([-0.5134,  0.4648])
# cov: tensor([[ 0.3139, -0.0221],
#         [-0.0221,  1.6155]])
# mu: tensor([-0.5238,  0.5793])
# cov: tensor([[ 0.3145, -0.0306],
#         [-0.0306,  1.1089]])
# mu: tensor([-0.5172,  0.6382])
# cov: tensor([[ 0.3142, -0.0332],
#         [-0.0332,  1.0912]])
# mu: tensor([-0.5793,  0.7960])
# cov: tensor([[ 0.3223, -0.0574],
#         [-0.0574,  0.8200]])
# mu: tensor([-0.5987,  0.6778])
# cov: tensor([[ 0.3273, -0.0510],
#         [-0.0510,  0.7772]])
# mu: tensor([-0.5757,  0.6964])
# cov: tensor([[ 0.3243, -0.0611],
#         [-0.0611,  0.7740]])
# mu: tensor([-0.4820,  0.4224])
# cov: tensor([[ 0.3112, -0.0312],
#         [-0.0312,  0.7355]])
# mu: tensor([-0.5296,  0.5382])
# cov: tensor([[ 0.3169, -0.0450],
#         [-0.0450,  0.7686]])
# mu: tensor([-0.6010,  0.6373])
# cov: tensor([[ 0.3294, -0.0574],
#         [-0.0574,  0.7734]])
# mu: tensor([-0.6073,  0.6809])
# cov: tensor([[ 0.3299, -0.0602],
#         [-0.0602,  0.7658]])
# mu: tensor([-0.6076,  0.6006])
# cov: tensor([[ 0.3310, -0.0545],
#         [-0.0545,  0.7219]])
# mu: tensor([-0.5729,  0.6248])
# cov: tensor([[ 0.3260, -0.0549],
#         [-0.0549,  0.7247]])
# mu: tensor([-0.5113,  0.4459])
# cov: tensor([[ 0.3189, -0.0325],
#         [-0.0325,  0.6549]])
# mu: tensor([-0.5057,  0.3336])
# cov: tensor([[ 0.3187, -0.0272],
#         [-0.0272,  0.6509]])
# mu: tensor([-0.4911,  0.3807])
# cov: tensor([[ 0.3173, -0.0281],
#         [-0.0281,  0.6600]])
# mu: tensor([-0.5033,  0.3339])
# cov: tensor([[ 0.3186, -0.0219],
#         [-0.0219,  0.6874]])
# mu: tensor([-0.5180,  0.2714])
# cov: tensor([[ 0.3209, -0.0203],
#         [-0.0203,  0.6603]])
# mu: tensor([-0.4783,  0.2639])
# cov: tensor([[ 0.3111, -0.0264],
#         [-0.0264,  0.6788]])
# mu: tensor([-0.4855,  0.2054])
# cov: tensor([[ 0.3133, -0.0192],
#         [-0.0192,  0.6660]])
# mu: tensor([-0.4940,  0.1523])
# cov: tensor([[ 0.3153, -0.0146],
#         [-0.0146,  0.6448]])
# mu: tensor([-0.4698,  0.0773])
# cov: tensor([[ 0.3100, -0.0011],
#         [-0.0011,  0.6150]])
# mu: tensor([-0.4648,  0.1723])
# cov: tensor([[ 0.3090, -0.0082],
#         [-0.0082,  0.6506]])
# mu: tensor([-0.4822,  0.2321])
# cov: tensor([[ 0.3105, -0.0163],
#         [-0.0163,  0.6853]])
# mu: tensor([-0.4840,  0.3584])
# cov: tensor([[ 0.3104, -0.0237],
#         [-0.0237,  0.6918]])
# mu: tensor([-0.4753,  0.2060])
# cov: tensor([[ 0.3099, -0.0078],
#         [-0.0078,  0.7409]])
# mu: tensor([-0.4842,  0.0329])
# cov: tensor([[0.3113, 0.0059],
#         [0.0059, 0.7619]])
# mu: tensor([-0.4661,  0.0245])
# cov: tensor([[0.3083, 0.0057],
#         [0.0057, 0.7634]])
# mu: tensor([-0.5023,  0.0565])
# cov: tensor([[ 0.3154, -0.0021],
#         [-0.0021,  0.7713]])
# mu: tensor([-0.4654, -0.0660])
# cov: tensor([[0.3086, 0.0189],
#         [0.0189, 0.7071]])
# mu: tensor([-0.4739, -0.0381])
# cov: tensor([[0.3101, 0.0165],
#         [0.0165, 0.7031]])
# mu: tensor([-0.4382, -0.0463])
# cov: tensor([[0.3031, 0.0133],
#         [0.0133, 0.7082]])
# mu: tensor([-0.4572, -0.0937])
# cov: tensor([[0.3053, 0.0117],
#         [0.0117, 0.6747]])
# mu: tensor([-0.4544, -0.0666])
# cov: tensor([[0.3050, 0.0101],
#         [0.0101, 0.6790]])
# mu: tensor([-0.4977, -0.0879])
# cov: tensor([[0.3124, 0.0127],
#         [0.0127, 0.6797]])
# /opt/anaconda3/lib/python3.7/site-packages/torch/autograd/__init__.py:156: UserWarning: grad and param do not obey the gradient layout contract. This is not an error, but may impair performance.
# grad.sizes() = [2, 2], strides() = [1, 2]
# param.sizes() = [2, 2], strides() = [2, 1] (Triggered internally at  ../torch/csrc/autograd/functions/accumulate_grad.h:185.)
#   allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
# mu: tensor([-0.5274, -0.0686])
# cov: tensor([[0.3167, 0.0139],
#         [0.0139, 0.6738]])
# mu: tensor([-0.5147,  0.0652])
# cov: tensor([[0.3148, 0.0016],
#         [0.0016, 0.6445]])
# mu: tensor([-0.4879,  0.0851])
# cov: tensor([[0.3112, 0.0042],
#         [0.0042, 0.6549]])
# mu: tensor([-0.5153,  0.2779])
# cov: tensor([[ 0.3143, -0.0153],
#         [-0.0153,  0.7736]])
# mu: tensor([-0.5282,  0.2877])
# cov: tensor([[ 0.3170, -0.0161],
#         [-0.0161,  0.7724]])
# mu: tensor([-0.5044,  0.1169])
# cov: tensor([[3.1412e-01, 6.7069e-04],
#         [6.7075e-04, 6.8688e-01]])
# mu: tensor([-0.6024,  0.1442])
# cov: tensor([[ 0.3377, -0.0050],
#         [-0.0050,  0.6881]])
# mu: tensor([-0.6250,  0.1067])
# cov: tensor([[0.3434, 0.0018],
#         [0.0018, 0.6929]])
# mu: tensor([-0.6151,  0.0294])
# cov: tensor([[0.3419, 0.0096],
#         [0.0096, 0.6899]])
# mu: tensor([-0.6241,  0.0849])
# cov: tensor([[0.3427, 0.0075],
#         [0.0075, 0.6726]])
# mu: tensor([-0.6547,  0.1761])
# cov: tensor([[ 0.3465, -0.0017],
#         [-0.0017,  0.6930]])
# mu: tensor([-0.6284, -0.0616])
# cov: tensor([[0.3424, 0.0237],
#         [0.0237, 0.6666]])
# mu: tensor([-0.6057,  0.0330])
# cov: tensor([[0.3387, 0.0190],
#         [0.0190, 0.7165]])
# mu: tensor([-0.5770, -0.0409])
# cov: tensor([[0.3350, 0.0285],
#         [0.0285, 0.6923]])
# mu: tensor([-0.5676,  0.0264])
# cov: tensor([[0.3329, 0.0167],
#         [0.0167, 0.6326]])
# mu: tensor([-0.4620, -0.0460])
# cov: tensor([[0.3082, 0.0297],
#         [0.0297, 0.6274]])
# mu: tensor([-0.4812, -0.0977])
# cov: tensor([[0.3097, 0.0297],
#         [0.0297, 0.6146]])
# mu: tensor([-0.5088, -0.0188])
# cov: tensor([[0.3167, 0.0158],
#         [0.0158, 0.6284]])
# mu: tensor([-0.5281, -0.0164])
# cov: tensor([[0.3184, 0.0160],
#         [0.0160, 0.6283]])
# mu: tensor([-0.5542,  0.0198])
# cov: tensor([[0.3233, 0.0205],
#         [0.0205, 0.5720]])
# mu: tensor([-0.6075, -0.0858])
# cov: tensor([[0.3312, 0.0331],
#         [0.0331, 0.5906]])
# mu: tensor([-0.6179,  0.0775])
# cov: tensor([[0.3323, 0.0223],
#         [0.0223, 0.5990]])
# mu: tensor([-0.6450,  0.4420])
# cov: tensor([[ 0.3345, -0.0240],
#         [-0.0240,  0.7378]])
# mu: tensor([-0.6519,  0.2800])
# cov: tensor([[0.3395, 0.0045],
#         [0.0045, 0.7529]])
# mu: tensor([-0.6363,  0.2397])
# cov: tensor([[0.3373, 0.0063],
#         [0.0063, 0.7796]])
# mu: tensor([-0.8759,  0.7483])
# cov: tensor([[ 0.3887, -0.0944],
#         [-0.0944,  0.9635]])
# mu: tensor([-0.8055,  0.5338])
# cov: tensor([[ 0.3779, -0.0612],
#         [-0.0612,  0.8620]])
# mu: tensor([-0.8183,  0.5784])
# cov: tensor([[ 0.3793, -0.0629],
#         [-0.0629,  0.8129]])
# mu: tensor([-0.8567,  0.5402])
# cov: tensor([[ 0.3886, -0.0569],
#         [-0.0569,  0.8140]])
# mu: tensor([-0.8095,  0.6270])
# cov: tensor([[ 0.3795, -0.0687],
#         [-0.0687,  0.8030]])
# mu: tensor([-0.7638,  0.4274])
# cov: tensor([[ 0.3736, -0.0473],
#         [-0.0473,  0.7487]])
# mu: tensor([-0.7173,  0.3533])
# cov: tensor([[ 0.3674, -0.0364],
#         [-0.0364,  0.7297]])
# mu: tensor([-0.6938,  0.2227])
# cov: tensor([[ 0.3652, -0.0293],
#         [-0.0293,  0.7409]])
# mu: tensor([-0.6845,  0.2338])
# cov: tensor([[ 0.3635, -0.0304],
#         [-0.0304,  0.7416]])
# mu: tensor([-0.6346,  0.2626])
# cov: tensor([[ 0.3544, -0.0325],
#         [-0.0325,  0.7433]])
# mu: tensor([-0.7241,  0.1688])
# cov: tensor([[ 0.3759, -0.0029],
#         [-0.0029,  0.7776]])
# mu: tensor([-0.7071,  0.2537])
# cov: tensor([[ 0.3725, -0.0083],
#         [-0.0083,  0.8193]])
# mu: tensor([-0.6363,  0.0067])
# cov: tensor([[0.3594, 0.0259],
#         [0.0259, 0.7681]])
# mu: tensor([-0.6317,  0.0317])
# cov: tensor([[0.3585, 0.0247],
#         [0.0247, 0.7914]])
# mu: tensor([-0.6276, -0.0775])
# cov: tensor([[0.3580, 0.0334],
#         [0.0334, 0.7009]])
# mu: tensor([-0.7547,  0.0424])
# cov: tensor([[0.3934, 0.0143],
#         [0.0143, 0.6854]])
# mu: tensor([-0.8076,  0.3293])
# cov: tensor([[ 0.4037, -0.0321],
#         [-0.0321,  0.7466]])
# mu: tensor([-0.8465,  0.3089])
# cov: tensor([[ 0.4100, -0.0336],
#         [-0.0336,  0.7397]])
# mu: tensor([-0.8791,  0.4000])
# cov: tensor([[ 0.4157, -0.0443],
#         [-0.0443,  0.7245]])
# mu: tensor([-0.8675,  0.3029])
# cov: tensor([[ 0.4143, -0.0328],
#         [-0.0328,  0.7500]])
# mu: tensor([-0.8631,  0.3129])
# cov: tensor([[ 0.4134, -0.0336],
#         [-0.0336,  0.7527]])
# mu: tensor([-0.8079,  0.2304])
# cov: tensor([[ 0.4061, -0.0253],
#         [-0.0253,  0.7452]])
# mu: tensor([-0.7630,  0.1329])
# cov: tensor([[ 0.3952, -0.0053],
#         [-0.0053,  0.7173]])
# mu: tensor([-0.8013,  0.3396])
# cov: tensor([[ 0.4008, -0.0268],
#         [-0.0268,  0.7002]])
# mu: tensor([-0.7611,  0.1626])
# cov: tensor([[ 0.3970, -0.0166],
#         [-0.0166,  0.6969]])
# mu: tensor([-0.8446, -0.1066])
# cov: tensor([[0.4138, 0.0048],
#         [0.0048, 0.5551]])
# mu: tensor([-0.8841, -0.0741])
# cov: tensor([[ 0.4194, -0.0021],
#         [-0.0021,  0.5618]])
# mu: tensor([-0.8708,  0.0408])
# cov: tensor([[ 0.4179, -0.0098],
#         [-0.0098,  0.5635]])
# mu: tensor([-1.0074, -0.0953])
# cov: tensor([[0.4525, 0.0110],
#         [0.0110, 0.5476]])
# mu: tensor([-1.0543, -0.2718])
# cov: tensor([[0.4623, 0.0411],
#         [0.0411, 0.5803]])
# mu: tensor([-1.1096, -0.2735])
# cov: tensor([[0.4720, 0.0455],
#         [0.0455, 0.5776]])
# mu: tensor([-1.0769, -0.3446])
# cov: tensor([[0.4636, 0.0560],
#         [0.0560, 0.5819]])
# mu: tensor([-1.1286, -0.3997])
# cov: tensor([[0.4758, 0.0648],
#         [0.0648, 0.5691]])
# mu: tensor([-1.1893, -0.4081])
# cov: tensor([[0.4889, 0.0685],
#         [0.0685, 0.5691]])
# mu: tensor([-1.1743, -0.3741])
# cov: tensor([[0.4858, 0.0623],
#         [0.0623, 0.5656]])
# mu: tensor([-1.0851, -0.2791])
# cov: tensor([[0.4679, 0.0543],
#         [0.0543, 0.6041]])
# mu: tensor([-1.0781, -0.2606])
# cov: tensor([[0.4666, 0.0522],
#         [0.0522, 0.6074]])
# mu: tensor([-0.9236, -0.1759])
# cov: tensor([[0.4342, 0.0441],
#         [0.0441, 0.6166]])
# mu: tensor([-0.8372,  0.0062])
# cov: tensor([[0.4146, 0.0200],
#         [0.0200, 0.6454]])
# mu: tensor([-0.7856, -0.0066])
# cov: tensor([[0.4034, 0.0292],
#         [0.0292, 0.6492]])
# mu: tensor([-0.9281,  0.0675])
# cov: tensor([[0.4380, 0.0177],
#         [0.0177, 0.6479]])
# mu: tensor([-0.9302,  0.0204])
# cov: tensor([[0.4381, 0.0190],
#         [0.0190, 0.6655]])
# mu: tensor([-1.0083,  0.0327])
# cov: tensor([[0.4579, 0.0185],
#         [0.0185, 0.6638]])
# mu: tensor([-0.9349,  0.1153])
# cov: tensor([[0.4428, 0.0094],
#         [0.0094, 0.6697]])
# mu: tensor([-0.8669,  0.2997])
# cov: tensor([[ 0.4302, -0.0128],
#         [-0.0128,  0.6490]])
# mu: tensor([-0.7599,  0.3530])
# cov: tensor([[ 0.4047, -0.0175],
#         [-0.0175,  0.6548]])
# mu: tensor([-0.7662,  0.3237])
# cov: tensor([[ 0.4067, -0.0135],
#         [-0.0135,  0.6504]])
# mu: tensor([-0.7548,  0.2019])
# cov: tensor([[ 0.4056, -0.0039],
#         [-0.0039,  0.6375]])
# mu: tensor([-0.7857,  0.0886])
# cov: tensor([[0.4098, 0.0011],
#         [0.0011, 0.6108]])
# mu: tensor([-0.7889,  0.1203])
# cov: tensor([[ 0.4103, -0.0041],
#         [-0.0041,  0.6272]])
# mu: tensor([-0.7869,  0.0851])
# cov: tensor([[0.4101, 0.0017],
#         [0.0017, 0.6485]])
# mu: tensor([-0.8488, -0.0513])
# cov: tensor([[0.4275, 0.0262],
#         [0.0262, 0.6405]])
# mu: tensor([-0.8604,  0.0691])
# cov: tensor([[0.4289, 0.0153],
#         [0.0153, 0.7014]])
# mu: tensor([-0.8385,  0.0093])
# cov: tensor([[0.4236, 0.0261],
#         [0.0261, 0.6945]])
# mu: tensor([-1.0478,  0.0981])
# cov: tensor([[ 0.4809, -0.0081],
#         [-0.0081,  0.7054]])
# mu: tensor([-1.0279,  0.0027])
# cov: tensor([[0.4762, 0.0075],
#         [0.0075, 0.7362]])
# mu: tensor([-1.0246, -0.1209])
# cov: tensor([[0.4759, 0.0150],
#         [0.0150, 0.6443]])
# mu: tensor([-0.9309, -0.0718])
# cov: tensor([[0.4551, 0.0035],
#         [0.0035, 0.6380]])
# mu: tensor([-0.8913,  0.1168])
# cov: tensor([[ 0.4449, -0.0314],
#         [-0.0314,  0.6038]])
# mu: tensor([-0.8178,  0.0608])
# cov: tensor([[ 0.4305, -0.0190],
#         [-0.0190,  0.5935]])
# mu: tensor([-0.6935,  0.0479])
# cov: tensor([[ 0.3982, -0.0224],
#         [-0.0224,  0.5983]])
# mu: tensor([-0.6954,  0.1517])
# cov: tensor([[ 0.3983, -0.0256],
#         [-0.0256,  0.5850]])
# mu: tensor([-0.6991,  0.0483])
# cov: tensor([[ 0.3991, -0.0171],
#         [-0.0171,  0.5534]])
# mu: tensor([-0.6694,  0.0677])
# cov: tensor([[ 0.3942, -0.0221],
#         [-0.0221,  0.5495]])
# mu: tensor([-0.7265,  0.1386])
# cov: tensor([[ 0.4049, -0.0249],
#         [-0.0249,  0.5246]])
# mu: tensor([-0.7431,  0.0911])
# cov: tensor([[ 0.4077, -0.0204],
#         [-0.0204,  0.5247]])
# mu: tensor([-0.6608, -0.0318])
# cov: tensor([[ 0.3873, -0.0066],
#         [-0.0066,  0.5594]])
# mu: tensor([-0.7798, -0.0875])
# cov: tensor([[0.4166, 0.0041],
#         [0.0041, 0.5622]])
# mu: tensor([-0.7650, -0.0741])
# cov: tensor([[0.4151, 0.0051],
#         [0.0051, 0.5674]])
# mu: tensor([-0.7855,  0.1908])
# cov: tensor([[ 0.4198, -0.0382],
#         [-0.0382,  0.6702]])
# mu: tensor([-0.7856,  0.2681])
# cov: tensor([[ 0.4194, -0.0475],
#         [-0.0475,  0.6530]])
# mu: tensor([-0.8623,  0.2638])
# cov: tensor([[ 0.4358, -0.0460],
#         [-0.0460,  0.6531]])
# mu: tensor([-0.8694,  0.2553])
# cov: tensor([[ 0.4369, -0.0457],
#         [-0.0457,  0.6515]])
# mu: tensor([-0.7837,  0.2460])
# cov: tensor([[ 0.4182, -0.0391],
#         [-0.0391,  0.6524]])
# mu: tensor([-0.8521,  0.3311])
# cov: tensor([[ 0.4303, -0.0459],
#         [-0.0459,  0.6390]])
# mu: tensor([-0.8278,  0.4967])
# cov: tensor([[ 0.4245, -0.0574],
#         [-0.0574,  0.7085]])
# mu: tensor([-0.7955,  0.4448])
# cov: tensor([[ 0.4215, -0.0530],
#         [-0.0530,  0.7023]])
# mu: tensor([-0.8231,  0.4517])
# cov: tensor([[ 0.4286, -0.0540],
#         [-0.0540,  0.7020]])
# mu: tensor([-0.7102,  0.1713])
# cov: tensor([[ 0.4063, -0.0164],
#         [-0.0164,  0.7370]])
# mu: tensor([-0.7160,  0.1330])
# cov: tensor([[ 0.4069, -0.0136],
#         [-0.0136,  0.7475]])
# mu: tensor([-0.7269,  0.0752])
# cov: tensor([[ 0.4077, -0.0104],
#         [-0.0104,  0.7587]])
# mu: tensor([-0.7096,  0.0849])
# cov: tensor([[ 0.4045, -0.0106],
#         [-0.0106,  0.7603]])
# mu: tensor([-0.5809,  0.0523])
# cov: tensor([[ 0.3706, -0.0046],
#         [-0.0046,  0.7599]])
# mu: tensor([-0.5224, -0.0203])
# cov: tensor([[ 0.3546, -0.0031],
#         [-0.0031,  0.8234]])
# mu: tensor([-0.6735, -0.3996])
# cov: tensor([[0.3996, 0.0797],
#         [0.0797, 0.7690]])
# mu: tensor([-0.6271, -0.2254])
# cov: tensor([[0.3896, 0.0502],
#         [0.0502, 0.7374]])
# mu: tensor([-0.6135, -0.1966])
# cov: tensor([[0.3890, 0.0501],
#         [0.0501, 0.7403]])
# mu: tensor([-0.6440, -0.2601])
# cov: tensor([[0.3954, 0.0609],
#         [0.0609, 0.7553]])
# mu: tensor([-0.6468, -0.0911])
# cov: tensor([[0.3972, 0.0285],
#         [0.0285, 0.8824]])
# mu: tensor([-0.6704, -0.0378])
# cov: tensor([[0.4001, 0.0254],
#         [0.0254, 0.8797]])
# mu: tensor([-0.6751, -0.1125])
# cov: tensor([[0.4008, 0.0322],
#         [0.0322, 0.8577]])
# mu: tensor([-0.6740,  0.0607])
# cov: tensor([[0.4006, 0.0129],
#         [0.0129, 0.8166]])
# mu: tensor([-0.7046, -0.0609])
# cov: tensor([[0.4083, 0.0344],
#         [0.0344, 0.8483]])
# mu: tensor([-0.6681, -0.1214])
# cov: tensor([[0.4031, 0.0378],
#         [0.0378, 0.8551]])
# mu: tensor([-0.6663, -0.1502])
# cov: tensor([[0.4032, 0.0382],
#         [0.0382, 0.8351]])
# mu: tensor([-0.8017,  0.0543])
# cov: tensor([[0.4422, 0.0129],
#         [0.0129, 0.7365]])
# mu: tensor([-0.8094, -0.0592])
# cov: tensor([[0.4436, 0.0262],
#         [0.0262, 0.7902]])
# mu: tensor([-0.8623,  0.1126])
# cov: tensor([[ 4.5430e-01, -5.1176e-04],
#         [-5.1175e-04,  8.3854e-01]])
# mu: tensor([-0.8488,  0.1315])
# cov: tensor([[ 0.4526, -0.0029],
#         [-0.0029,  0.8352]])
# mu: tensor([-0.8767,  0.0746])
# cov: tensor([[4.5941e-01, 6.0280e-04],
#         [6.0281e-04, 7.9697e-01]])
# mu: tensor([-0.8800,  0.0327])
# cov: tensor([[0.4597, 0.0027],
#         [0.0027, 0.8010]])
# mu: tensor([-0.8504, -0.0682])
# cov: tensor([[0.4525, 0.0196],
#         [0.0196, 0.7913]])
# mu: tensor([-0.8228, -0.0263])
# cov: tensor([[0.4477, 0.0132],
#         [0.0132, 0.7829]])
# mu: tensor([-0.7168, -0.2042])
# cov: tensor([[0.4186, 0.0450],
#         [0.0450, 0.7790]])
# mu: tensor([-0.6908, -0.2182])
# cov: tensor([[0.4146, 0.0419],
#         [0.0419, 0.7883]])
# mu: tensor([-0.6371, -0.1076])
# cov: tensor([[0.4041, 0.0185],
#         [0.0185, 0.7367]])
# mu: tensor([-0.5859, -0.1183])
# cov: tensor([[0.3929, 0.0067],
#         [0.0067, 0.7621]])
# mu: tensor([-0.5420, -0.2910])
# cov: tensor([[0.3859, 0.0120],
#         [0.0120, 0.8407]])
# mu: tensor([-0.5206, -0.1360])
# cov: tensor([[ 0.3817, -0.0170],
#         [-0.0170,  0.8145]])
# mu: tensor([-0.5107, -0.0544])
# cov: tensor([[ 0.3797, -0.0289],
#         [-0.0289,  0.8224]])
# mu: tensor([-0.4636, -0.1219])
# cov: tensor([[ 0.3736, -0.0363],
#         [-0.0363,  0.8704]])
# mu: tensor([-0.4818, -0.3783])
# cov: tensor([[ 0.3753, -0.0178],
#         [-0.0178,  0.9235]])
# mu: tensor([-0.5244, -0.2867])
# cov: tensor([[ 0.3845, -0.0389],
#         [-0.0389,  0.9714]])
# mu: tensor([-0.5545, -0.2766])
# cov: tensor([[ 0.3913, -0.0402],
#         [-0.0402,  0.9714]])
# mu: tensor([-0.4290, -0.1791])
# cov: tensor([[ 0.3496, -0.0469],
#         [-0.0469,  1.0787]])
# mu: tensor([-0.4385, -0.0526])
# cov: tensor([[ 0.3501, -0.0465],
#         [-0.0465,  0.9796]])
# mu: tensor([-0.4512,  0.0272])
# cov: tensor([[ 0.3524, -0.0583],
#         [-0.0583,  1.0348]])
# mu: tensor([-0.3969,  0.0839])
# cov: tensor([[ 0.3386, -0.0493],
#         [-0.0493,  1.1142]])
# mu: tensor([-0.3993,  0.4106])
# cov: tensor([[ 0.3382, -0.0835],
#         [-0.0835,  1.2499]])
# mu: tensor([-0.4031,  0.4959])
# cov: tensor([[ 0.3382, -0.0815],
#         [-0.0815,  1.1265]])
# mu: tensor([-0.3489,  0.4081])
# cov: tensor([[ 0.3240, -0.0522],
#         [-0.0522,  1.0736]])
# mu: tensor([-0.4144,  0.6397])
# cov: tensor([[ 0.3361, -0.0818],
#         [-0.0818,  1.0509]])
# mu: tensor([-0.5012,  0.9356])
# cov: tensor([[ 0.3505, -0.1376],
#         [-0.1376,  1.2559]])
# mu: tensor([-0.6194,  0.5071])
# cov: tensor([[ 0.4019, -0.0748],
#         [-0.0748,  1.0992]])
# mu: tensor([-0.6017,  0.5574])
# cov: tensor([[ 0.3999, -0.0806],
#         [-0.0806,  1.0821]])
# mu: tensor([-0.6130,  0.4648])
# cov: tensor([[ 0.4042, -0.0622],
#         [-0.0622,  1.1300]])
# mu: tensor([-0.5625,  0.4368])
# cov: tensor([[ 0.3966, -0.0600],
#         [-0.0600,  1.1303]])
# mu: tensor([-0.5240,  0.4279])
# cov: tensor([[ 0.3898, -0.0644],
#         [-0.0644,  1.1372]])
# mu: tensor([-0.7882,  1.1818])
# cov: tensor([[ 0.4545, -0.2745],
#         [-0.2745,  1.7674]])
# mu: tensor([-0.6978,  0.8294])
# cov: tensor([[ 0.4391, -0.2156],
#         [-0.2156,  1.5418]])
# mu: tensor([-0.6774,  0.6019])
# cov: tensor([[ 0.4364, -0.1834],
#         [-0.1834,  1.5386]])
# mu: tensor([-0.6638,  0.7607])
# cov: tensor([[ 0.4329, -0.2045],
#         [-0.2045,  1.4723]])
# mu: tensor([-0.5106,  0.1149])
# cov: tensor([[ 0.3958, -0.0642],
#         [-0.0642,  0.9760]])
# mu: tensor([-0.5016,  0.0600])
# cov: tensor([[ 0.3942, -0.0569],
#         [-0.0569,  0.9472]])
# mu: tensor([-0.5134,  0.1547])
# cov: tensor([[ 0.3954, -0.0580],
#         [-0.0580,  0.8669]])
# mu: tensor([-0.5233,  0.2792])
# cov: tensor([[ 0.3964, -0.0644],
#         [-0.0644,  0.8018]])
# mu: tensor([-0.4775,  0.4621])
# cov: tensor([[ 0.3793, -0.0916],
#         [-0.0916,  0.8514]])
# mu: tensor([-0.4700,  0.3531])
# cov: tensor([[ 0.3786, -0.0824],
#         [-0.0824,  0.8252]])
# mu: tensor([-0.4969,  0.1267])
# cov: tensor([[ 0.3856, -0.0632],
#         [-0.0632,  0.6868]])
# mu: tensor([-0.4905,  0.0011])
# cov: tensor([[ 0.3856, -0.0642],
#         [-0.0642,  0.7449]])
# mu: tensor([-0.4982,  0.0742])
# cov: tensor([[ 0.3864, -0.0670],
#         [-0.0670,  0.7204]])
# mu: tensor([-0.4855,  0.0788])
# cov: tensor([[ 0.3852, -0.0657],
#         [-0.0657,  0.7222]])
# mu: tensor([-0.5226,  0.1437])
# cov: tensor([[ 0.3914, -0.0661],
#         [-0.0661,  0.6920]])
# mu: tensor([-0.5805,  0.1101])
# cov: tensor([[ 0.4106, -0.0600],
#         [-0.0600,  0.6898]])
# mu: tensor([-0.5884,  0.1320])
# cov: tensor([[ 0.4127, -0.0649],
#         [-0.0649,  0.6999]])
# mu: tensor([-0.6163, -0.1252])
# cov: tensor([[ 0.4197, -0.0177],
#         [-0.0177,  0.6951]])
# mu: tensor([-0.5511, -0.0924])
# cov: tensor([[ 0.4047, -0.0228],
#         [-0.0228,  0.6942]])
# mu: tensor([-0.4810, -0.0278])
# cov: tensor([[ 0.3861, -0.0455],
#         [-0.0455,  0.6709]])
# mu: tensor([-0.5090,  0.1641])
# cov: tensor([[ 0.3903, -0.0652],
#         [-0.0652,  0.7356]])
# mu: tensor([-0.5682,  0.2673])
# cov: tensor([[ 0.4023, -0.0878],
#         [-0.0878,  0.7776]])
# mu: tensor([-0.5580,  0.3107])
# cov: tensor([[ 0.4014, -0.0906],
#         [-0.0906,  0.7711]])
# mu: tensor([-0.5803,  0.2609])
# cov: tensor([[ 0.4051, -0.0781],
#         [-0.0781,  0.8064]])
# mu: tensor([-0.6185,  0.3094])
# cov: tensor([[ 0.4123, -0.0870],
#         [-0.0870,  0.8172]])
# mu: tensor([-0.6648,  0.3625])
# cov: tensor([[ 0.4221, -0.0908],
#         [-0.0908,  0.8025]])
# mu: tensor([-0.7179,  0.1737])
# cov: tensor([[ 0.4339, -0.0714],
#         [-0.0714,  0.7691]])
# mu: tensor([-0.7477,  0.1924])
# cov: tensor([[ 0.4400, -0.0799],
#         [-0.0799,  0.7727]])
# mu: tensor([-0.7794,  0.1108])
# cov: tensor([[ 0.4487, -0.0628],
#         [-0.0628,  0.7949]])
# mu: tensor([-0.8577,  0.0080])
# cov: tensor([[ 0.4697, -0.0497],
#         [-0.0497,  0.7617]])
# mu: tensor([-0.8592,  0.0372])
# cov: tensor([[ 0.4698, -0.0513],
#         [-0.0513,  0.7622]])
# mu: tensor([-0.7921, -0.0839])
# cov: tensor([[ 0.4519, -0.0374],
#         [-0.0374,  0.8031]])
# mu: tensor([-0.7129, -0.0876])
# cov: tensor([[ 0.4328, -0.0278],
#         [-0.0278,  0.8103]])
# mu: tensor([-0.6619, -0.0395])
# cov: tensor([[ 0.4244, -0.0274],
#         [-0.0274,  0.8272]])
# mu: tensor([-0.5810,  0.0231])
# cov: tensor([[ 0.3998, -0.0493],
#         [-0.0493,  0.8089]])
# mu: tensor([-0.5318,  0.1578])
# cov: tensor([[ 0.3886, -0.0611],
#         [-0.0611,  0.8615]])
# mu: tensor([-0.4626,  0.3089])
# cov: tensor([[ 0.3720, -0.0462],
#         [-0.0462,  1.0897]])
# mu: tensor([-0.4986,  0.3683])
# cov: tensor([[ 0.3768, -0.0536],
#         [-0.0536,  1.1009]])
# mu: tensor([-0.4811,  0.3223])
# cov: tensor([[ 0.3748, -0.0512],
#         [-0.0512,  1.1052]])
# mu: tensor([-0.4941,  0.3434])
# cov: tensor([[ 0.3764, -0.0435],
#         [-0.0435,  1.0061]])
# mu: tensor([-0.4682,  0.2793])
# cov: tensor([[ 0.3736, -0.0384],
#         [-0.0384,  0.9990]])
# mu: tensor([-0.4695,  0.2102])
# cov: tensor([[ 0.3739, -0.0337],
#         [-0.0337,  0.9598]])
# mu: tensor([-0.4697,  0.3701])
# cov: tensor([[ 0.3735, -0.0447],
#         [-0.0447,  1.0700]])
# mu: tensor([-0.5408,  0.5420])
# cov: tensor([[ 0.3920, -0.0828],
#         [-0.0828,  1.1357]])
# mu: tensor([-0.5887,  0.7930])
# cov: tensor([[ 0.3993, -0.1218],
#         [-0.1218,  1.3436]])
# mu: tensor([-0.5778,  0.6269])
# cov: tensor([[ 0.3985, -0.1104],
#         [-0.1104,  1.3262]])
# mu: tensor([-0.4500,  0.0023])
# cov: tensor([[0.3675, 0.0231],
#         [0.0231, 0.8254]])
# mu: tensor([-0.4589, -0.0197])
# cov: tensor([[0.3697, 0.0262],
#         [0.0262, 0.8257]])
# mu: tensor([-0.4324,  0.1219])
# cov: tensor([[0.3662, 0.0071],
#         [0.0071, 0.7218]])
# mu: tensor([-0.4306,  0.1378])
# cov: tensor([[0.3658, 0.0058],
#         [0.0058, 0.7252]])
# mu: tensor([-0.4548, -0.0970])
# cov: tensor([[0.3737, 0.0510],
#         [0.0510, 0.8180]])
# mu: tensor([-0.4412, -0.1201])
# cov: tensor([[0.3715, 0.0524],
#         [0.0524, 0.8208]])
# mu: tensor([-0.5605,  0.0978])
# cov: tensor([[ 0.4171, -0.0123],
#         [-0.0123,  0.8828]])
# mu: tensor([-0.5442,  0.1314])
# cov: tensor([[ 0.4128, -0.0191],
#         [-0.0191,  0.8743]])
# mu: tensor([-0.4853,  0.1314])
# cov: tensor([[ 0.4005, -0.0118],
#         [-0.0118,  0.8778]])
# mu: tensor([-0.4555,  0.2732])
# cov: tensor([[ 0.3928, -0.0137],
#         [-0.0137,  1.0506]])
# mu: tensor([-0.6063,  0.4248])
# cov: tensor([[ 0.4365, -0.0446],
#         [-0.0446,  1.0584]])
# mu: tensor([-0.6801,  0.3826])
# cov: tensor([[ 0.4542, -0.0354],
#         [-0.0354,  1.0632]])
# mu: tensor([-0.5923,  0.1943])
# cov: tensor([[0.4384, 0.0028],
#         [0.0028, 0.9738]])
# mu: tensor([-0.5235,  0.3645])
# cov: tensor([[ 0.4194, -0.0514],
#         [-0.0514,  0.8231]])
# mu: tensor([-0.4561,  0.3099])
# cov: tensor([[ 0.4047, -0.0446],
#         [-0.0446,  0.8237]])
# mu: tensor([-0.4887,  0.3711])
# cov: tensor([[ 0.4120, -0.0568],
#         [-0.0568,  0.8435]])
# mu: tensor([-0.4083,  0.1622])
# cov: tensor([[ 0.3968, -0.0217],
#         [-0.0217,  0.7646]])
# mu: tensor([-0.4087,  0.1330])
# cov: tensor([[ 0.3970, -0.0184],
#         [-0.0184,  0.7674]])
# mu: tensor([-0.3752,  0.1139])
# cov: tensor([[ 0.3910, -0.0116],
#         [-0.0116,  0.7626]])
# mu: tensor([-0.3849,  0.1488])
# cov: tensor([[ 0.3938, -0.0181],
#         [-0.0181,  0.7634]])
# mu: tensor([-0.3089,  0.0125])
# cov: tensor([[0.3777, 0.0255],
#         [0.0255, 0.6679]])
# mu: tensor([-0.2739,  0.1437])
# cov: tensor([[0.3693, 0.0056],
#         [0.0056, 0.6384]])
# mu: tensor([-0.2732,  0.0855])
# cov: tensor([[0.3693, 0.0058],
#         [0.0058, 0.6314]])
# mu: tensor([-0.3283,  0.1070])
# cov: tensor([[0.3815, 0.0109],
#         [0.0109, 0.6212]])
# mu: tensor([-0.3358,  0.1415])
# cov: tensor([[0.3820, 0.0095],
#         [0.0095, 0.6224]])
# mu: tensor([-0.2977,  0.2143])
# cov: tensor([[0.3748, 0.0020],
#         [0.0020, 0.6202]])
# mu: tensor([-0.3038,  0.2575])
# cov: tensor([[3.7535e-01, 3.5545e-05],
#         [3.5528e-05, 6.1610e-01]])
# mu: tensor([-0.2950,  0.2405])
# cov: tensor([[0.3730, 0.0023],
#         [0.0023, 0.6230]])
# mu: tensor([-0.3833,  0.3615])
# cov: tensor([[ 0.3954, -0.0376],
#         [-0.0376,  0.6853]])
# mu: tensor([-0.4120,  0.4459])
# cov: tensor([[ 0.3992, -0.0427],
#         [-0.0427,  0.6613]])
# mu: tensor([-0.3936,  0.4757])
# cov: tensor([[ 0.3933, -0.0492],
#         [-0.0492,  0.6558]])
# mu: tensor([-0.3307,  0.3022])
# cov: tensor([[ 0.3837, -0.0208],
#         [-0.0208,  0.5722]])
# mu: tensor([-0.3445,  0.3419])
# cov: tensor([[ 0.3852, -0.0235],
#         [-0.0235,  0.5745]])
# mu: tensor([-0.3304,  0.3013])
# cov: tensor([[ 0.3822, -0.0172],
#         [-0.0172,  0.5815]])
# mu: tensor([-0.2966,  0.3393])
# cov: tensor([[ 0.3707, -0.0226],
#         [-0.0226,  0.5847]])
# mu: tensor([-0.2762,  0.3000])
# cov: tensor([[ 0.3679, -0.0206],
#         [-0.0206,  0.5911]])
# mu: tensor([-0.2824,  0.1758])
# cov: tensor([[ 0.3688, -0.0127],
#         [-0.0127,  0.6252]])
# mu: tensor([-0.2418,  0.2258])
# cov: tensor([[ 0.3580, -0.0229],
#         [-0.0229,  0.6167]])
# mu: tensor([-0.2907,  0.2979])
# cov: tensor([[ 0.3738, -0.0370],
#         [-0.0370,  0.6090]])
# mu: tensor([-0.2921,  0.1686])
# cov: tensor([[ 0.3747, -0.0253],
#         [-0.0253,  0.6162]])
# mu: tensor([-0.2740,  0.2661])
# cov: tensor([[ 0.3718, -0.0319],
#         [-0.0319,  0.6226]])
# mu: tensor([-0.2387,  0.2185])
# cov: tensor([[ 0.3669, -0.0244],
#         [-0.0244,  0.6114]])
# mu: tensor([-0.2432,  0.2287])
# cov: tensor([[ 0.3681, -0.0257],
#         [-0.0257,  0.6060]])
# mu: tensor([-0.2483,  0.3134])
# cov: tensor([[ 0.3685, -0.0321],
#         [-0.0321,  0.6069]])
# mu: tensor([-0.2424,  0.1972])
# cov: tensor([[ 0.3684, -0.0327],
#         [-0.0327,  0.6638]])
# mu: tensor([-0.3137,  0.5343])
# cov: tensor([[ 0.3798, -0.0825],
#         [-0.0825,  0.8761]])
# mu: tensor([-0.2938,  0.5924])
# cov: tensor([[ 0.3769, -0.0824],
#         [-0.0824,  0.8963]])
# mu: tensor([-0.4710,  0.8995])
# cov: tensor([[ 0.4214, -0.1565],
#         [-0.1565,  1.0191]])
# mu: tensor([-0.4389,  0.6804])
# cov: tensor([[ 0.4193, -0.1496],
#         [-0.1496,  1.0813]])
# mu: tensor([-0.4113,  0.6690])
# cov: tensor([[ 0.4164, -0.1490],
#         [-0.1490,  1.0813]])
# mu: tensor([-0.3466,  0.3604])
# cov: tensor([[ 0.4046, -0.0998],
#         [-0.0998,  0.8992]])
# mu: tensor([-0.2970,  0.0385])
# cov: tensor([[ 0.3985, -0.0656],
#         [-0.0656,  0.7135]])
# mu: tensor([-0.3336,  0.0582])
# cov: tensor([[ 0.4096, -0.0630],
#         [-0.0630,  0.7028]])
# mu: tensor([-0.2999,  0.1365])
# cov: tensor([[ 0.4025, -0.0654],
#         [-0.0654,  0.7391]])
# mu: tensor([-0.2500,  0.1097])
# cov: tensor([[ 0.3942, -0.0693],
#         [-0.0693,  0.7483]])
# mu: tensor([-0.3081,  0.2717])
# cov: tensor([[ 0.4053, -0.0895],
#         [-0.0895,  0.7677]])
# mu: tensor([-0.2861,  0.1410])
# cov: tensor([[ 0.4035, -0.0825],
#         [-0.0825,  0.7514]])
# mu: tensor([-0.3010,  0.3056])
# cov: tensor([[ 0.4059, -0.1034],
#         [-0.1034,  0.7864]])
# mu: tensor([-0.3104,  0.2712])
# cov: tensor([[ 0.4087, -0.0993],
#         [-0.0993,  0.7821]])
# mu: tensor([-0.2861,  0.2614])
# cov: tensor([[ 0.4046, -0.0964],
#         [-0.0964,  0.7806]])
# mu: tensor([-0.2812,  0.2896])
# cov: tensor([[ 0.4042, -0.0972],
#         [-0.0972,  0.7830]])
# mu: tensor([-0.2195,  0.0826])
# cov: tensor([[ 0.3923, -0.0705],
#         [-0.0705,  0.7480]])
# mu: tensor([-0.1823, -0.1409])
# cov: tensor([[ 0.3908, -0.0761],
#         [-0.0761,  0.8721]])
# mu: tensor([-0.2040, -0.0698])
# cov: tensor([[ 0.4028, -0.1052],
#         [-0.1052,  0.9337]])
# mu: tensor([-0.4014,  0.2148])
# cov: tensor([[ 0.5092, -0.2674],
#         [-0.2674,  1.1794]])
# mu: tensor([-0.3240,  0.0548])
# cov: tensor([[ 0.4841, -0.2142],
#         [-0.2142,  1.0671]])
# mu: tensor([-0.3673,  0.1703])
# cov: tensor([[ 0.4858, -0.2031],
#         [-0.2031,  0.9886]])
# mu: tensor([-0.3128,  0.0531])
# cov: tensor([[ 0.4701, -0.1814],
#         [-0.1814,  0.9722]])
# mu: tensor([-0.2629, -0.0944])
# cov: tensor([[ 0.4568, -0.1541],
#         [-0.1541,  0.9287]])
# mu: tensor([-0.3208, -0.2167])
# cov: tensor([[ 0.4752, -0.1344],
#         [-0.1344,  0.8576]])
# mu: tensor([-0.4215, -0.1095])
# cov: tensor([[ 0.5100, -0.1564],
#         [-0.1564,  0.8622]])
# mu: tensor([-0.5369,  0.0216])
# cov: tensor([[ 0.5664, -0.2205],
#         [-0.2205,  0.9351]])
# mu: tensor([-0.4987, -0.2000])
# cov: tensor([[ 0.5511, -0.1750],
#         [-0.1750,  0.8756]])
# mu: tensor([-0.5594, -0.0955])
# cov: tensor([[ 0.5676, -0.1916],
#         [-0.1916,  0.8821]])
# mu: tensor([-0.5564, -0.3485])
# cov: tensor([[ 0.5659, -0.1764],
#         [-0.1764,  1.0222]])
# mu: tensor([-0.4915, -0.5075])
# cov: tensor([[ 0.5157, -0.0687],
#         [-0.0687,  0.7942]])
# mu: tensor([-0.4793, -0.4297])
# cov: tensor([[ 0.5271, -0.1383],
#         [-0.1383,  1.0820]])
# mu: tensor([-0.6678,  0.0677])
# cov: tensor([[ 0.6189, -0.2830],
#         [-0.2830,  1.1937]])
# mu: tensor([-0.6074, -0.0632])
# cov: tensor([[ 0.6028, -0.2565],
#         [-0.2565,  1.1559]])
# mu: tensor([-0.5851,  0.0421])
# cov: tensor([[ 0.5972, -0.2790],
#         [-0.2790,  1.1384]])
# mu: tensor([-0.4468, -0.3233])
# cov: tensor([[ 0.5276, -0.1656],
#         [-0.1656,  1.0329]])
# mu: tensor([-0.4109, -0.3705])
# cov: tensor([[ 0.5269, -0.1790],
#         [-0.1790,  1.0724]])
# mu: tensor([-0.4093, -0.5206])
# cov: tensor([[ 0.5255, -0.1654],
#         [-0.1654,  1.0551]])
# mu: tensor([-0.3749, -0.4517])
# cov: tensor([[ 0.5179, -0.1769],
#         [-0.1769,  1.1266]])
# mu: tensor([-0.3203, -0.7266])
# cov: tensor([[ 0.4925, -0.1553],
#         [-0.1553,  1.2866]])
# mu: tensor([-0.4420, -0.9430])
# cov: tensor([[ 0.5208, -0.1164],
#         [-0.1164,  1.3019]])
# mu: tensor([-0.4230, -1.0573])
# cov: tensor([[ 0.5076, -0.0941],
#         [-0.0941,  1.3081]])
# mu: tensor([-0.4127, -0.6704])
# cov: tensor([[ 0.5168, -0.1501],
#         [-0.1501,  1.2591]])
# mu: tensor([-0.4457, -0.7241])
# cov: tensor([[ 0.5212, -0.1401],
#         [-0.1401,  1.2784]])
# mu: tensor([-0.5264, -0.3060])
# cov: tensor([[ 0.5419, -0.1550],
#         [-0.1550,  1.0543]])
# mu: tensor([-0.5633, -0.2174])
# cov: tensor([[ 0.5552, -0.1647],
#         [-0.1647,  1.0219]])
# mu: tensor([-0.6022, -0.4626])
# cov: tensor([[ 0.5596, -0.1426],
#         [-0.1426,  1.0981]])
# mu: tensor([-0.5874, -0.6386])
# cov: tensor([[ 0.5439, -0.0949],
#         [-0.0949,  1.0524]])
# mu: tensor([-0.5482, -0.6385])
# cov: tensor([[ 0.5314, -0.0865],
#         [-0.0865,  1.0905]])
# mu: tensor([-0.6141, -0.2716])
# cov: tensor([[ 0.5386, -0.0680],
#         [-0.0680,  0.7798]])
# mu: tensor([-0.6112, -0.3283])
# cov: tensor([[ 0.5381, -0.0656],
#         [-0.0656,  0.8002]])
# mu: tensor([-0.5487, -0.4173])
# cov: tensor([[ 0.5105, -0.0347],
#         [-0.0347,  0.7691]])
# mu: tensor([-0.4754, -0.3482])
# cov: tensor([[ 0.4842, -0.0551],
#         [-0.0551,  0.7592]])
# mu: tensor([-0.5260, -0.3054])
# cov: tensor([[ 0.4976, -0.0744],
#         [-0.0744,  0.7798]])
# mu: tensor([-0.4788, -0.2809])
# cov: tensor([[ 0.4849, -0.0795],
#         [-0.0795,  0.7781]])
# mu: tensor([-0.4510, -0.4156])
# cov: tensor([[ 0.4849, -0.0898],
#         [-0.0898,  0.8686]])
# mu: tensor([-0.5877, -0.3779])
# cov: tensor([[ 0.5292, -0.0888],
#         [-0.0888,  0.8607]])
# mu: tensor([-0.6081, -0.3008])
# cov: tensor([[ 0.5326, -0.0885],
#         [-0.0885,  0.8189]])
# mu: tensor([-0.4913, -0.2452])
# cov: tensor([[ 0.4846, -0.1037],
#         [-0.1037,  0.8224]])
# mu: tensor([-0.5490, -0.4454])
# cov: tensor([[ 0.4892, -0.0268],
#         [-0.0268,  0.6168]])
# mu: tensor([-0.5470, -0.4108])
# cov: tensor([[ 0.4892, -0.0296],
#         [-0.0296,  0.6248]])
# mu: tensor([-0.5713, -0.4368])
# cov: tensor([[ 0.4946, -0.0252],
#         [-0.0252,  0.6270]])
# mu: tensor([-0.6275, -0.3187])
# cov: tensor([[ 0.5098, -0.0441],
#         [-0.0441,  0.6399]])
# mu: tensor([-0.6460, -0.2122])
# cov: tensor([[ 0.5144, -0.0614],
#         [-0.0614,  0.6960]])
# mu: tensor([-0.6031, -0.2414])
# cov: tensor([[ 0.5069, -0.0650],
#         [-0.0650,  0.7085]])
# mu: tensor([-0.5866, -0.2882])
# cov: tensor([[ 0.4983, -0.0541],
#         [-0.0541,  0.7140]])
# mu: tensor([-0.6023, -0.1880])
# cov: tensor([[ 0.4999, -0.0596],
#         [-0.0596,  0.7217]])
# mu: tensor([-0.6423, -0.2571])
# cov: tensor([[ 0.5110, -0.0464],
#         [-0.0464,  0.7075]])
# mu: tensor([-0.6247, -0.2159])
# cov: tensor([[ 0.5074, -0.0515],
#         [-0.0515,  0.7173]])
# mu: tensor([-0.6630, -0.1936])
# cov: tensor([[ 0.5186, -0.0497],
#         [-0.0497,  0.7057]])
# mu: tensor([-0.6163, -0.1870])
# cov: tensor([[ 0.5058, -0.0522],
#         [-0.0522,  0.7053]])
# mu: tensor([-0.5985, -0.3273])
# cov: tensor([[ 0.4994, -0.0302],
#         [-0.0302,  0.6833]])
# mu: tensor([-0.6361, -0.2441])
# cov: tensor([[ 0.5122, -0.0352],
#         [-0.0352,  0.6391]])
# mu: tensor([-0.6723, -0.0823])
# cov: tensor([[ 0.5185, -0.0478],
#         [-0.0478,  0.6283]])
# mu: tensor([-0.6713,  0.0296])
# cov: tensor([[ 0.5185, -0.0549],
#         [-0.0549,  0.5970]])
# mu: tensor([-0.7745,  0.1230])
# cov: tensor([[ 0.5447, -0.0622],
#         [-0.0622,  0.5753]])
# mu: tensor([-0.7833,  0.2084])
# cov: tensor([[ 0.5455, -0.0683],
#         [-0.0683,  0.6206]])
# mu: tensor([-0.7485,  0.1836])
# cov: tensor([[ 0.5407, -0.0675],
#         [-0.0675,  0.6228]])
# mu: tensor([-0.6959,  0.2155])
# cov: tensor([[ 0.5249, -0.0716],
#         [-0.0716,  0.6264]])
# mu: tensor([-0.7089,  0.2098])
# cov: tensor([[ 0.5269, -0.0739],
#         [-0.0739,  0.6217]])
# mu: tensor([-0.6806,  0.3740])
# cov: tensor([[ 0.5138, -0.1106],
#         [-0.1106,  0.6119]])
# mu: tensor([-0.6563,  0.3423])
# cov: tensor([[ 0.5098, -0.1045],
#         [-0.1045,  0.6029]])
# mu: tensor([-0.6372,  0.3244])
# cov: tensor([[ 0.5063, -0.0980],
#         [-0.0980,  0.5963]])
# mu: tensor([-0.6406,  0.3306])
# cov: tensor([[ 0.5069, -0.0984],
#         [-0.0984,  0.5948]])
# mu: tensor([-0.7092,  0.4235])
# cov: tensor([[ 0.5205, -0.1107],
#         [-0.1107,  0.5990]])
# mu: tensor([-0.6188,  0.3999])
# cov: tensor([[ 0.4826, -0.1019],
#         [-0.1019,  0.5971]])
# mu: tensor([-0.6492,  0.3682])
# cov: tensor([[ 0.4899, -0.1022],
#         [-0.1022,  0.5852]])
# mu: tensor([-0.6975,  0.3387])
# cov: tensor([[ 0.5024, -0.1008],
#         [-0.1008,  0.5798]])
# mu: tensor([-0.7732,  0.3901])
# cov: tensor([[ 0.5206, -0.1085],
#         [-0.1085,  0.5798]])
# Iteration 1 | Log Likelihood: 0.464
# mu: tensor([-0.7732,  0.3901])
# cov: tensor([[ 0.5206, -0.1085],
#         [-0.1085,  0.5798]])
# mu: tensor([-0.6889,  0.3398])
# cov: tensor([[ 0.4950, -0.1027],
#         [-0.1027,  0.5941]])
# mu: tensor([-0.8042,  0.5272])
# cov: tensor([[ 0.5290, -0.1537],
#         [-0.1537,  0.6671]])
# mu: tensor([-0.9119,  0.8530])
# cov: tensor([[ 0.5526, -0.2302],
#         [-0.2302,  0.7463]])
# mu: tensor([-0.9281,  0.7902])
# cov: tensor([[ 0.5598, -0.2197],
#         [-0.2197,  0.7389]])
# mu: tensor([-0.7273,  0.5327])
# cov: tensor([[ 0.5021, -0.1504],
#         [-0.1504,  0.6586]])
# mu: tensor([-0.7962,  0.7315])
# cov: tensor([[ 0.5139, -0.1795],
#         [-0.1795,  0.7187]])
# mu: tensor([-0.6878,  0.5409])
# cov: tensor([[ 0.5023, -0.1819],
#         [-0.1819,  0.8042]])
# mu: tensor([-0.7628,  0.5260])
# cov: tensor([[ 0.5255, -0.1767],
#         [-0.1767,  0.8053]])
# mu: tensor([-0.5324,  0.1912])
# cov: tensor([[ 0.4519, -0.1014],
#         [-0.1014,  0.7931]])
# mu: tensor([-0.5434,  0.3875])
# cov: tensor([[ 0.4533, -0.1296],
#         [-0.1296,  0.8304]])
# mu: tensor([-0.5253,  0.3429])
# cov: tensor([[ 0.4512, -0.1233],
#         [-0.1233,  0.8128]])
# mu: tensor([-0.5442,  0.4135])
# cov: tensor([[ 0.4553, -0.1384],
#         [-0.1384,  0.8674]])
# mu: tensor([-0.5487,  0.4234])
# cov: tensor([[ 0.4563, -0.1391],
#         [-0.1391,  0.8609]])
# mu: tensor([-0.5746,  0.2949])
# cov: tensor([[ 0.4599, -0.1218],
#         [-0.1218,  0.9436]])
# mu: tensor([-0.5667,  0.3224])
# cov: tensor([[ 0.4597, -0.1230],
#         [-0.1230,  0.9382]])
# mu: tensor([-0.8862,  0.8525])
# cov: tensor([[ 0.5836, -0.3138],
#         [-0.3138,  1.2117]])
# mu: tensor([-0.7743,  0.5762])
# cov: tensor([[ 0.5536, -0.2442],
#         [-0.2442,  1.0539]])
# mu: tensor([-0.6723,  0.4063])
# cov: tensor([[ 0.5262, -0.2058],
#         [-0.2058,  1.0061]])
# mu: tensor([-0.6605,  0.4684])
# cov: tensor([[ 0.5243, -0.2092],
#         [-0.2092,  1.0235]])
# mu: tensor([-0.7356,  0.4402])
# cov: tensor([[ 0.5506, -0.2207],
#         [-0.2207,  0.9846]])
# mu: tensor([-0.5348,  0.1700])
# cov: tensor([[ 0.4657, -0.0986],
#         [-0.0986,  0.8131]])
# mu: tensor([-0.5409,  0.1441])
# cov: tensor([[ 0.4675, -0.0956],
#         [-0.0956,  0.7929]])
# mu: tensor([-0.5299,  0.1421])
# cov: tensor([[ 0.4650, -0.0960],
#         [-0.0960,  0.7933]])
# mu: tensor([-0.4708, -0.0792])
# cov: tensor([[ 0.4498, -0.0551],
#         [-0.0551,  0.7096]])
# mu: tensor([-0.4785, -0.1207])
# cov: tensor([[ 0.4510, -0.0500],
#         [-0.0500,  0.7287]])
# mu: tensor([-0.5488,  0.0757])
# cov: tensor([[ 0.4618, -0.0508],
#         [-0.0508,  0.6256]])
# mu: tensor([-0.5559,  0.1197])
# cov: tensor([[ 0.4635, -0.0575],
#         [-0.0575,  0.6304]])
# mu: tensor([-0.5328,  0.0242])
# cov: tensor([[ 0.4624, -0.0587],
#         [-0.0587,  0.6620]])
# mu: tensor([-0.4774,  0.0659])
# cov: tensor([[ 0.4430, -0.0613],
#         [-0.0613,  0.6827]])
# mu: tensor([-0.6163,  0.4210])
# cov: tensor([[ 0.4801, -0.1328],
#         [-0.1328,  0.7719]])
# mu: tensor([-0.7345,  0.8971])
# cov: tensor([[ 0.5064, -0.2333],
#         [-0.2333,  1.1424]])
# mu: tensor([-0.5529,  0.2737])
# cov: tensor([[ 0.4586, -0.0844],
#         [-0.0844,  0.8047]])
# mu: tensor([-0.5390,  0.2345])
# cov: tensor([[ 0.4577, -0.0829],
#         [-0.0829,  0.8041]])
# mu: tensor([-0.5183,  0.1410])
# cov: tensor([[ 0.4532, -0.0697],
#         [-0.0697,  0.7942]])
# mu: tensor([-0.6374,  0.1043])
# cov: tensor([[ 0.5000, -0.0734],
#         [-0.0734,  0.7703]])
# mu: tensor([-0.6462,  0.1583])
# cov: tensor([[ 0.5017, -0.0804],
#         [-0.0804,  0.7887]])
# mu: tensor([-0.6295,  0.1958])
# cov: tensor([[ 0.5004, -0.0852],
#         [-0.0852,  0.7738]])
# mu: tensor([-0.6616, -0.0884])
# cov: tensor([[ 0.5056, -0.0558],
#         [-0.0558,  0.8442]])
# mu: tensor([-0.7023, -0.0086])
# cov: tensor([[ 0.5178, -0.0666],
#         [-0.0666,  0.8249]])
# mu: tensor([-0.7343,  0.0410])
# cov: tensor([[ 0.5312, -0.0844],
#         [-0.0844,  0.8462]])
# mu: tensor([-0.7806,  0.1756])
# cov: tensor([[ 0.5445, -0.1022],
#         [-0.1022,  0.7851]])
# mu: tensor([-0.7200,  0.1187])
# cov: tensor([[ 0.5277, -0.0827],
#         [-0.0827,  0.7647]])
# mu: tensor([-0.7823,  0.2282])
# cov: tensor([[ 0.5371, -0.0923],
#         [-0.0923,  0.7661]])
# mu: tensor([-0.7367,  0.1908])
# cov: tensor([[ 0.5235, -0.0864],
#         [-0.0864,  0.7705]])
# mu: tensor([-0.8058,  0.0553])
# cov: tensor([[ 0.5429, -0.0546],
#         [-0.0546,  0.8181]])
# mu: tensor([-0.7720, -0.0528])
# cov: tensor([[ 0.5288, -0.0233],
#         [-0.0233,  0.8001]])
# mu: tensor([-0.8006,  0.2538])
# cov: tensor([[ 0.5370, -0.0833],
#         [-0.0833,  0.7958]])
# mu: tensor([-0.8049,  0.1485])
# cov: tensor([[ 0.5379, -0.0720],
#         [-0.0720,  0.8396]])
# mu: tensor([-0.7858,  0.2333])
# cov: tensor([[ 0.5337, -0.0838],
#         [-0.0838,  0.8249]])
# mu: tensor([-0.8124,  0.2033])
# cov: tensor([[ 0.5412, -0.0826],
#         [-0.0826,  0.8084]])
# mu: tensor([-0.9062, -0.0140])
# cov: tensor([[ 0.5703, -0.0473],
#         [-0.0473,  0.7135]])
# mu: tensor([-0.8163,  0.0045])
# cov: tensor([[ 0.5475, -0.0527],
#         [-0.0527,  0.7123]])
# mu: tensor([-0.7751,  0.0759])
# cov: tensor([[ 0.5404, -0.0593],
#         [-0.0593,  0.7151]])
# mu: tensor([-0.6848,  0.0084])
# cov: tensor([[ 0.5204, -0.0628],
#         [-0.0628,  0.7481]])
# mu: tensor([-0.7267,  0.0885])
# cov: tensor([[ 0.5301, -0.0795],
#         [-0.0795,  0.7762]])
# mu: tensor([-0.5735, -0.0476])
# cov: tensor([[ 0.4811, -0.0726],
#         [-0.0726,  0.8452]])
# mu: tensor([-0.6816, -0.0368])
# cov: tensor([[ 0.5253, -0.0818],
#         [-0.0818,  0.8448]])
# mu: tensor([-0.7396, -0.1165])
# cov: tensor([[ 0.5435, -0.0634],
#         [-0.0634,  0.8516]])
# mu: tensor([-0.6738,  0.0029])
# cov: tensor([[ 0.5293, -0.0904],
#         [-0.0904,  0.8007]])
# mu: tensor([-0.7832, -0.1469])
# cov: tensor([[ 0.5549, -0.0529],
#         [-0.0529,  0.8549]])
# mu: tensor([-0.9610, -0.2008])
# cov: tensor([[ 0.6297, -0.0411],
#         [-0.0411,  0.8385]])
# mu: tensor([-0.9704, -0.1497])
# cov: tensor([[ 0.6329, -0.0473],
#         [-0.0473,  0.8146]])
# mu: tensor([-0.9066,  0.2578])
# cov: tensor([[ 0.6166, -0.1215],
#         [-0.1215,  0.7998]])
# mu: tensor([-0.6912,  0.1012])
# cov: tensor([[ 0.5392, -0.0433],
#         [-0.0433,  0.7461]])
# mu: tensor([-0.5918, -0.0020])
# cov: tensor([[ 0.5042, -0.0121],
#         [-0.0121,  0.7210]])
# mu: tensor([-0.6281, -0.1973])
# cov: tensor([[0.5131, 0.0226],
#         [0.0226, 0.7757]])
# ...
# cov: tensor([[ 0.9426, -0.1215],
#         [-0.1215,  0.9025]])
# mu: tensor([ 0.1722, -0.3509])
# cov: tensor([[ 0.8950, -0.1077],
#         [-0.1076,  0.9904]])
# mu: tensor([ 0.2377, -0.3066])
# cov: tensor([[ 0.8057, -0.0643],
#         [-0.0643,  1.0846]])
# mu: tensor([ 0.2023, -0.2414])
# cov: tensor([[ 0.8268, -0.0632],
#         [-0.0632,  1.0428]])
# mu: tensor([ 0.1383, -0.1770])
# cov: tensor([[ 0.9052, -0.1023],
#         [-0.1023,  1.0523]])
# mu: tensor([ 0.1469, -0.1160])
# cov: tensor([[ 0.9014, -0.1167],
#         [-0.1167,  1.1474]])
# mu: tensor([ 0.2728, -0.1597])
# cov: tensor([[0.6588, 0.0025],
#         [0.0025, 1.0908]])
# mu: tensor([ 0.2280, -0.2124])
# cov: tensor([[0.6698, 0.0278],
#         [0.0278, 1.1362]])
# mu: tensor([ 0.2093, -0.2960])
# cov: tensor([[0.6780, 0.0510],
#         [0.0510, 1.0371]])
# mu: tensor([0.2564, 0.0732])
# cov: tensor([[0.6706, 0.0376],
#         [0.0376, 1.3416]])
# mu: tensor([0.1799, 0.0642])
# cov: tensor([[0.7195, 0.0611],
#         [0.0611, 1.3484]])
# mu: tensor([0.1363, 0.0566])
# cov: tensor([[0.7478, 0.0951],
#         [0.0951, 1.3664]])
# mu: tensor([ 0.1040, -0.0692])
# cov: tensor([[0.7501, 0.0750],
#         [0.0750, 1.1805]])
# mu: tensor([ 0.0927, -0.2216])
# cov: tensor([[0.7508, 0.0772],
#         [0.0772, 1.0821]])
# mu: tensor([ 0.1073, -0.1753])
# cov: tensor([[0.7377, 0.0456],
#         [0.0456, 1.0604]])
# mu: tensor([ 0.0629, -0.2267])
# cov: tensor([[0.7519, 0.0469],
#         [0.0469, 1.0432]])
# mu: tensor([ 0.0319, -0.1142])
# cov: tensor([[0.7638, 0.0406],
#         [0.0406, 0.9712]])
# mu: tensor([ 0.0092, -0.1480])
# cov: tensor([[0.7714, 0.0467],
#         [0.0467, 0.9721]])
# mu: tensor([0.0600, 0.0474])
# cov: tensor([[ 0.7580, -0.0055],
#         [-0.0055,  0.7679]])
# mu: tensor([ 0.0600, -0.0614])
# cov: tensor([[0.7580, 0.0034],
#         [0.0034, 0.7702]])
# mu: tensor([ 0.0335, -0.0882])
# cov: tensor([[0.7792, 0.0105],
#         [0.0105, 0.7620]])
# mu: tensor([ 0.0326, -0.0759])
# cov: tensor([[0.7806, 0.0051],
#         [0.0051, 0.7598]])
# mu: tensor([-0.0239, -0.1274])
# cov: tensor([[0.8175, 0.0109],
#         [0.0109, 0.7359]])
# mu: tensor([ 0.0272, -0.0537])
# cov: tensor([[0.7949, 0.0062],
#         [0.0062, 0.7759]])
# mu: tensor([-0.0725, -0.1758])
# cov: tensor([[0.8633, 0.0527],
#         [0.0527, 0.7797]])
# mu: tensor([-0.0927, -0.2634])
# cov: tensor([[0.8715, 0.0822],
#         [0.0822, 0.8423]])
# mu: tensor([-0.0590, -0.2098])
# cov: tensor([[0.8536, 0.0728],
#         [0.0728, 0.8839]])
# mu: tensor([-0.0603, -0.2082])
# cov: tensor([[0.8550, 0.0721],
#         [0.0721, 0.8837]])
# mu: tensor([ 0.1246, -0.1207])
# cov: tensor([[ 0.6827, -0.0679],
#         [-0.0679,  0.7912]])
# mu: tensor([ 0.0197, -0.1655])
# cov: tensor([[ 0.7410, -0.0316],
#         [-0.0316,  0.8116]])
# mu: tensor([-0.0090, -0.3406])
# cov: tensor([[ 0.7476, -0.0018],
#         [-0.0018,  0.8240]])
# mu: tensor([-0.0969, -0.1351])
# cov: tensor([[ 0.8315, -0.0711],
#         [-0.0711,  0.7908]])
# mu: tensor([-0.1590, -0.1814])
# cov: tensor([[ 0.8836, -0.0588],
#         [-0.0588,  0.7647]])
# mu: tensor([-0.1514, -0.1272])
# cov: tensor([[ 0.8823, -0.0864],
#         [-0.0864,  0.8079]])
# mu: tensor([-0.1351, -0.0203])
# cov: tensor([[ 0.8745, -0.1217],
#         [-0.1217,  0.8528]])
# mu: tensor([-0.1957,  0.0704])
# cov: tensor([[ 0.9215, -0.1659],
#         [-0.1659,  0.8745]])
# mu: tensor([-0.2794,  0.0903])
# cov: tensor([[ 0.9775, -0.1913],
#         [-0.1913,  0.8823]])
# mu: tensor([-0.4965,  0.3684])
# cov: tensor([[ 1.1086, -0.3332],
#         [-0.3332,  1.0248]])
# mu: tensor([-0.4590,  0.2751])
# cov: tensor([[ 1.0982, -0.3255],
#         [-0.3255,  1.0784]])
# mu: tensor([-0.4208,  0.2162])
# cov: tensor([[ 1.0759, -0.2944],
#         [-0.2944,  1.0361]])
# mu: tensor([-0.1757,  0.0147])
# cov: tensor([[ 0.9410, -0.2949],
#         [-0.2949,  1.1707]])
# mu: tensor([-0.1699,  0.0639])
# cov: tensor([[ 0.9388, -0.3056],
#         [-0.3056,  1.1614]])
# mu: tensor([-0.2176,  0.1578])
# cov: tensor([[ 0.9859, -0.3716],
#         [-0.3716,  1.2255]])
# mu: tensor([-0.1047, -0.0223])
# cov: tensor([[ 0.9088, -0.2382],
#         [-0.2382,  0.9964]])
# mu: tensor([-0.1179, -0.1439])
# cov: tensor([[ 0.9135, -0.1660],
#         [-0.1660,  0.9071]])
# mu: tensor([-0.2696, -0.0084])
# cov: tensor([[ 1.2494, -0.4612],
#         [-0.4612,  1.1664]])
# mu: tensor([-1.1329,  0.1409])
# cov: tensor([[ 2.2807, -0.5632],
#         [-0.5632,  1.1570]])
# mu: tensor([-0.0715, -0.0630])
# cov: tensor([[ 0.7419, -0.2374],
#         [-0.2374,  1.0907]])
# mu: tensor([ 0.0018, -0.1410])
# cov: tensor([[ 0.7048, -0.2176],
#         [-0.2176,  1.0902]])
# mu: tensor([ 0.0033, -0.0765])
# cov: tensor([[ 0.7061, -0.2487],
#         [-0.2487,  1.2323]])
# mu: tensor([0.0378, 0.0395])
# cov: tensor([[ 0.6912, -0.2650],
#         [-0.2650,  1.2916]])
# mu: tensor([0.0510, 0.0133])
# cov: tensor([[ 0.6926, -0.2736],
#         [-0.2736,  1.3206]])
# mu: tensor([ 0.0464, -0.0554])
# cov: tensor([[ 0.6971, -0.2421],
#         [-0.2421,  1.2574]])
# mu: tensor([-0.0200,  0.1858])
# cov: tensor([[ 0.7112, -0.2725],
#         [-0.2725,  1.2900]])
# mu: tensor([-0.1617,  0.4480])
# cov: tensor([[ 0.8077, -0.4743],
#         [-0.4743,  1.7020]])
# mu: tensor([-0.2115,  0.4631])
# cov: tensor([[ 0.8336, -0.4995],
#         [-0.4995,  1.7129]])
# mu: tensor([-0.0802,  0.1320])
# cov: tensor([[ 0.7475, -0.3211],
#         [-0.3211,  1.3848]])
# mu: tensor([0.0121, 0.0655])
# cov: tensor([[ 0.7077, -0.3115],
#         [-0.3115,  1.3923]])
# mu: tensor([ 0.0028, -0.0610])
# cov: tensor([[ 0.7123, -0.2838],
#         [-0.2838,  1.3034]])
# mu: tensor([ 0.0242, -0.2309])
# cov: tensor([[ 0.6970, -0.2195],
#         [-0.2195,  1.1195]])
# mu: tensor([ 0.0225, -0.1399])
# cov: tensor([[ 0.6984, -0.2319],
#         [-0.2319,  1.0427]])
# mu: tensor([0.0135, 0.0071])
# cov: tensor([[ 0.7019, -0.2587],
#         [-0.2587,  1.1050]])
# mu: tensor([ 0.0649, -0.0540])
# cov: tensor([[ 0.6703, -0.2250],
#         [-0.2250,  1.0694]])
# mu: tensor([ 0.0597, -0.1792])
# cov: tensor([[ 0.6686, -0.1574],
#         [-0.1574,  0.9921]])
# mu: tensor([ 0.0645, -0.0842])
# cov: tensor([[ 0.6678, -0.1675],
#         [-0.1675,  0.9753]])
# mu: tensor([ 0.0162, -0.1674])
# cov: tensor([[ 0.6978, -0.1475],
#         [-0.1475,  0.9446]])
# mu: tensor([ 0.0245, -0.0257])
# cov: tensor([[ 0.6981, -0.2417],
#         [-0.2417,  1.3182]])
# mu: tensor([ 0.0928, -0.2825])
# cov: tensor([[ 0.6757, -0.1964],
#         [-0.1964,  1.2775]])
# mu: tensor([ 0.0842, -0.3824])
# cov: tensor([[ 0.6770, -0.1729],
#         [-0.1729,  1.2688]])
# mu: tensor([ 0.0394, -0.5166])
# cov: tensor([[ 0.6951, -0.1256],
#         [-0.1256,  1.1819]])
# mu: tensor([ 0.0308, -0.1935])
# cov: tensor([[ 0.6971, -0.1371],
#         [-0.1371,  0.9076]])
# mu: tensor([ 0.0201, -0.3668])
# cov: tensor([[ 0.6902, -0.0718],
#         [-0.0718,  0.8854]])
# mu: tensor([ 0.0006, -0.5316])
# cov: tensor([[ 0.6895, -0.0297],
#         [-0.0297,  0.9614]])
# mu: tensor([-0.0331, -0.5915])
# cov: tensor([[ 0.6949, -0.0198],
#         [-0.0198,  0.9793]])
# mu: tensor([ 0.0065, -0.5346])
# cov: tensor([[ 0.6763, -0.0468],
#         [-0.0468,  0.9402]])
# mu: tensor([-0.0373, -0.2867])
# cov: tensor([[ 0.7062, -0.0986],
#         [-0.0986,  0.9212]])
# mu: tensor([-0.2041, -0.2625])
# cov: tensor([[ 0.8436, -0.0518],
#         [-0.0518,  0.8973]])
# mu: tensor([-0.2031, -0.1557])
# cov: tensor([[ 0.8454, -0.0727],
#         [-0.0727,  0.8561]])
# mu: tensor([-0.2267, -0.1242])
# cov: tensor([[ 0.8596, -0.0904],
#         [-0.0904,  0.8781]])
# mu: tensor([-0.1211, -0.2843])
# cov: tensor([[ 0.8012, -0.0300],
#         [-0.0300,  0.8273]])
# mu: tensor([-0.0890, -0.2126])
# cov: tensor([[ 0.7886, -0.0472],
#         [-0.0472,  0.8287]])
# mu: tensor([-0.0944, -0.2544])
# cov: tensor([[ 0.7897, -0.0343],
#         [-0.0343,  0.8434]])
# mu: tensor([-0.0276, -0.0506])
# cov: tensor([[ 0.7676, -0.0849],
#         [-0.0849,  0.7500]])
# mu: tensor([-0.0773, -0.1497])
# cov: tensor([[ 0.7837, -0.0468],
#         [-0.0468,  0.8376]])
# mu: tensor([-0.1083, -0.1898])
# cov: tensor([[ 0.7945, -0.0433],
#         [-0.0433,  0.8245]])
# mu: tensor([-0.1287, -0.2322])
# cov: tensor([[ 0.8058, -0.0226],
#         [-0.0226,  0.8606]])
# mu: tensor([-0.1717, -0.1758])
# cov: tensor([[ 0.8339, -0.0550],
#         [-0.0550,  0.8972]])
# mu: tensor([-0.1486, -0.0882])
# cov: tensor([[ 0.8319, -0.0653],
#         [-0.0653,  0.8485]])
# mu: tensor([-0.1313, -0.0624])
# cov: tensor([[ 0.8285, -0.0672],
#         [-0.0672,  0.8510]])
# mu: tensor([-0.1167, -0.2313])
# cov: tensor([[ 0.8265, -0.0591],
#         [-0.0591,  0.8912]])
# mu: tensor([-0.1319, -0.0853])
# cov: tensor([[ 0.8456, -0.1037],
#         [-0.1037,  0.7898]])
# mu: tensor([-0.1242,  0.0839])
# cov: tensor([[ 0.8420, -0.1538],
#         [-0.1538,  0.8167]])
# mu: tensor([-0.2086,  0.1186])
# cov: tensor([[ 0.9179, -0.1826],
#         [-0.1826,  0.8275]])
# mu: tensor([-0.1525,  0.0847])
# cov: tensor([[ 0.8830, -0.1749],
#         [-0.1749,  0.8328]])
# mu: tensor([-0.1524,  0.0690])
# cov: tensor([[ 0.8830, -0.1717],
#         [-0.1717,  0.8448]])
# mu: tensor([-0.2602,  0.2472])
# cov: tensor([[ 0.9375, -0.2317],
#         [-0.2317,  0.8832]])
# mu: tensor([-0.1377,  0.0437])
# cov: tensor([[ 0.8404, -0.1368],
#         [-0.1368,  0.8983]])
# mu: tensor([ 0.0204, -0.1712])
# cov: tensor([[ 0.7433, -0.1142],
#         [-0.1142,  1.0135]])
# mu: tensor([ 0.1052, -0.2590])
# cov: tensor([[ 0.6926, -0.0643],
#         [-0.0643,  0.9645]])
# mu: tensor([ 0.1463, -0.2246])
# cov: tensor([[ 0.6812, -0.0677],
#         [-0.0677,  0.9669]])
# mu: tensor([0.0601, 0.0877])
# cov: tensor([[ 0.7657, -0.2865],
#         [-0.2865,  1.4819]])
# mu: tensor([0.0593, 0.3192])
# cov: tensor([[ 0.7521, -0.3691],
#         [-0.3691,  1.8584]])
# mu: tensor([0.0621, 0.2281])
# cov: tensor([[ 0.7527, -0.3488],
#         [-0.3488,  1.7614]])
# mu: tensor([0.0340, 0.3746])
# cov: tensor([[ 0.7540, -0.3494],
#         [-0.3494,  1.7278]])
# mu: tensor([0.0728, 0.0820])
# cov: tensor([[ 0.7406, -0.2687],
#         [-0.2687,  1.3703]])
# mu: tensor([0.0573, 0.0148])
# cov: tensor([[ 0.7504, -0.2516],
#         [-0.2516,  1.3545]])
# mu: tensor([ 0.0341, -0.0962])
# cov: tensor([[ 0.7681, -0.2129],
#         [-0.2129,  1.3094]])
# mu: tensor([ 0.0027, -0.2014])
# cov: tensor([[ 0.7955, -0.1584],
#         [-0.1584,  1.1106]])
# mu: tensor([ 0.0514, -0.2746])
# cov: tensor([[ 0.7822, -0.1495],
#         [-0.1495,  1.1127]])
# mu: tensor([ 0.0710, -0.2346])
# cov: tensor([[ 0.7768, -0.1613],
#         [-0.1613,  1.0869]])
# mu: tensor([ 0.1037, -0.4016])
# cov: tensor([[ 0.7734, -0.1749],
#         [-0.1749,  1.2576]])
# mu: tensor([ 0.1026, -0.4547])
# cov: tensor([[ 0.7728, -0.1655],
#         [-0.1655,  1.2367]])
# mu: tensor([ 0.1058, -0.5017])
# cov: tensor([[ 0.7711, -0.1631],
#         [-0.1631,  1.2859]])
# mu: tensor([ 0.0552, -0.4793])
# cov: tensor([[ 0.8164, -0.2211],
#         [-0.2211,  1.3384]])
# mu: tensor([ 0.0718, -0.5235])
# cov: tensor([[ 0.7959, -0.1813],
#         [-0.1813,  1.2638]])
# mu: tensor([-0.0075, -0.3979])
# cov: tensor([[ 0.8311, -0.2136],
#         [-0.2136,  1.2828]])
# mu: tensor([-0.3702,  0.4016])
# cov: tensor([[ 1.3042, -0.9687],
#         [-0.9687,  2.3228]])
# mu: tensor([-0.4785,  0.5966])
# cov: tensor([[ 1.3817, -1.0814],
#         [-1.0814,  2.4665]])
# mu: tensor([-0.2995,  0.2299])
# cov: tensor([[ 1.7288, -1.9358],
#         [-1.9358,  4.5461]])
# mu: tensor([ 0.0157, -0.4514])
# cov: tensor([[ 0.9339, -0.3832],
#         [-0.3832,  1.5337]])
# mu: tensor([ 0.0925, -0.4976])
# cov: tensor([[ 0.8383, -0.3760],
#         [-0.3760,  1.5540]])
# mu: tensor([ 0.0366, -0.2570])
# cov: tensor([[ 0.8484, -0.3886],
#         [-0.3886,  1.5013]])
# mu: tensor([ 0.0857, -0.2729])
# cov: tensor([[ 0.8131, -0.3530],
#         [-0.3530,  1.4807]])
# mu: tensor([ 0.1243, -0.1439])
# cov: tensor([[ 0.8204, -0.3776],
#         [-0.3776,  1.2708]])
# mu: tensor([-0.1464,  0.3486])
# cov: tensor([[ 1.1488, -0.7804],
#         [-0.7804,  1.6158]])
# mu: tensor([-0.1586,  0.2599])
# cov: tensor([[ 1.1482, -0.7757],
#         [-0.7757,  1.7366]])
# mu: tensor([-0.0670,  0.1068])
# cov: tensor([[ 1.0937, -0.6987],
#         [-0.6987,  1.6325]])
# mu: tensor([ 0.0113, -0.1261])
# cov: tensor([[ 1.0280, -0.5608],
#         [-0.5608,  1.3896]])
# mu: tensor([ 0.0766, -0.3071])
# cov: tensor([[ 0.9064, -0.3564],
#         [-0.3564,  1.0928]])
# mu: tensor([ 0.0580, -0.2799])
# cov: tensor([[ 0.9385, -0.3924],
#         [-0.3924,  1.1316]])
# mu: tensor([ 0.2127, -0.4351])
# cov: tensor([[ 0.6641, -0.2314],
#         [-0.2314,  1.0563]])
# mu: tensor([ 0.1626, -0.1647])
# cov: tensor([[ 0.6892, -0.2680],
#         [-0.2680,  0.9546]])
# mu: tensor([0.1288, 0.0128])
# cov: tensor([[ 0.6907, -0.2675],
#         [-0.2675,  0.9104]])
# mu: tensor([ 0.1451, -0.0027])
# cov: tensor([[ 0.6865, -0.2612],
#         [-0.2612,  0.9022]])
# mu: tensor([ 0.2247, -0.1429])
# cov: tensor([[ 0.6308, -0.1573],
#         [-0.1573,  0.7086]])
# mu: tensor([ 0.2601, -0.2284])
# cov: tensor([[ 0.6174, -0.1400],
#         [-0.1400,  0.6965]])
# mu: tensor([ 0.2162, -0.2456])
# cov: tensor([[ 0.6320, -0.1235],
#         [-0.1235,  0.7082]])
# mu: tensor([ 0.1704, -0.2818])
# cov: tensor([[ 0.6509, -0.1011],
#         [-0.1011,  0.7319]])
# mu: tensor([ 0.0987, -0.2029])
# cov: tensor([[ 0.6771, -0.1041],
#         [-0.1041,  0.7135]])
# mu: tensor([ 0.1015, -0.1089])
# cov: tensor([[ 0.6775, -0.1231],
#         [-0.1231,  0.7223]])
# mu: tensor([ 0.1199, -0.2650])
# cov: tensor([[ 0.6177, -0.0080],
#         [-0.0080,  0.6308]])
# mu: tensor([ 0.1267, -0.2018])
# cov: tensor([[ 0.6177, -0.0278],
#         [-0.0278,  0.7051]])
# mu: tensor([ 0.1668, -0.1848])
# cov: tensor([[ 0.5966, -0.0187],
#         [-0.0187,  0.7146]])
# mu: tensor([ 0.1431, -0.0931])
# cov: tensor([[ 0.6298, -0.0900],
#         [-0.0900,  0.8439]])
# mu: tensor([ 0.1527, -0.1175])
# cov: tensor([[ 0.6272, -0.0849],
#         [-0.0849,  0.8341]])
# mu: tensor([ 0.1775, -0.0786])
# cov: tensor([[ 0.6191, -0.0882],
#         [-0.0882,  0.8429]])
# mu: tensor([0.1671, 0.0128])
# cov: tensor([[ 0.6250, -0.1089],
#         [-0.1089,  0.7956]])
# mu: tensor([0.1904, 0.0079])
# cov: tensor([[ 0.6202, -0.1166],
#         [-0.1166,  0.7973]])
# mu: tensor([ 0.1957, -0.1135])
# cov: tensor([[ 0.6191, -0.1052],
#         [-0.1052,  0.8151]])
# mu: tensor([ 0.1592, -0.1114])
# cov: tensor([[ 0.6330, -0.1051],
#         [-0.1051,  0.8150]])
# mu: tensor([ 0.1735, -0.1320])
# cov: tensor([[ 0.6319, -0.1039],
#         [-0.1039,  0.8139]])
# mu: tensor([ 0.1476, -0.1061])
# cov: tensor([[ 0.6385, -0.1024],
#         [-0.1024,  0.8058]])
# mu: tensor([ 0.2010, -0.1454])
# cov: tensor([[ 0.6082, -0.0628],
#         [-0.0628,  0.7608]])
# mu: tensor([ 0.1432, -0.1050])
# cov: tensor([[ 0.6717, -0.0620],
#         [-0.0620,  0.7435]])
# mu: tensor([ 0.1732, -0.1284])
# cov: tensor([[ 0.6574, -0.0638],
#         [-0.0638,  0.7521]])
# mu: tensor([ 0.1614, -0.1994])
# cov: tensor([[ 0.6587, -0.0583],
#         [-0.0583,  0.7727]])
# mu: tensor([ 0.1209, -0.2125])
# cov: tensor([[ 0.6704, -0.0398],
#         [-0.0398,  0.7845]])
# mu: tensor([ 0.1131, -0.3077])
# cov: tensor([[ 0.6713, -0.0313],
#         [-0.0313,  0.7729]])
# mu: tensor([ 0.0629, -0.2692])
# cov: tensor([[ 0.6905, -0.0458],
#         [-0.0458,  0.7837]])
# mu: tensor([ 0.1453, -0.2281])
# cov: tensor([[ 0.5862, -0.0298],
#         [-0.0298,  0.8263]])
# mu: tensor([ 0.1417, -0.2977])
# cov: tensor([[ 0.5864, -0.0258],
#         [-0.0258,  0.8371]])
# mu: tensor([ 0.0844, -0.3075])
# cov: tensor([[ 0.6097, -0.0362],
#         [-0.0362,  0.8337]])
# mu: tensor([ 0.0651, -0.3136])
# cov: tensor([[ 0.6227, -0.0335],
#         [-0.0335,  0.8341]])
# mu: tensor([ 0.0284, -0.2795])
# cov: tensor([[ 0.6439, -0.0347],
#         [-0.0347,  0.8229]])
# mu: tensor([ 0.0210, -0.2176])
# cov: tensor([[ 0.6537, -0.0465],
#         [-0.0465,  0.7657]])
# mu: tensor([ 0.0198, -0.2538])
# cov: tensor([[ 0.6535, -0.0398],
#         [-0.0398,  0.7417]])
# mu: tensor([-0.0537, -0.2232])
# cov: tensor([[ 0.6928, -0.0404],
#         [-0.0404,  0.7359]])
# mu: tensor([-0.0453, -0.3025])
# cov: tensor([[ 0.6843, -0.0227],
#         [-0.0227,  0.7641]])
# mu: tensor([-0.0912, -0.1558])
# cov: tensor([[ 0.7059, -0.0460],
#         [-0.0460,  0.7351]])
# mu: tensor([-0.0249, -0.1647])
# cov: tensor([[ 0.6631, -0.0196],
#         [-0.0196,  0.7298]])
# mu: tensor([-0.0960, -0.0814])
# cov: tensor([[ 0.6971, -0.0230],
#         [-0.0230,  0.6946]])
# mu: tensor([-0.1061,  0.1044])
# cov: tensor([[ 0.7024, -0.0745],
#         [-0.0745,  0.6865]])
# mu: tensor([-0.0449,  0.1014])
# cov: tensor([[ 0.6722, -0.0535],
#         [-0.0535,  0.6858]])
# Iteration 5 | Log Likelihood: 0.75

# %%
censored_multi.censored_multi_normal.cov_est.mean(0)
# Out:
# tensor([[1.8514, 0.0939],
#         [0.0939, 1.3408]], grad_fn=<MeanBackward1>)

# %% [markdown]
# # Multivariate Normal Performance Experiment

# %%
store = Store(args.out_dir + '/' + args.exp)

schema = { 
    'kl_div_emp': float, 
    'kl_div_censored': float,
    'kl_div_censored_avg': float,
    'var': int,
}

store.add_table(TABLE_NAME, schema)


for i in range(args.trials): 
    for var in range(1, args.var + 1): 
        # create new dataset
        gt_loc, gt_scale = ch.zeros(args.d), var * ch.eye(args.d)
        gt_dist = MultivariateNormal(gt_loc, gt_scale)
        samples = gt_dist.sample([args.samples])

        # right truncate at 0
        phi = oracle.Right(Tensor([0.0, float('inf')]))
        indices = phi(samples).nonzero()[:,0]
        S = samples[indices]
        alpha = S.size(0) / samples.size(0)

        emp_dist = MultivariateNormal(S.mean(0), cov(S))


        censored_multi = CensoredMultivariateNormal(phi=phi, 
                              alpha=alpha, 
                              iter_=1, 
                              bs=1, 
                              num_samples=100,
                              lr=1e-1)
        censored_multi.fit(S)

        loc_ = censored_multi.loc@censored_multi.covariance_matrix.inverse() 
        cov_ = censored_multi.covariance_matrix.inverse()

        censor_dist = MultivariateNormal(loc_, cov_)
        
        cov_avg_ = censored_multi.censored_multi_normal.cov_est.mean(0).inverse()
        loc_avg_ = censored_multi.censored_multi_normal.loc_est.mean(0)@cov_avg_

        censor_dist_avg = MultivariateNormal(loc_avg_, cov_avg_)

        kl_censor = float(kl_divergence(gt_dist, censor_dist))
        kl_censor_avg = float(kl_divergence(gt_dist, censor_dist_avg))
        kl_emp = float(kl_divergence(gt_dist, emp_dist))


        store[TABLE_NAME].update_row({ 
            'kl_div_emp': kl_emp, 
            'kl_div_censored_avg': kl_censor_avg, 
            'kl_div_censored': kl_censor,
            'var': var,
        })
        store[TABLE_NAME].flush_row()
# Out:
# Logging in: /Users/patroklos/Desktop/exp/multi_censor/multiCensoredVaryingVar/ac9bad85-5e14-484c-b2f9-40785e343adb
# mu: tensor([-0.8216,  0.0089])
# cov: tensor([[ 0.4394, -0.0094],
#         [-0.0094,  1.0497]])
# mu: tensor([-0.7943, -0.0701])
# cov: tensor([[0.4347, 0.0092],
#         [0.0092, 0.9868]])
# mu: tensor([-0.8289, -0.0989])
# cov: tensor([[0.4404, 0.0052],
#         [0.0052, 0.9606]])
# mu: tensor([-0.8732,  0.1692])
# cov: tensor([[ 0.4478, -0.0281],
#         [-0.0281,  1.0709]])
# mu: tensor([-0.8710,  0.1638])
# cov: tensor([[ 0.4473, -0.0273],
#         [-0.0273,  1.0698]])
# mu: tensor([-0.8658,  0.0360])
# cov: tensor([[ 0.4468, -0.0165],
#         [-0.0165,  0.9245]])
# mu: tensor([-0.8632, -0.0651])
# cov: tensor([[ 0.4462, -0.0033],
#         [-0.0033,  0.8783]])
# mu: tensor([-0.9822, -0.1931])
# cov: tensor([[0.4726, 0.0132],
#         [0.0132, 0.8678]])
# mu: tensor([-0.9938, -0.1238])
# cov: tensor([[0.4757, 0.0038],
#         [0.0038, 0.8480]])
# mu: tensor([-1.0019, -0.2406])
# cov: tensor([[0.4768, 0.0188],
#         [0.0188, 0.8099]])
# mu: tensor([-0.8670, -0.0692])
# cov: tensor([[ 0.4440, -0.0049],
#         [-0.0049,  0.8469]])
# mu: tensor([-0.9462, -0.1025])
# cov: tensor([[ 0.4623, -0.0064],
#         [-0.0064,  0.8293]])
# mu: tensor([-0.9063, -0.0805])
# cov: tensor([[ 0.4521, -0.0088],
#         [-0.0088,  0.8340]])
# mu: tensor([-0.8518,  0.0278])
# cov: tensor([[ 0.4412, -0.0265],
#         [-0.0265,  0.8099]])
# mu: tensor([-0.9435,  0.4013])
# cov: tensor([[ 0.4595, -0.0914],
#         [-0.0914,  1.0222]])
# mu: tensor([-0.9708,  0.1505])
# cov: tensor([[ 0.4644, -0.0522],
#         [-0.0522,  1.3230]])
# mu: tensor([-0.9246, -0.3298])
# cov: tensor([[0.4523, 0.0209],
#         [0.0209, 1.2960]])
# mu: tensor([-0.8778, -0.3443])
# cov: tensor([[0.4406, 0.0245],
#         [0.0245, 1.2949]])
# mu: tensor([-0.8169,  0.0505])
# cov: tensor([[ 0.4273, -0.0425],
#         [-0.0425,  1.2468]])
# mu: tensor([-0.9736,  0.1523])
# cov: tensor([[ 0.4629, -0.0444],
#         [-0.0444,  1.2039]])
# mu: tensor([-1.0039, -0.3457])
# cov: tensor([[0.4672, 0.0127],
#         [0.0127, 1.1064]])
# mu: tensor([-0.9681, -0.2875])
# cov: tensor([[ 0.4632, -0.0027],
#         [-0.0027,  1.0834]])
# mu: tensor([-0.9413,  0.0924])
# cov: tensor([[ 0.4607, -0.0282],
#         [-0.0282,  0.9165]])
# mu: tensor([-0.9006, -0.1152])
# cov: tensor([[0.4501, 0.0053],
#         [0.0053, 0.9486]])
# mu: tensor([-0.9036, -0.2534])
# cov: tensor([[0.4503, 0.0143],
#         [0.0143, 0.8775]])
# mu: tensor([-0.7727, -0.2373])
# cov: tensor([[0.4212, 0.0035],
#         [0.0035, 0.8789]])
# mu: tensor([-0.8282, -0.3024])
# cov: tensor([[0.4305, 0.0159],
#         [0.0159, 0.8949]])
# mu: tensor([-0.7864,  0.0615])
# cov: tensor([[ 0.4232, -0.0338],
#         [-0.0338,  0.7941]])
# mu: tensor([-0.8195,  0.0105])
# cov: tensor([[ 0.4303, -0.0254],
#         [-0.0254,  0.8015]])
# mu: tensor([-0.8846, -0.1085])
# cov: tensor([[ 0.4485, -0.0024],
#         [-0.0024,  0.7918]])
# mu: tensor([-0.8739, -0.2103])
# cov: tensor([[0.4472, 0.0040],
#         [0.0040, 0.7859]])
# mu: tensor([-0.8863, -0.1581])
# cov: tensor([[ 0.4500, -0.0021],
#         [-0.0021,  0.7832]])
# mu: tensor([-0.8413, -0.2268])
# cov: tensor([[0.4371, 0.0180],
#         [0.0180, 0.7518]])
# mu: tensor([-1.0038, -0.1919])
# cov: tensor([[0.4874, 0.0067],
#         [0.0067, 0.7543]])
# mu: tensor([-1.0985, -0.0565])
# cov: tensor([[ 0.5149, -0.0294],
#         [-0.0294,  0.8000]])
# mu: tensor([-0.8766, -0.1402])
# cov: tensor([[0.4554, 0.0144],
#         [0.0144, 0.8052]])
# mu: tensor([-0.9856, -0.2772])
# cov: tensor([[0.4815, 0.0396],
#         [0.0396, 0.8189]])
# mu: tensor([-1.0397, -0.4991])
# cov: tensor([[0.4872, 0.0602],
#         [0.0602, 0.8894]])
# mu: tensor([-1.0168, -0.3364])
# cov: tensor([[0.4843, 0.0429],
#         [0.0429, 0.8313]])
# mu: tensor([-0.9819, -0.2301])
# cov: tensor([[0.4794, 0.0440],
#         [0.0440, 1.0127]])
# mu: tensor([-0.9225, -0.3295])
# cov: tensor([[0.4680, 0.0595],
#         [0.0595, 0.9942]])
# mu: tensor([-0.9607, -0.1997])
# cov: tensor([[0.4785, 0.0427],
#         [0.0427, 0.9434]])
# mu: tensor([-1.0048, -0.3411])
# cov: tensor([[0.4906, 0.0747],
#         [0.0747, 0.9501]])
# mu: tensor([-0.8861, -0.1609])
# cov: tensor([[0.4607, 0.0252],
#         [0.0252, 0.8710]])
# mu: tensor([-1.1805, -0.3133])
# cov: tensor([[0.5584, 0.0754],
#         [0.0754, 0.8967]])
# mu: tensor([-1.0398,  0.1595])
# cov: tensor([[ 0.5191, -0.0322],
#         [-0.0322,  0.6978]])
# mu: tensor([-1.0734,  0.1902])
# cov: tensor([[ 0.5267, -0.0367],
#         [-0.0367,  0.6976]])
# mu: tensor([-1.0317,  0.4577])
# cov: tensor([[ 0.5138, -0.0733],
#         [-0.0733,  0.7664]])
# mu: tensor([-0.9894,  0.3724])
# cov: tensor([[ 0.5078, -0.0623],
#         [-0.0623,  0.7466]])
# mu: tensor([-1.1126,  0.0800])
# cov: tensor([[ 0.5445, -0.0201],
#         [-0.0201,  0.6460]])
# mu: tensor([-1.0175,  0.0204])
# cov: tensor([[ 0.5169, -0.0119],
#         [-0.0119,  0.6613]])
# mu: tensor([-1.0302,  0.1526])
# cov: tensor([[ 0.5181, -0.0189],
#         [-0.0189,  0.6579]])
# mu: tensor([-1.0743,  0.3293])
# cov: tensor([[ 0.5234, -0.0406],
#         [-0.0406,  0.7457]])
# mu: tensor([-1.1086,  0.3713])
# cov: tensor([[ 0.5322, -0.0515],
#         [-0.0515,  0.7592]])
# mu: tensor([-0.9285,  0.3349])
# cov: tensor([[ 0.4874, -0.0464],
#         [-0.0464,  0.7601]])
# mu: tensor([-0.8300,  0.1699])
# cov: tensor([[ 0.4642, -0.0198],
#         [-0.0198,  0.7641]])
# mu: tensor([-0.7744,  0.2208])
# cov: tensor([[ 0.4528, -0.0214],
#         [-0.0214,  0.7783]])
# mu: tensor([-0.7574,  0.1341])
# cov: tensor([[ 0.4498, -0.0091],
#         [-0.0091,  0.7445]])
# mu: tensor([-0.7441,  0.2635])
# cov: tensor([[ 0.4454, -0.0277],
#         [-0.0277,  0.7749]])
# mu: tensor([-0.7695,  0.5748])
# cov: tensor([[ 0.4480, -0.0581],
#         [-0.0581,  1.0625]])
# mu: tensor([-0.7282,  0.4203])
# cov: tensor([[ 0.4408, -0.0364],
#         [-0.0364,  1.3149]])
# mu: tensor([-0.7251,  0.5097])
# cov: tensor([[ 0.4393, -0.0597],
#         [-0.0597,  0.9916]])
# mu: tensor([-0.6923,  0.4548])
# cov: tensor([[ 0.4346, -0.0516],
#         [-0.0516,  0.9776]])
# mu: tensor([-0.7404,  0.5319])
# cov: tensor([[ 0.4495, -0.0748],
#         [-0.0748,  1.0136]])
# mu: tensor([-0.7228,  0.3362])
# cov: tensor([[ 0.4481, -0.0581],
#         [-0.0581,  0.8206]])
# mu: tensor([-0.7132,  0.4017])
# cov: tensor([[ 0.4458, -0.0624],
#         [-0.0624,  0.8553]])
# mu: tensor([-0.7105,  0.4330])
# cov: tensor([[ 0.4459, -0.0629],
#         [-0.0629,  0.8129]])
# mu: tensor([-0.6967,  0.2784])
# cov: tensor([[ 0.4444, -0.0476],
#         [-0.0476,  0.6930]])
# mu: tensor([-0.7175,  0.2668])
# cov: tensor([[ 0.4482, -0.0431],
#         [-0.0431,  0.6955]])
# mu: tensor([-0.7540,  0.2327])
# cov: tensor([[ 0.4538, -0.0390],
#         [-0.0390,  0.6981]])
# mu: tensor([-0.7353,  0.1154])
# cov: tensor([[ 0.4504, -0.0229],
#         [-0.0229,  0.6707]])
# mu: tensor([-0.6731,  0.0057])
# cov: tensor([[0.4373, 0.0010],
#         [0.0010, 0.6269]])
# mu: tensor([-0.7307,  0.0616])
# cov: tensor([[ 0.4513, -0.0060],
#         [-0.0060,  0.6219]])
# mu: tensor([-0.7446,  0.0023])
# cov: tensor([[0.4553, 0.0046],
#         [0.0046, 0.6228]])
# mu: tensor([-0.6807,  0.0917])
# cov: tensor([[ 0.4421, -0.0074],
#         [-0.0074,  0.6181]])
# mu: tensor([-0.7524,  0.1490])
# cov: tensor([[ 0.4579, -0.0222],
#         [-0.0222,  0.6312]])
# mu: tensor([-0.7958,  0.2003])
# cov: tensor([[ 0.4659, -0.0373],
#         [-0.0373,  0.6506]])
# mu: tensor([-0.8521,  0.1810])
# cov: tensor([[ 0.4839, -0.0309],
#         [-0.0309,  0.6529]])
# mu: tensor([-1.1235,  0.0636])
# cov: tensor([[ 0.5717, -0.0181],
#         [-0.0181,  0.6159]])
# mu: tensor([-0.9213, -0.0476])
# cov: tensor([[0.5148, 0.0139],
#         [0.0139, 0.5979]])
# mu: tensor([-0.7001, -0.0083])
# cov: tensor([[0.4428, 0.0085],
#         [0.0085, 0.6012]])
# mu: tensor([-0.7237,  0.1421])
# cov: tensor([[ 0.4510, -0.0357],
#         [-0.0357,  0.6518]])
# mu: tensor([-0.6930,  0.2728])
# cov: tensor([[ 0.4445, -0.0504],
#         [-0.0504,  0.6520]])
# mu: tensor([-0.7278,  0.4026])
# cov: tensor([[ 0.4491, -0.0615],
#         [-0.0615,  0.6529]])
# mu: tensor([-0.7787,  0.2960])
# cov: tensor([[ 0.4676, -0.0387],
#         [-0.0387,  0.6578]])
# mu: tensor([-0.8319,  0.3179])
# cov: tensor([[ 0.4769, -0.0437],
#         [-0.0437,  0.6601]])
# mu: tensor([-0.8342,  0.4524])
# cov: tensor([[ 0.4768, -0.0516],
#         [-0.0516,  0.6935]])
# mu: tensor([-0.8390,  0.3617])
# cov: tensor([[ 0.4797, -0.0361],
#         [-0.0361,  0.7076]])
# mu: tensor([-0.9323,  0.3610])
# cov: tensor([[ 0.5068, -0.0403],
#         [-0.0403,  0.7054]])
# mu: tensor([-0.9586,  0.3834])
# cov: tensor([[ 0.5121, -0.0430],
#         [-0.0430,  0.7046]])
# mu: tensor([-0.8905,  0.4112])
# cov: tensor([[ 0.4946, -0.0466],
#         [-0.0466,  0.7059]])
# mu: tensor([-0.7961,  0.1545])
# cov: tensor([[ 0.4750, -0.0118],
#         [-0.0118,  0.7908]])
# mu: tensor([-0.7253,  0.0453])
# cov: tensor([[ 4.6102e-01, -1.0483e-04],
#         [-1.0484e-04,  7.9835e-01]])
# mu: tensor([-0.7666,  0.1786])
# cov: tensor([[ 0.4715, -0.0310],
#         [-0.0310,  0.8865]])
# mu: tensor([-0.7453, -0.0110])
# cov: tensor([[ 0.4670, -0.0010],
#         [-0.0010,  0.7733]])
# mu: tensor([-0.8250, -0.0331])
# cov: tensor([[0.4927, 0.0101],
#         [0.0101, 0.7753]])
# mu: tensor([-0.8375, -0.0613])
# cov: tensor([[0.4950, 0.0144],
#         [0.0144, 0.7821]])
# mu: tensor([-0.8389, -0.0663])
# cov: tensor([[0.4954, 0.0154],
#         [0.0154, 0.7818]])
# mu: tensor([-0.8341, -0.1216])
# cov: tensor([[0.4936, 0.0280],
#         [0.0280, 0.7655]])
# mu: tensor([-0.8796, -0.2276])
# cov: tensor([[0.5024, 0.0388],
#         [0.0388, 0.7468]])
# mu: tensor([-0.9747, -0.7544])
# cov: tensor([[0.5194, 0.1300],
#         [0.1300, 0.9850]])
# mu: tensor([-0.8498, -0.3858])
# cov: tensor([[0.4949, 0.0679],
#         [0.0679, 0.8638]])
# mu: tensor([-0.8568, -0.1577])
# cov: tensor([[0.4974, 0.0402],
#         [0.0402, 0.8725]])
# mu: tensor([-0.8063, -0.1793])
# cov: tensor([[0.4883, 0.0442],
#         [0.0442, 0.8708]])
# mu: tensor([-0.7792, -0.1644])
# cov: tensor([[0.4850, 0.0432],
#         [0.0432, 0.8708]])
# mu: tensor([-0.7842, -0.0704])
# cov: tensor([[0.4868, 0.0254],
#         [0.0254, 0.8691]])
# mu: tensor([-0.8226, -0.2593])
# cov: tensor([[0.4925, 0.0449],
#         [0.0449, 0.9066]])
# mu: tensor([-0.7242, -0.2904])
# cov: tensor([[0.4580, 0.0617],
#         [0.0617, 0.9036]])
# mu: tensor([-0.8462, -0.5291])
# cov: tensor([[0.4922, 0.1165],
#         [0.1165, 0.9543]])
# mu: tensor([-0.7030, -0.2227])
# cov: tensor([[0.4595, 0.0492],
#         [0.0492, 0.8169]])
# mu: tensor([-0.7081, -0.5223])
# cov: tensor([[0.4578, 0.0879],
#         [0.0879, 0.8946]])
# mu: tensor([-0.7276, -0.6681])
# cov: tensor([[0.4599, 0.1132],
#         [0.1132, 0.9200]])
# mu: tensor([-0.7619, -0.5025])
# cov: tensor([[0.4713, 0.1000],
#         [0.1000, 0.8278]])
# mu: tensor([-0.6425, -0.4055])
# cov: tensor([[0.4353, 0.0656],
#         [0.0656, 0.7982]])
# mu: tensor([-0.7427, -0.4292])
# cov: tensor([[0.4616, 0.0948],
#         [0.0948, 0.7812]])
# mu: tensor([-0.7567, -0.2246])
# cov: tensor([[0.4717, 0.0411],
#         [0.0411, 0.8279]])
# mu: tensor([-0.8156, -0.2205])
# cov: tensor([[0.4912, 0.0456],
#         [0.0456, 0.8217]])
# mu: tensor([-0.8344, -0.2813])
# cov: tensor([[0.4931, 0.0554],
#         [0.0554, 0.8606]])
# mu: tensor([-0.8429, -0.2068])
# cov: tensor([[0.4967, 0.0410],
#         [0.0410, 0.8413]])
# mu: tensor([-0.8082, -0.2377])
# cov: tensor([[0.4891, 0.0444],
#         [0.0444, 0.8431]])
# mu: tensor([-0.7135, -0.0175])
# cov: tensor([[ 0.4617, -0.0084],
#         [-0.0084,  0.7636]])
# mu: tensor([-0.6955,  0.0640])
# cov: tensor([[ 0.4584, -0.0181],
#         [-0.0181,  0.7497]])
# mu: tensor([-0.7209,  0.0914])
# cov: tensor([[ 0.4625, -0.0241],
#         [-0.0241,  0.7573]])
# mu: tensor([-0.6776,  0.0547])
# cov: tensor([[ 0.4535, -0.0142],
#         [-0.0142,  0.7477]])
# mu: tensor([-0.6789,  0.1196])
# cov: tensor([[ 0.4536, -0.0268],
#         [-0.0268,  0.7623]])
# mu: tensor([-0.6748,  0.1600])
# cov: tensor([[ 0.4535, -0.0276],
#         [-0.0276,  0.7562]])
# mu: tensor([-0.7126,  0.1106])
# cov: tensor([[ 0.4610, -0.0222],
#         [-0.0222,  0.7555]])
# mu: tensor([-0.7012, -0.0054])
# cov: tensor([[ 0.4588, -0.0092],
#         [-0.0092,  0.7825]])
# mu: tensor([-0.7113, -0.1723])
# cov: tensor([[0.4606, 0.0186],
#         [0.0186, 0.7335]])
# mu: tensor([-0.7144, -0.0143])
# cov: tensor([[0.4616, 0.0022],
#         [0.0022, 0.6638]])
# mu: tensor([-0.6583, -0.0690])
# cov: tensor([[0.4516, 0.0160],
#         [0.0160, 0.6477]])
# mu: tensor([-0.6972, -0.1224])
# cov: tensor([[0.4609, 0.0221],
#         [0.0221, 0.6384]])
# mu: tensor([-0.7346, -0.0329])
# cov: tensor([[0.4669, 0.0087],
#         [0.0087, 0.6680]])
# mu: tensor([-0.6609, -0.0651])
# cov: tensor([[0.4514, 0.0046],
#         [0.0046, 0.6829]])
# mu: tensor([-0.7401, -0.1205])
# cov: tensor([[0.4722, 0.0155],
#         [0.0155, 0.6865]])
# mu: tensor([-0.7423, -0.1152])
# cov: tensor([[0.4724, 0.0153],
#         [0.0153, 0.6861]])
# mu: tensor([-0.7220, -0.0365])
# cov: tensor([[0.4685, 0.0048],
#         [0.0048, 0.6708]])
# mu: tensor([-0.7015, -0.0201])
# cov: tensor([[0.4625, 0.0009],
#         [0.0009, 0.6688]])
# mu: tensor([-7.8914e-01,  7.6490e-04])
# cov: tensor([[0.4922, 0.0026],
#         [0.0026, 0.6573]])
# mu: tensor([-0.7815, -0.0739])
# cov: tensor([[0.4903, 0.0137],
#         [0.0137, 0.6533]])
# mu: tensor([-0.7556, -0.0725])
# cov: tensor([[0.4845, 0.0121],
#         [0.0121, 0.6536]])
# mu: tensor([-0.7933, -0.1234])
# cov: tensor([[0.4911, 0.0194],
#         [0.0194, 0.6609]])
# mu: tensor([-0.6833, -0.1397])
# cov: tensor([[0.4631, 0.0206],
#         [0.0206, 0.6617]])
# mu: tensor([-0.7706, -0.0847])
# cov: tensor([[0.5007, 0.0073],
#         [0.0073, 0.6494]])
# mu: tensor([-0.7628, -0.1428])
# cov: tensor([[0.4991, 0.0138],
#         [0.0138, 0.6441]])
# mu: tensor([-0.6880, -0.2266])
# cov: tensor([[0.4743, 0.0206],
#         [0.0206, 0.6864]])
# mu: tensor([-0.6926, -0.0771])
# cov: tensor([[ 0.4769, -0.0090],
#         [-0.0090,  0.8296]])
# mu: tensor([-0.6664, -0.2669])
# cov: tensor([[0.4708, 0.0091],
#         [0.0091, 0.8891]])
# mu: tensor([-0.5436, -0.2128])
# cov: tensor([[ 0.4360, -0.0124],
#         [-0.0124,  0.8789]])
# mu: tensor([-0.5336, -0.3284])
# cov: tensor([[0.4344, 0.0020],
#         [0.0020, 0.7524]])
# mu: tensor([-0.7259, -0.5633])
# cov: tensor([[0.4916, 0.0540],
#         [0.0540, 0.7180]])
# mu: tensor([-0.6941, -0.5594])
# cov: tensor([[0.4840, 0.0555],
#         [0.0555, 0.7196]])
# mu: tensor([-0.7032, -0.4934])
# cov: tensor([[0.4880, 0.0460],
#         [0.0460, 0.7133]])
# mu: tensor([-0.7052, -0.6176])
# cov: tensor([[0.4880, 0.0493],
#         [0.0493, 0.6988]])
# mu: tensor([-0.6389, -0.4549])
# cov: tensor([[0.4755, 0.0230],
#         [0.0230, 0.6561]])
# mu: tensor([-0.6624, -0.5506])
# cov: tensor([[0.4776, 0.0438],
#         [0.0438, 0.5883]])
# mu: tensor([-0.6110, -0.7710])
# cov: tensor([[0.4627, 0.0502],
#         [0.0502, 0.6885]])
# mu: tensor([-0.5373, -0.9062])
# cov: tensor([[0.4479, 0.0318],
#         [0.0318, 0.7812]])
# mu: tensor([-0.5012, -0.8915])
# cov: tensor([[0.4408, 0.0292],
#         [0.0292, 0.7803]])
# mu: tensor([-0.4462, -0.7260])
# cov: tensor([[ 0.4426, -0.0323],
#         [-0.0323,  0.8863]])
# mu: tensor([-0.6507, -0.5198])
# cov: tensor([[ 0.5551, -0.0816],
#         [-0.0816,  0.8559]])
# mu: tensor([-0.6557, -0.4515])
# cov: tensor([[ 0.5671, -0.1321],
#         [-0.1321,  1.0456]])
# mu: tensor([-0.8565, -0.2617])
# cov: tensor([[ 0.6383, -0.1062],
#         [-0.1062,  0.8510]])
# mu: tensor([-0.6578, -0.4430])
# cov: tensor([[ 0.5612, -0.0710],
#         [-0.0710,  0.8666]])
# mu: tensor([-0.6754, -0.5306])
# cov: tensor([[ 0.5632, -0.0557],
#         [-0.0557,  0.8588]])
# mu: tensor([-0.6683, -0.6164])
# cov: tensor([[ 0.5620, -0.0514],
#         [-0.0514,  0.8721]])
# mu: tensor([-0.6783, -0.4927])
# cov: tensor([[ 0.5637, -0.0549],
#         [-0.0549,  0.8204]])
# mu: tensor([-0.7102, -0.1551])
# cov: tensor([[ 0.6139, -0.2974],
#         [-0.2974,  1.8590]])
# mu: tensor([-0.8559,  0.3081])
# cov: tensor([[ 0.6747, -0.4025],
#         [-0.4025,  1.8222]])
# mu: tensor([-0.7924,  0.0347])
# cov: tensor([[ 0.6414, -0.2789],
#         [-0.2789,  1.3863]])
# mu: tensor([-0.6252, -0.3015])
# cov: tensor([[ 0.5505, -0.1236],
#         [-0.1236,  1.1393]])
# mu: tensor([-0.6611, -0.2092])
# cov: tensor([[ 0.5647, -0.1302],
#         [-0.1302,  1.0673]])
# mu: tensor([-0.6631, -0.0341])
# cov: tensor([[ 0.5688, -0.1646],
#         [-0.1646,  1.0219]])
# mu: tensor([-0.5446, -0.0867])
# cov: tensor([[ 0.5275, -0.1511],
#         [-0.1511,  1.0189]])
# mu: tensor([-0.6510,  0.3510])
# cov: tensor([[ 0.5850, -0.3129],
#         [-0.3129,  1.2719]])
# mu: tensor([-0.5036, -0.1113])
# cov: tensor([[ 0.5239, -0.1857],
#         [-0.1857,  1.1311]])
# mu: tensor([-0.5073, -0.2153])
# cov: tensor([[ 0.5179, -0.1281],
#         [-0.1281,  0.8055]])
# mu: tensor([-0.4442, -0.2557])
# cov: tensor([[ 0.4996, -0.1278],
#         [-0.1278,  0.8167]])
# mu: tensor([-0.4444, -0.3113])
# cov: tensor([[ 0.4994, -0.1250],
#         [-0.1250,  0.8352]])
# mu: tensor([-0.4542, -0.2738])
# cov: tensor([[ 0.5022, -0.1309],
#         [-0.1309,  0.8428]])
# mu: tensor([-0.4061, -0.5766])
# cov: tensor([[ 0.4993, -0.1376],
#         [-0.1376,  0.9941]])
# mu: tensor([-0.4957, -0.6373])
# cov: tensor([[ 0.5259, -0.1223],
#         [-0.1223,  0.8870]])
# mu: tensor([-0.5053, -0.4908])
# cov: tensor([[ 0.5307, -0.1412],
#         [-0.1412,  0.9073]])
# mu: tensor([-0.5323, -0.5463])
# cov: tensor([[ 0.5357, -0.1220],
#         [-0.1220,  0.8773]])
# mu: tensor([-0.4170, -0.6031])
# cov: tensor([[ 0.4903, -0.1105],
#         [-0.1105,  0.8792]])
# mu: tensor([-0.4157, -0.5448])
# cov: tensor([[ 0.4903, -0.1125],
#         [-0.1125,  0.8555]])
# mu: tensor([-0.4230, -0.4631])
# cov: tensor([[ 0.4900, -0.1095],
#         [-0.1095,  0.8187]])
# mu: tensor([-0.4139, -0.3760])
# cov: tensor([[ 0.4899, -0.1224],
#         [-0.1224,  0.8280]])
# mu: tensor([-0.3839, -0.3497])
# cov: tensor([[ 0.4795, -0.1291],
#         [-0.1291,  0.8726]])
# mu: tensor([-0.3896, -0.2133])
# cov: tensor([[ 0.4851, -0.1627],
#         [-0.1627,  0.9867]])
# mu: tensor([-0.3371, -0.3128])
# cov: tensor([[ 0.4737, -0.1574],
#         [-0.1574,  1.0087]])
# mu: tensor([-0.3884, -0.2086])
# cov: tensor([[ 0.4868, -0.1720],
#         [-0.1720,  1.0133]])
# mu: tensor([-0.3411, -0.3537])
# cov: tensor([[ 0.4843, -0.1783],
#         [-0.1783,  1.0733]])
# mu: tensor([-0.4372, -0.3907])
# cov: tensor([[ 0.5124, -0.1643],
#         [-0.1643,  1.0795]])
# mu: tensor([-0.4315, -0.0231])
# cov: tensor([[ 0.5139, -0.1995],
#         [-0.1995,  0.9758]])
# mu: tensor([-0.4216, -0.0178])
# cov: tensor([[ 0.5109, -0.1969],
#         [-0.1969,  0.9880]])
# mu: tensor([-0.5214, -0.1954])
# cov: tensor([[ 0.5489, -0.1467],
#         [-0.1467,  0.8383]])
# mu: tensor([-0.4984, -0.1781])
# cov: tensor([[ 0.5422, -0.1438],
#         [-0.1438,  0.8896]])
# mu: tensor([-0.5999, -0.4285])
# cov: tensor([[ 0.5725, -0.0744],
#         [-0.0744,  0.9241]])
# mu: tensor([-0.5591, -0.2067])
# cov: tensor([[ 0.5658, -0.1120],
#         [-0.1120,  0.9845]])
# mu: tensor([-0.6484, -0.2378])
# cov: tensor([[ 0.5954, -0.1159],
#         [-0.1159,  0.9621]])
# mu: tensor([-0.5879, -0.2271])
# cov: tensor([[ 0.5770, -0.1188],
#         [-0.1188,  0.9617]])
# mu: tensor([-0.5663, -0.2638])
# cov: tensor([[ 0.5737, -0.1117],
#         [-0.1117,  0.9469]])
# mu: tensor([-0.5351, -0.2920])
# cov: tensor([[ 0.5637, -0.1103],
#         [-0.1103,  0.9557]])
# mu: tensor([-0.5726, -0.1072])
# cov: tensor([[ 0.5683, -0.1199],
#         [-0.1199,  0.9439]])
# mu: tensor([-0.5716,  0.0466])
# cov: tensor([[ 0.5713, -0.1634],
#         [-0.1634,  0.9782]])
# mu: tensor([-0.5534, -0.2969])
# cov: tensor([[ 0.5671, -0.1485],
#         [-0.1485,  1.3447]])
# mu: tensor([-0.5510, -0.2203])
# cov: tensor([[ 0.5671, -0.1560],
#         [-0.1560,  1.2909]])
# mu: tensor([-0.5354, -0.3424])
# cov: tensor([[ 0.5611, -0.1325],
#         [-0.1325,  1.2444]])
# mu: tensor([-0.5547, -0.4214])
# cov: tensor([[ 0.5647, -0.1067],
#         [-0.1067,  1.2011]])
# mu: tensor([-0.4988, -0.4712])
# cov: tensor([[ 0.5472, -0.0833],
#         [-0.0833,  1.1755]])
# mu: tensor([-0.5156, -0.1364])
# cov: tensor([[ 0.5485, -0.0932],
#         [-0.0932,  1.1468]])
# mu: tensor([-0.6061, -0.4307])
# cov: tensor([[5.7048e-01, 1.1864e-03],
#         [1.1867e-03, 1.4854e+00]])
# mu: tensor([-0.5928, -0.2136])
# cov: tensor([[ 0.5690, -0.0304],
#         [-0.0304,  1.5386]])
# mu: tensor([-0.5821, -0.3448])
# cov: tensor([[ 0.5648, -0.0138],
#         [-0.0138,  1.6282]])
# mu: tensor([-0.3163, -1.6096])
# cov: tensor([[ 0.4561, -0.1107],
#         [-0.1107,  4.0618]])
# mu: tensor([-0.3991, -0.2020])
# cov: tensor([[ 0.4628, -0.0239],
#         [-0.0239,  1.2520]])
# mu: tensor([-0.3654, -0.5149])
# cov: tensor([[0.4539, 0.0108],
#         [0.0108, 1.2516]])
# mu: tensor([-0.3312, -0.3843])
# cov: tensor([[ 0.4506, -0.0116],
#         [-0.0116,  1.1437]])
# mu: tensor([-0.3440, -0.3896])
# cov: tensor([[ 0.4522, -0.0125],
#         [-0.0125,  1.1422]])
# mu: tensor([-0.3719, -0.2479])
# cov: tensor([[ 0.4599, -0.0298],
#         [-0.0298,  1.1345]])
# mu: tensor([-0.3612, -0.2749])
# cov: tensor([[ 0.4587, -0.0296],
#         [-0.0296,  1.1408]])
# mu: tensor([-0.3091, -0.2318])
# cov: tensor([[ 0.4383, -0.0485],
#         [-0.0485,  1.1237]])
# mu: tensor([-0.3159, -0.2357])
# cov: tensor([[ 0.4389, -0.0509],
#         [-0.0509,  1.1184]])
# mu: tensor([-0.4603, -0.0488])
# cov: tensor([[ 0.5114, -0.1038],
#         [-0.1038,  1.1129]])
# mu: tensor([-0.4541, -0.3106])
# cov: tensor([[ 0.5050, -0.0483],
#         [-0.0483,  1.0534]])
# mu: tensor([-0.4410, -0.3461])
# cov: tensor([[ 0.5013, -0.0420],
#         [-0.0420,  1.0467]])
# mu: tensor([-0.4473, -0.2193])
# cov: tensor([[ 0.5025, -0.0496],
#         [-0.0496,  1.0130]])
# mu: tensor([-0.4247, -0.3253])
# cov: tensor([[ 0.4966, -0.0347],
#         [-0.0347,  0.9978]])
# mu: tensor([-0.4144, -0.3934])
# cov: tensor([[ 0.4945, -0.0312],
#         [-0.0312,  1.0234]])
# mu: tensor([-0.4087, -0.3084])
# cov: tensor([[ 0.4944, -0.0452],
#         [-0.0452,  1.0141]])
# mu: tensor([-0.4655, -0.3011])
# cov: tensor([[ 0.5147, -0.0375],
#         [-0.0375,  1.0068]])
# mu: tensor([-0.4284, -0.4075])
# cov: tensor([[ 0.5054, -0.0127],
#         [-0.0127,  0.9408]])
# mu: tensor([-0.4638, -0.0941])
# cov: tensor([[ 0.5149, -0.0355],
#         [-0.0355,  0.7808]])
# mu: tensor([-0.4366, -0.1176])
# cov: tensor([[ 0.5067, -0.0267],
#         [-0.0267,  0.7719]])
# mu: tensor([-0.4291, -0.1388])
# cov: tensor([[ 0.5054, -0.0223],
#         [-0.0223,  0.7577]])
# mu: tensor([-0.4814, -0.0540])
# cov: tensor([[ 0.5290, -0.0429],
#         [-0.0429,  0.7516]])
# mu: tensor([-0.4849, -0.1471])
# cov: tensor([[ 0.5291, -0.0255],
#         [-0.0255,  0.7333]])
# mu: tensor([-0.5383, -0.1969])
# cov: tensor([[ 0.5441, -0.0129],
#         [-0.0129,  0.7437]])
# mu: tensor([-0.5420, -0.0983])
# cov: tensor([[ 0.5442, -0.0149],
#         [-0.0149,  0.7729]])
# mu: tensor([-0.5152, -0.1688])
# cov: tensor([[ 0.5385, -0.0052],
#         [-0.0052,  0.7626]])
# mu: tensor([-0.5098, -0.2656])
# cov: tensor([[0.5348, 0.0175],
#         [0.0175, 0.7056]])
# mu: tensor([-0.4762, -0.2570])
# cov: tensor([[0.5287, 0.0181],
#         [0.0181, 0.7067]])
# mu: tensor([-0.5794, -0.3458])
# cov: tensor([[0.5641, 0.0365],
#         [0.0365, 0.7008]])
# mu: tensor([-0.5350, -0.2090])
# cov: tensor([[0.5578, 0.0169],
#         [0.0169, 0.6397]])
# mu: tensor([-0.5025, -0.2166])
# cov: tensor([[0.5490, 0.0170],
#         [0.0170, 0.6404]])
# mu: tensor([-0.4568, -0.2710])
# cov: tensor([[0.5308, 0.0322],
#         [0.0322, 0.6311]])
# mu: tensor([-0.4735, -0.2457])
# cov: tensor([[0.5376, 0.0243],
#         [0.0243, 0.6389]])
# mu: tensor([-0.4300, -0.4202])
# cov: tensor([[0.5149, 0.0595],
#         [0.0595, 0.6575]])
# mu: tensor([-0.4536, -0.3998])
# cov: tensor([[0.5197, 0.0530],
#         [0.0530, 0.6650]])
# mu: tensor([-0.4036, -0.2857])
# cov: tensor([[0.5093, 0.0344],
#         [0.0344, 0.6404]])
# mu: tensor([-0.3868, -0.1808])
# cov: tensor([[0.5058, 0.0123],
#         [0.0123, 0.6217]])
# mu: tensor([-0.3865, -0.2170])
# cov: tensor([[0.5052, 0.0177],
#         [0.0177, 0.6331]])
# mu: tensor([-0.3767, -0.1893])
# cov: tensor([[0.5047, 0.0221],
#         [0.0221, 0.6762]])
# mu: tensor([-0.3941, -0.2468])
# cov: tensor([[0.5087, 0.0316],
#         [0.0316, 0.6880]])
# mu: tensor([-0.4433, -0.2642])
# cov: tensor([[0.5198, 0.0368],
#         [0.0368, 0.6902]])
# mu: tensor([-0.3590, -0.1629])
# cov: tensor([[0.4972, 0.0189],
#         [0.0189, 0.6838]])
# mu: tensor([-0.4412, -0.0034])
# cov: tensor([[ 0.5336, -0.0388],
#         [-0.0388,  0.7677]])
# mu: tensor([-0.4051,  0.0447])
# cov: tensor([[ 0.5207, -0.0431],
#         [-0.0431,  0.7926]])
# mu: tensor([-0.4161,  0.0106])
# cov: tensor([[ 0.5260, -0.0351],
#         [-0.0351,  0.7701]])
# mu: tensor([-0.3437,  0.0469])
# cov: tensor([[ 0.4980, -0.0390],
#         [-0.0390,  0.7767]])
# mu: tensor([-0.4132,  0.1100])
# cov: tensor([[ 0.5250, -0.0500],
#         [-0.0500,  0.7667]])
# mu: tensor([-0.5836,  0.1400])
# cov: tensor([[ 0.6054, -0.0590],
#         [-0.0590,  0.7667]])
# mu: tensor([-0.5880,  0.2843])
# cov: tensor([[ 0.6058, -0.0733],
#         [-0.0733,  0.8481]])
# mu: tensor([-0.5538,  0.2156])
# cov: tensor([[ 0.5985, -0.0582],
#         [-0.0582,  0.8166]])
# mu: tensor([-0.4657,  0.0265])
# cov: tensor([[ 0.5730, -0.0274],
#         [-0.0274,  0.8286]])
# mu: tensor([-0.4178,  0.0676])
# cov: tensor([[ 0.5601, -0.0427],
#         [-0.0427,  0.8127]])
# mu: tensor([-0.4769,  0.1531])
# cov: tensor([[ 0.5855, -0.0749],
#         [-0.0749,  0.8514]])
# mu: tensor([-0.5256,  0.1890])
# cov: tensor([[ 0.6112, -0.0974],
#         [-0.0974,  0.8694]])
# mu: tensor([-0.4713,  0.1766])
# cov: tensor([[ 0.5984, -0.0987],
#         [-0.0987,  0.8714]])
# mu: tensor([-0.4742,  0.1025])
# cov: tensor([[ 0.6007, -0.0770],
#         [-0.0770,  0.8596]])
# mu: tensor([-0.4570,  0.1274])
# cov: tensor([[ 0.5967, -0.0847],
#         [-0.0847,  0.8459]])
# mu: tensor([-0.4679, -0.0861])
# cov: tensor([[ 0.5994, -0.0508],
#         [-0.0508,  0.8782]])
# mu: tensor([-0.4438, -0.2844])
# cov: tensor([[ 0.5888, -0.0212],
#         [-0.0212,  0.9670]])
# mu: tensor([-0.5264, -0.0708])
# cov: tensor([[ 0.6317, -0.1071],
#         [-0.1071,  1.1208]])
# mu: tensor([-0.8610,  0.1666])
# cov: tensor([[ 0.8200, -0.2182],
#         [-0.2182,  1.1755]])
# mu: tensor([-0.7630,  0.1746])
# cov: tensor([[ 0.7896, -0.2186],
#         [-0.2186,  1.1758]])
# mu: tensor([-0.7239,  0.1201])
# cov: tensor([[ 0.7894, -0.2425],
#         [-0.2425,  1.2675]])
# mu: tensor([-0.5337,  0.1786])
# cov: tensor([[ 0.6638, -0.2273],
#         [-0.2273,  1.4156]])
# mu: tensor([-0.5129,  0.1765])
# cov: tensor([[ 0.6602, -0.2285],
#         [-0.2285,  1.4161]])
# mu: tensor([-0.4885,  0.2346])
# cov: tensor([[ 0.6540, -0.2345],
#         [-0.2345,  1.4286]])
# mu: tensor([-0.4336,  0.0050])
# cov: tensor([[ 0.6334, -0.1505],
#         [-0.1505,  1.0855]])
# mu: tensor([-0.5542, -0.1160])
# cov: tensor([[ 0.6874, -0.1282],
#         [-0.1282,  1.0320]])
# mu: tensor([-0.6630,  0.0991])
# cov: tensor([[ 0.7215, -0.1350],
#         [-0.1350,  0.8727]])
# mu: tensor([-0.6979,  0.0689])
# cov: tensor([[ 0.7269, -0.1212],
#         [-0.1212,  0.8866]])
# mu: tensor([-0.6730, -0.1613])
# cov: tensor([[ 0.7138, -0.0666],
#         [-0.0666,  0.9026]])
# mu: tensor([-0.6718, -0.1907])
# cov: tensor([[ 0.7138, -0.0661],
#         [-0.0661,  0.9082]])
# mu: tensor([-0.6452, -0.0380])
# cov: tensor([[ 0.7085, -0.0849],
#         [-0.0849,  0.9399]])
# mu: tensor([-0.6524, -0.0019])
# cov: tensor([[ 0.7094, -0.0879],
#         [-0.0879,  0.9491]])
# mu: tensor([-0.6310,  0.0794])
# cov: tensor([[ 0.7000, -0.1156],
#         [-0.1156,  0.8977]])
# mu: tensor([-0.5063,  0.0420])
# cov: tensor([[ 0.6491, -0.1171],
#         [-0.1171,  0.9103]])
# mu: tensor([-0.4506,  0.0316])
# cov: tensor([[ 0.6308, -0.0966],
#         [-0.0966,  0.9158]])
# mu: tensor([-0.5103,  0.0517])
# cov: tensor([[ 0.6558, -0.1087],
#         [-0.1087,  0.9205]])
# mu: tensor([-0.5836,  0.1663])
# cov: tensor([[ 0.6858, -0.1587],
#         [-0.1587,  1.0031]])
# mu: tensor([-0.5452,  0.2343])
# cov: tensor([[ 0.6740, -0.1772],
#         [-0.1772,  0.9747]])
# mu: tensor([-0.5183,  0.1261])
# cov: tensor([[ 0.6683, -0.1586],
#         [-0.1586,  0.9213]])
# mu: tensor([-0.4880,  0.1493])
# cov: tensor([[ 0.6641, -0.1716],
#         [-0.1716,  0.9095]])
# mu: tensor([-0.3916,  0.0133])
# cov: tensor([[ 0.6031, -0.1103],
#         [-0.1103,  0.8777]])
# mu: tensor([-0.4399,  0.1632])
# cov: tensor([[ 0.6195, -0.1377],
#         [-0.1377,  0.8663]])
# mu: tensor([-0.3810,  0.1353])
# cov: tensor([[ 0.5988, -0.1246],
#         [-0.1246,  0.8589]])
# mu: tensor([-0.4783,  0.2259])
# cov: tensor([[ 0.6533, -0.1499],
#         [-0.1499,  0.8316]])
# mu: tensor([-0.4916,  0.2223])
# cov: tensor([[ 0.6576, -0.1514],
#         [-0.1514,  0.8294]])
# mu: tensor([-0.5145,  0.1812])
# cov: tensor([[ 0.6611, -0.1450],
#         [-0.1450,  0.8413]])
# mu: tensor([-0.4442,  0.1295])
# cov: tensor([[ 0.6298, -0.1181],
#         [-0.1181,  0.8193]])
# mu: tensor([-0.3947,  0.1117])
# cov: tensor([[ 0.6158, -0.1041],
#         [-0.1041,  0.8141]])
# mu: tensor([-0.3699,  0.0923])
# cov: tensor([[ 0.6102, -0.1172],
#         [-0.1172,  0.8591]])
# mu: tensor([-0.3265,  0.0178])
# cov: tensor([[ 0.5880, -0.0943],
#         [-0.0943,  0.8561]])
# mu: tensor([-0.3018, -0.1677])
# cov: tensor([[ 0.5780, -0.0712],
#         [-0.0712,  1.0146]])
# mu: tensor([-0.4105, -0.1887])
# cov: tensor([[ 0.6332, -0.0767],
#         [-0.0767,  1.0039]])
# mu: tensor([-0.3593, -0.2306])
# cov: tensor([[ 0.6035, -0.0350],
#         [-0.0350,  0.9654]])
# mu: tensor([-0.3170, -0.1274])
# cov: tensor([[ 0.5954, -0.0533],
#         [-0.0533,  0.9243]])
# mu: tensor([-0.3442,  0.0454])
# cov: tensor([[ 0.5986, -0.0649],
#         [-0.0649,  0.9448]])
# mu: tensor([-0.2991, -0.2184])
# cov: tensor([[ 0.5785, -0.0179],
#         [-0.0179,  1.0697]])
# mu: tensor([-0.4243, -0.4027])
# cov: tensor([[0.6478, 0.0567],
#         [0.0567, 0.9870]])
# mu: tensor([-0.4868, -0.3191])
# cov: tensor([[0.6846, 0.0153],
#         [0.0153, 1.0313]])
# mu: tensor([-0.5285, -0.2633])
# cov: tensor([[ 0.6985, -0.0060],
#         [-0.0060,  1.0633]])
# mu: tensor([-0.5155, -0.1907])
# cov: tensor([[ 0.6966, -0.0143],
#         [-0.0143,  1.0353]])
# mu: tensor([-0.4989, -0.3217])
# cov: tensor([[ 0.6939, -0.0075],
#         [-0.0075,  1.0740]])
# mu: tensor([-0.5481, -0.2693])
# cov: tensor([[7.0518e-01, 6.5502e-04],
#         [6.5484e-04, 1.0363e+00]])
# mu: tensor([-0.5314, -0.2234])
# cov: tensor([[ 0.6995, -0.0105],
#         [-0.0105,  1.0311]])
# mu: tensor([-0.4671, -0.2576])
# cov: tensor([[ 0.6668, -0.0172],
#         [-0.0172,  1.0633]])
# mu: tensor([-0.5193, -0.4603])
# cov: tensor([[0.6792, 0.0185],
#         [0.0185, 0.9681]])
# mu: tensor([-0.6773, -0.4267])
# cov: tensor([[0.7671, 0.0256],
#         [0.0256, 0.9503]])
# mu: tensor([-0.6588, -0.1577])
# cov: tensor([[ 0.7692, -0.0442],
#         [-0.0442,  0.8573]])
# mu: tensor([-0.6654, -0.1220])
# cov: tensor([[ 0.7714, -0.0506],
#         [-0.0506,  0.8640]])
# mu: tensor([-0.6117, -0.1362])
# cov: tensor([[ 0.7489, -0.0471],
#         [-0.0471,  0.8641]])
# mu: tensor([-0.6328, -0.1354])
# cov: tensor([[ 0.7580, -0.0490],
#         [-0.0490,  0.8639]])
# mu: tensor([-0.6385, -0.2564])
# cov: tensor([[ 0.7583, -0.0320],
#         [-0.0320,  0.8748]])
# mu: tensor([-0.5507, -0.2116])
# cov: tensor([[ 0.7145, -0.0374],
#         [-0.0374,  0.9069]])
# mu: tensor([-0.4632, -0.1765])
# cov: tensor([[ 0.6594, -0.0546],
#         [-0.0546,  0.9038]])
# mu: tensor([-0.4390, -0.4610])
# cov: tensor([[0.6310, 0.0154],
#         [0.0154, 1.1202]])
# mu: tensor([-0.3768, -0.1465])
# cov: tensor([[ 0.6174, -0.0304],
#         [-0.0304,  1.1850]])
# mu: tensor([-0.4193, -0.0627])
# cov: tensor([[ 0.6358, -0.0445],
#         [-0.0445,  1.1569]])
# mu: tensor([-0.3882, -0.1429])
# cov: tensor([[ 0.6292, -0.0260],
#         [-0.0260,  1.1056]])
# mu: tensor([-0.2870, -0.1972])
# cov: tensor([[0.5792, 0.0026],
#         [0.0026, 1.0894]])
# mu: tensor([-0.2868, -0.0042])
# cov: tensor([[ 0.5809, -0.0414],
#         [-0.0414,  1.1326]])
# mu: tensor([-0.3437, -0.2450])
# cov: tensor([[ 5.9712e-01, -2.3570e-04],
#         [-2.3599e-04,  1.1344e+00]])
# mu: tensor([-0.2851, -0.2291])
# cov: tensor([[ 0.5728, -0.0244],
#         [-0.0244,  1.1317]])
# mu: tensor([-0.2970, -0.1619])
# cov: tensor([[ 0.5822, -0.0415],
#         [-0.0415,  1.0828]])
# mu: tensor([-0.3528, -0.2248])
# cov: tensor([[ 0.6126, -0.0289],
#         [-0.0289,  1.0239]])
# mu: tensor([-0.3685, -0.1565])
# cov: tensor([[ 0.6185, -0.0503],
#         [-0.0503,  1.0994]])
# mu: tensor([-0.4428, -0.1296])
# cov: tensor([[ 0.6465, -0.0718],
#         [-0.0718,  1.1081]])
# mu: tensor([-0.4349, -0.0891])
# cov: tensor([[ 0.6450, -0.0769],
#         [-0.0769,  1.1047]])
# mu: tensor([-0.3743, -0.1811])
# cov: tensor([[ 0.6157, -0.0365],
#         [-0.0365,  1.0497]])
# mu: tensor([-0.5686,  0.1182])
# cov: tensor([[ 0.7559, -0.2577],
#         [-0.2577,  1.3982]])
# mu: tensor([-0.5149, -0.0071])
# cov: tensor([[ 0.7633, -0.3180],
#         [-0.3180,  1.6699]])
# mu: tensor([-0.5021,  0.1432])
# cov: tensor([[ 0.7605, -0.4041],
#         [-0.4041,  2.1556]])
# mu: tensor([-0.4221, -0.0394])
# cov: tensor([[ 0.7111, -0.2798],
#         [-0.2798,  1.8479]])
# mu: tensor([-0.3011, -0.2428])
# cov: tensor([[ 0.6420, -0.1800],
#         [-0.1800,  1.7098]])
# mu: tensor([-0.4156, -0.1862])
# cov: tensor([[ 0.7244, -0.2774],
#         [-0.2774,  1.7049]])
# mu: tensor([-0.6151, -0.0160])
# cov: tensor([[ 0.9110, -0.4075],
#         [-0.4076,  1.7791]])
# mu: tensor([-0.6047, -0.0510])
# cov: tensor([[ 0.9091, -0.4150],
#         [-0.4150,  1.8555]])
# mu: tensor([-0.6747,  0.2738])
# cov: tensor([[ 0.9370, -0.5236],
#         [-0.5236,  2.2601]])
# mu: tensor([-0.7907,  0.8047])
# cov: tensor([[ 1.0015, -0.7367],
#         [-0.7367,  2.5329]])
# mu: tensor([-0.2715,  0.1756])
# cov: tensor([[ 0.5864, -0.2178],
#         [-0.2178,  1.8872]])
# mu: tensor([-0.2902,  0.1268])
# cov: tensor([[ 0.5892, -0.2085],
#         [-0.2085,  1.9167]])
# mu: tensor([-0.2712,  0.0824])
# cov: tensor([[ 0.5806, -0.1997],
#         [-0.1997,  1.9311]])
# mu: tensor([-0.2290,  0.0856])
# cov: tensor([[ 0.5687, -0.1900],
#         [-0.1900,  1.9355]])
# mu: tensor([-0.2719,  0.2314])
# cov: tensor([[ 0.5777, -0.1640],
#         [-0.1640,  1.5321]])
# mu: tensor([-0.3681,  0.4670])
# cov: tensor([[ 0.6423, -0.3103],
#         [-0.3103,  1.8516]])
# mu: tensor([-0.3005,  0.0452])
# cov: tensor([[ 0.6303, -0.2616],
#         [-0.2616,  1.7383]])
# mu: tensor([-0.2929, -0.0733])
# cov: tensor([[ 0.6225, -0.2101],
#         [-0.2101,  1.6790]])
# mu: tensor([-0.3363,  0.3341])
# cov: tensor([[ 0.6238, -0.1838],
#         [-0.1838,  0.9908]])
# mu: tensor([-0.3002,  0.2080])
# cov: tensor([[ 0.6145, -0.1618],
#         [-0.1618,  0.9653]])
# mu: tensor([-0.4169,  0.2515])
# cov: tensor([[ 0.7165, -0.2095],
#         [-0.2095,  0.9843]])
# mu: tensor([-0.4921,  0.5793])
# cov: tensor([[ 0.7455, -0.3392],
#         [-0.3392,  1.1238]])
# mu: tensor([-0.4523,  0.4299])
# cov: tensor([[ 0.7352, -0.3055],
#         [-0.3055,  1.0242]])
# mu: tensor([-0.4099,  0.2866])
# cov: tensor([[ 0.7331, -0.3020],
#         [-0.3020,  1.0257]])
# mu: tensor([-0.5958,  0.5328])
# cov: tensor([[ 0.8370, -0.3861],
#         [-0.3861,  0.9584]])
# mu: tensor([-0.6003,  0.5399])
# cov: tensor([[ 0.8377, -0.3868],
#         [-0.3868,  0.9589]])
# mu: tensor([-0.5394,  0.4381])
# cov: tensor([[ 0.8358, -0.4218],
#         [-0.4218,  1.1399]])
# mu: tensor([-0.3978,  0.2420])
# cov: tensor([[ 0.7462, -0.3045],
#         [-0.3045,  0.9882]])
# mu: tensor([-0.2969, -0.0154])
# cov: tensor([[ 0.6746, -0.1745],
#         [-0.1745,  0.8377]])
# mu: tensor([-0.3785, -0.0528])
# cov: tensor([[ 0.7171, -0.1620],
#         [-0.1620,  0.8389]])
# mu: tensor([-0.3910, -0.0975])
# cov: tensor([[ 0.7181, -0.1568],
#         [-0.1568,  0.8629]])
# mu: tensor([-0.3925, -0.0888])
# cov: tensor([[ 0.7199, -0.1613],
#         [-0.1613,  0.8646]])
# mu: tensor([-0.3807, -0.0191])
# cov: tensor([[ 0.7195, -0.1671],
#         [-0.1671,  0.8125]])
# mu: tensor([-0.3248, -0.1575])
# cov: tensor([[ 0.7042, -0.1565],
#         [-0.1565,  0.8539]])
# mu: tensor([-0.3110, -0.1470])
# cov: tensor([[ 0.6989, -0.1556],
#         [-0.1556,  0.8635]])
# mu: tensor([-0.2843, -0.1734])
# cov: tensor([[ 0.6905, -0.1476],
#         [-0.1476,  0.8560]])
# mu: tensor([-0.4357, -0.0826])
# cov: tensor([[ 0.7857, -0.1847],
#         [-0.1847,  0.8632]])
# mu: tensor([-0.4723, -0.1478])
# cov: tensor([[ 0.8061, -0.1547],
#         [-0.1547,  0.8344]])
# mu: tensor([-0.4988, -0.0679])
# cov: tensor([[ 0.8117, -0.1585],
#         [-0.1585,  0.8073]])
# mu: tensor([-0.4972, -0.0636])
# cov: tensor([[ 0.8117, -0.1585],
#         [-0.1585,  0.8074]])
# mu: tensor([-0.4932, -0.1139])
# cov: tensor([[ 0.8080, -0.1424],
#         [-0.1424,  0.7904]])
# mu: tensor([-0.5582, -0.0870])
# cov: tensor([[ 0.8473, -0.1575],
#         [-0.1575,  0.7961]])
# mu: tensor([-0.4206, -0.1066])
# cov: tensor([[ 0.7423, -0.1204],
#         [-0.1204,  0.8028]])
# mu: tensor([-0.4433, -0.0588])
# cov: tensor([[ 0.7445, -0.1216],
#         [-0.1216,  0.7975]])
# mu: tensor([-0.3653, -0.0954])
# cov: tensor([[ 0.7277, -0.1427],
#         [-0.1427,  0.8326]])
# mu: tensor([-0.4614,  0.0412])
# cov: tensor([[ 0.7704, -0.1946],
#         [-0.1946,  0.8932]])
# mu: tensor([-0.4682,  0.1724])
# cov: tensor([[ 0.7752, -0.2432],
#         [-0.2432,  0.9484]])
# mu: tensor([-0.5171,  0.2677])
# cov: tensor([[ 0.8041, -0.2976],
#         [-0.2976,  1.0506]])
# mu: tensor([-0.7432,  0.2574])
# cov: tensor([[ 0.9476, -0.2868],
#         [-0.2868,  1.0510]])
# mu: tensor([-0.6057,  0.3905])
# cov: tensor([[ 0.8663, -0.3082],
#         [-0.3082,  1.1382]])
# mu: tensor([-0.6139,  0.3672])
# cov: tensor([[ 0.8612, -0.2987],
#         [-0.2987,  1.1978]])
# mu: tensor([-0.5361,  0.1388])
# cov: tensor([[ 0.8067, -0.1729],
#         [-0.1729,  1.1919]])
# mu: tensor([-0.5350, -0.0859])
# cov: tensor([[ 0.8050, -0.1227],
#         [-0.1227,  1.1455]])
# mu: tensor([-0.5378, -0.1823])
# cov: tensor([[ 0.8051, -0.1084],
#         [-0.1084,  1.2305]])
# mu: tensor([-0.4725, -0.2119])
# cov: tensor([[ 0.7653, -0.0811],
#         [-0.0811,  1.2172]])
# mu: tensor([-0.4139, -0.2677])
# cov: tensor([[ 0.7383, -0.0530],
#         [-0.0530,  1.1883]])
# mu: tensor([-0.3263, -0.2237])
# cov: tensor([[ 0.6924, -0.0637],
#         [-0.0637,  1.1939]])
# mu: tensor([-0.3350, -0.1760])
# cov: tensor([[ 0.6965, -0.0716],
#         [-0.0716,  1.1735]])
# mu: tensor([-0.3449, -0.1538])
# cov: tensor([[ 0.7024, -0.0799],
#         [-0.0799,  1.1808]])
# mu: tensor([-0.2942, -0.1401])
# cov: tensor([[ 0.6685, -0.0767],
#         [-0.0767,  1.1921]])
# mu: tensor([-0.2706,  0.0325])
# cov: tensor([[ 0.6590, -0.1221],
#         [-0.1221,  1.2200]])
# mu: tensor([-0.2884,  0.1087])
# cov: tensor([[ 0.6688, -0.1524],
#         [-0.1524,  1.2893]])
# mu: tensor([-0.2665,  0.0697])
# cov: tensor([[ 0.6635, -0.1465],
#         [-0.1465,  1.2857]])
# mu: tensor([-0.2751,  0.0068])
# cov: tensor([[ 0.6677, -0.1315],
#         [-0.1315,  1.2314]])
# mu: tensor([-0.3216,  0.0598])
# cov: tensor([[ 0.6726, -0.0955],
#         [-0.0955,  1.1088]])
# mu: tensor([-0.2630, -0.0143])
# cov: tensor([[ 0.6367, -0.0713],
#         [-0.0713,  1.1154]])
# mu: tensor([-0.2522, -0.0905])
# cov: tensor([[ 0.6303, -0.0519],
#         [-0.0519,  1.1598]])
# mu: tensor([-0.1817, -0.1223])
# cov: tensor([[ 0.6026, -0.0550],
#         [-0.0550,  1.1707]])
# mu: tensor([-0.3046,  0.3592])
# cov: tensor([[ 0.6727, -0.2995],
#         [-0.2995,  2.0007]])
# mu: tensor([-0.3897,  0.4689])
# cov: tensor([[ 0.7323, -0.4053],
#         [-0.4053,  2.1509]])
# mu: tensor([-0.4438,  0.1656])
# cov: tensor([[ 0.7718, -0.3060],
#         [-0.3060,  1.9320]])
# mu: tensor([-0.4533,  0.1361])
# cov: tensor([[ 0.7738, -0.2999],
#         [-0.2999,  1.9508]])
# mu: tensor([-0.4829,  0.2204])
# cov: tensor([[ 0.7866, -0.3319],
#         [-0.3319,  2.0279]])
# mu: tensor([-0.4777,  0.2845])
# cov: tensor([[ 0.7869, -0.3402],
#         [-0.3402,  1.8001]])
# mu: tensor([-0.4310,  0.2575])
# cov: tensor([[ 0.7731, -0.3380],
#         [-0.3380,  1.8034]])
# mu: tensor([-0.4453,  0.2182])
# cov: tensor([[ 0.7817, -0.3218],
#         [-0.3218,  1.8227]])
# mu: tensor([-0.3452, -0.2518])
# cov: tensor([[ 0.6862, -0.0072],
#         [-0.0072,  1.0063]])
# mu: tensor([-0.3387, -0.3513])
# cov: tensor([[ 6.8420e-01, -9.6995e-04],
#         [-9.7089e-04,  1.0826e+00]])
# mu: tensor([-0.4870, -0.3744])
# cov: tensor([[ 0.7811, -0.0038],
#         [-0.0038,  1.0723]])
# mu: tensor([-0.4910, -0.3638])
# cov: tensor([[ 0.7820, -0.0058],
#         [-0.0058,  1.0767]])
# mu: tensor([-0.5158, -0.3097])
# cov: tensor([[ 0.7884, -0.0171],
#         [-0.0171,  1.0956]])
# mu: tensor([-0.4926, -0.2324])
# cov: tensor([[ 0.7822, -0.0327],
#         [-0.0327,  1.0690]])
# mu: tensor([-0.5858, -0.3676])
# cov: tensor([[0.8286, 0.0140],
#         [0.0140, 1.0143]])
# mu: tensor([-0.5488, -0.3850])
# cov: tensor([[0.8108, 0.0113],
#         [0.0112, 1.0251]])
# mu: tensor([-0.4490, -0.2529])
# cov: tensor([[ 0.7712, -0.0232],
#         [-0.0232,  1.0234]])
# mu: tensor([-0.4247, -0.3577])
# cov: tensor([[ 0.7594, -0.0044],
#         [-0.0044,  1.0488]])
# mu: tensor([-0.4503, -0.4291])
# cov: tensor([[ 7.6407e-01, -9.8803e-04],
#         [-9.8902e-04,  9.9513e-01]])
# mu: tensor([-0.5502, -0.3507])
# cov: tensor([[ 0.8205, -0.0012],
#         [-0.0012,  0.9476]])
# mu: tensor([-0.4907, -0.2825])
# cov: tensor([[ 0.7994, -0.0227],
#         [-0.0227,  0.9267]])
# Iteration 1 | Log Likelihood: 0.062
# mu: tensor([-1.1218, -0.0696])
# cov: tensor([[ 0.7994, -0.0444],
#         [-0.0444,  2.0421]])
# mu: tensor([-1.1807, -1.1148])
# cov: tensor([[0.7865, 0.3929],
#         [0.3929, 1.7419]])
# mu: tensor([-0.9359, -0.9621])
# cov: tensor([[0.6869, 0.2975],
#         [0.2975, 1.7050]])
# mu: tensor([-0.5970, -0.3567])
# cov: tensor([[0.5534, 0.1483],
#         [0.1483, 2.6100]])
# mu: tensor([-0.6858, -1.0117])
# cov: tensor([[0.5703, 0.2543],
#         [0.2543, 3.2077]])
# mu: tensor([-0.6420, -0.5609])
# cov: tensor([[0.5627, 0.1922],
#         [0.1922, 2.9285]])
# mu: tensor([-1.0711,  3.8490])
# cov: tensor([[ 0.6818, -1.0026],
#         [-1.0026,  9.6288]])
# mu: tensor([-0.8007, -0.2573])
# cov: tensor([[0.6244, 0.0554],
#         [0.0554, 0.3836]])
# mu: tensor([-0.9347, -0.3080])
# cov: tensor([[0.6601, 0.0748],
#         [0.0748, 0.3916]])
# mu: tensor([-0.9277, -0.3040])
# cov: tensor([[0.6575, 0.0735],
#         [0.0735, 0.3913]])
# mu: tensor([-1.2272, -0.3679])
# cov: tensor([[0.7991, 0.1015],
#         [0.1015, 0.3964]])
# mu: tensor([-1.0283, -0.4317])
# cov: tensor([[0.7234, 0.0960],
#         [0.0960, 0.4278]])
# mu: tensor([-1.0372, -0.3157])
# cov: tensor([[0.7345, 0.0639],
#         [0.0639, 0.4352]])
# mu: tensor([-1.1650, -0.3035])
# cov: tensor([[0.7762, 0.0649],
#         [0.0649, 0.4334]])
# mu: tensor([-1.0236, -0.4418])
# cov: tensor([[0.7247, 0.0756],
#         [0.0756, 0.4844]])
# mu: tensor([-0.8992, -0.2458])
# cov: tensor([[0.6944, 0.0408],
#         [0.0408, 0.4845]])
# mu: tensor([-0.8686, -0.1760])
# cov: tensor([[0.6863, 0.0289],
#         [0.0289, 0.5297]])
# mu: tensor([-0.8270, -0.2169])
# cov: tensor([[0.6697, 0.0390],
#         [0.0390, 0.5288]])
# mu: tensor([-0.8016, -0.1974])
# cov: tensor([[0.6676, 0.0415],
#         [0.0415, 0.5362]])
# mu: tensor([-1.1467,  0.1783])
# cov: tensor([[ 0.8729, -0.1311],
#         [-0.1311,  0.5863]])
# mu: tensor([-1.0695,  0.1341])
# cov: tensor([[ 0.8640, -0.1502],
#         [-0.1502,  0.6348]])
# mu: tensor([-0.9417,  0.0591])
# cov: tensor([[ 0.7995, -0.0995],
#         [-0.0995,  0.6114]])
# mu: tensor([-0.7200, -0.0512])
# cov: tensor([[ 0.6892, -0.0883],
#         [-0.0883,  0.6779]])
# mu: tensor([-0.7475,  0.0179])
# cov: tensor([[ 0.7002, -0.1066],
#         [-0.1066,  0.6953]])
# mu: tensor([-0.6553,  0.1240])
# cov: tensor([[ 0.6715, -0.1199],
#         [-0.1199,  0.7218]])
# mu: tensor([-0.7166,  0.0029])
# cov: tensor([[ 0.7011, -0.0791],
#         [-0.0791,  0.7248]])
# mu: tensor([-1.1337,  0.5035])
# cov: tensor([[ 0.9120, -0.3040],
#         [-0.3040,  0.9415]])
# mu: tensor([-1.3889,  0.8599])
# cov: tensor([[ 0.9850, -0.3921],
#         [-0.3921,  1.0390]])
# mu: tensor([-1.2047,  0.7195])
# cov: tensor([[ 0.9382, -0.4107],
#         [-0.4107,  1.2196]])
# mu: tensor([-0.9040,  0.0221])
# cov: tensor([[ 0.8866, -0.3916],
#         [-0.3916,  1.4993]])
# mu: tensor([-0.6285, -0.3273])
# cov: tensor([[ 0.7169, -0.1578],
#         [-0.1578,  1.1829]])
# mu: tensor([-0.7611,  0.1593])
# cov: tensor([[ 0.7987, -0.3050],
#         [-0.3050,  1.1592]])
# mu: tensor([-1.2029,  1.1246])
# cov: tensor([[ 1.0183, -0.7099],
#         [-0.7099,  1.7493]])
# mu: tensor([-1.0083,  0.7623])
# cov: tensor([[ 0.9218, -0.5310],
#         [-0.5310,  1.4175]])
# mu: tensor([-0.7397,  0.2279])
# cov: tensor([[ 0.7637, -0.2501],
#         [-0.2501,  0.9992]])
# mu: tensor([-0.8645,  0.6698])
# cov: tensor([[ 0.8208, -0.4151],
#         [-0.4151,  1.2239]])
# mu: tensor([-0.7783,  0.4268])
# cov: tensor([[ 0.7895, -0.3662],
#         [-0.3662,  1.4100]])
# mu: tensor([-0.8860,  0.4429])
# cov: tensor([[ 0.8008, -0.3120],
#         [-0.3120,  1.3195]])
# mu: tensor([-0.8491,  0.6623])
# cov: tensor([[ 0.7884, -0.3488],
#         [-0.3488,  1.3239]])
# mu: tensor([-0.8393,  0.3083])
# cov: tensor([[ 0.7895, -0.2556],
#         [-0.2556,  1.3610]])
# mu: tensor([-0.7244,  0.3337])
# cov: tensor([[ 0.7474, -0.2425],
#         [-0.2425,  1.3859]])
# mu: tensor([-0.7058,  0.4613])
# cov: tensor([[ 0.7395, -0.2783],
#         [-0.2783,  1.2658]])
# mu: tensor([-0.4772, -0.0548])
# cov: tensor([[ 0.6020, -0.0161],
#         [-0.0161,  0.8798]])
# mu: tensor([-0.4323, -0.0915])
# cov: tensor([[ 0.5966, -0.0415],
#         [-0.0415,  0.9528]])
# mu: tensor([-0.4507, -0.2600])
# cov: tensor([[ 0.6002, -0.0089],
#         [-0.0089,  0.8660]])
# mu: tensor([-0.5366, -0.5663])
# cov: tensor([[0.6268, 0.0873],
#         [0.0873, 1.0246]])
# mu: tensor([-0.5381, -0.3237])
# cov: tensor([[0.6453, 0.0199],
#         [0.0199, 0.8727]])
# mu: tensor([-0.6205, -0.2865])
# cov: tensor([[ 0.6896, -0.0144],
#         [-0.0144,  0.8852]])
# mu: tensor([-1.1295, -0.3023])
# cov: tensor([[0.9693, 0.0420],
#         [0.0420, 0.8578]])
# mu: tensor([-0.7570,  0.0217])
# cov: tensor([[ 0.7957, -0.0807],
#         [-0.0807,  0.7990]])
# mu: tensor([-0.9698,  0.6434])
# cov: tensor([[ 0.8671, -0.2559],
#         [-0.2559,  1.1651]])
# mu: tensor([-0.8636,  0.1842])
# cov: tensor([[ 0.8409, -0.1589],
#         [-0.1589,  0.8430]])
# mu: tensor([-0.9249,  0.3463])
# cov: tensor([[ 0.8755, -0.2361],
#         [-0.2361,  0.9345]])
# mu: tensor([-1.4550,  0.6016])
# cov: tensor([[ 1.1638, -0.3611],
#         [-0.3611,  0.9833]])
# mu: tensor([-1.4283,  0.1621])
# cov: tensor([[ 1.1568, -0.1529],
#         [-0.1529,  0.5997]])
# mu: tensor([-0.8412, -0.1872])
# cov: tensor([[0.8092, 0.0093],
#         [0.0093, 0.5600]])
# mu: tensor([-0.9364, -0.3319])
# cov: tensor([[0.8357, 0.0387],
#         [0.0387, 0.5731]])
# mu: tensor([-0.8299, -0.2567])
# cov: tensor([[0.8017, 0.0109],
#         [0.0109, 0.5517]])
# mu: tensor([-1.3196, -0.0758])
# cov: tensor([[ 1.0736, -0.0506],
#         [-0.0506,  0.5400]])
# mu: tensor([-0.6444, -0.1956])
# cov: tensor([[ 0.6967, -0.0016],
#         [-0.0016,  0.5383]])
# mu: tensor([-0.6615, -0.1352])
# cov: tensor([[ 0.7011, -0.0097],
#         [-0.0097,  0.5420]])
# mu: tensor([-0.9922, -0.0673])
# cov: tensor([[ 0.8797, -0.0763],
#         [-0.0763,  0.5393]])
# mu: tensor([-1.0229,  0.0971])
# cov: tensor([[ 0.8858, -0.0905],
#         [-0.0905,  0.5081]])
# mu: tensor([-0.9913,  0.0552])
# cov: tensor([[ 0.8724, -0.0805],
#         [-0.0805,  0.5160]])
# mu: tensor([-0.9656, -0.0921])
# cov: tensor([[ 0.8533, -0.0209],
#         [-0.0209,  0.5143]])
# mu: tensor([-0.9562, -0.0544])
# cov: tensor([[ 0.8500, -0.0328],
#         [-0.0328,  0.5092]])
# mu: tensor([-1.1562, -0.0982])
# cov: tensor([[ 0.9320, -0.0134],
#         [-0.0134,  0.5137]])
# mu: tensor([-1.5317, -0.2569])
# cov: tensor([[1.0764, 0.0461],
#         [0.0461, 0.5381]])
# mu: tensor([-1.2624, -0.1982])
# cov: tensor([[0.9566, 0.0399],
#         [0.0399, 0.5707]])
# mu: tensor([-1.4244, -0.2519])
# cov: tensor([[1.0214, 0.0499],
#         [0.0499, 0.5589]])
# mu: tensor([-0.9188, -0.1077])
# cov: tensor([[ 0.7854, -0.0441],
#         [-0.0441,  0.5420]])
# mu: tensor([-1.3040, -0.0531])
# cov: tensor([[ 0.9758, -0.0728],
#         [-0.0728,  0.5462]])
# mu: tensor([-0.9498, -0.0744])
# cov: tensor([[ 0.8250, -0.0582],
#         [-0.0582,  0.5458]])
# mu: tensor([-0.9973, -0.1137])
# cov: tensor([[ 0.8382, -0.0464],
#         [-0.0464,  0.5562]])
# mu: tensor([-1.4622, -0.3284])
# cov: tensor([[1.0516, 0.0456],
#         [0.0456, 0.5936]])
# mu: tensor([-0.8961, -0.2413])
# cov: tensor([[0.7838, 0.0117],
#         [0.0117, 0.5909]])
# mu: tensor([-0.9072, -0.4153])
# cov: tensor([[0.7749, 0.0725],
#         [0.0725, 0.5882]])
# mu: tensor([-1.2765, -0.1747])
# cov: tensor([[ 1.0043, -0.0551],
#         [-0.0551,  0.6495]])
# mu: tensor([-1.0828, -0.1591])
# cov: tensor([[ 0.9081, -0.0568],
#         [-0.0568,  0.6527]])
# mu: tensor([-1.1620, -0.7965])
# cov: tensor([[0.8929, 0.1375],
#         [0.1375, 0.8440]])
# mu: tensor([-1.1740, -0.7853])
# cov: tensor([[0.8983, 0.1383],
#         [0.1383, 0.8353]])
# mu: tensor([-1.7156, -1.3536])
# cov: tensor([[1.0785, 0.3145],
#         [0.3145, 0.9852]])
# mu: tensor([-1.4472, -0.9948])
# cov: tensor([[1.0137, 0.2422],
#         [0.2422, 0.9352]])
# mu: tensor([-1.1172, -0.6340])
# cov: tensor([[0.8769, 0.0965],
#         [0.0965, 0.7972]])
# mu: tensor([-0.9102, -0.4850])
# cov: tensor([[0.8151, 0.0380],
#         [0.0380, 0.7521]])
# mu: tensor([-0.8298, -0.4454])
# cov: tensor([[0.7857, 0.0201],
#         [0.0201, 0.7426]])
# mu: tensor([-0.6931, -0.3456])
# cov: tensor([[ 0.7256, -0.0176],
#         [-0.0176,  0.7247]])
# mu: tensor([-0.8354, -0.3935])
# cov: tensor([[0.7858, 0.0137],
#         [0.0137, 0.7339]])
# mu: tensor([-0.7866, -0.0503])
# cov: tensor([[ 0.7828, -0.1065],
#         [-0.1065,  0.8071]])
# mu: tensor([-0.7635, -0.6290])
# cov: tensor([[ 0.7837, -0.1328],
#         [-0.1328,  1.5698]])
# mu: tensor([-0.6181, -0.5035])
# cov: tensor([[ 0.7447, -0.1791],
#         [-0.1791,  1.5246]])
# mu: tensor([-0.8681, -0.8592])
# cov: tensor([[ 0.8137, -0.0480],
#         [-0.0480,  1.7262]])
# mu: tensor([-0.8109, -0.1985])
# cov: tensor([[ 0.9288, -1.1786],
#         [ 1.1786, -8.1460]])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-e96f6f02e22b> in <module>
#      33                               num_samples=100,
#      34                               lr=1e-1)
# ---> 35         censored_multi.fit(S)
#      36
#      37         loc_ = censored_multi.loc@censored_multi.covariance_matrix.inverse()
#
# ~/Desktop/delphi_/delphi/distributions/multivariate_normal.py in fit(self, S)
#      54
#      55         # run PGD for parameter estimation
# ---> 56         self.trainer.train_model()
#      57
#      58         with ch.no_grad():
#
# ~/Desktop/delphi_/delphi/trainer.py in train_model(self)
#     172             # raise error
#     173             except Exception as e:
# --> 174                 raise e
#     175             # evaluate model on validation set, if there is one
#     176             if self.model.val_loader is not None:
#
# ~/Desktop/delphi_/delphi/trainer.py in train_model(self)
#     166         for epoch in range(1, self.epochs + 1):
#     167             try:
# --> 168                 self.model_loop(TRAIN, self.model.train_loader, epoch)
#     169             # if raising ProcedureComplete, then terminate
#     170             except ProcedureComplete:
#
# ~/Desktop/delphi_/delphi/trainer.py in model_loop(self, loop_type, loader, epoch)
#     213             if is_train:
#     214                 self.model.optimizer.zero_grad()
# --> 215                 loss, prec1, prec5 = self.model.train_step(i, batch)
#     216                 loss.backward()
#     217                  # ch.nn.utils.clip_grad_norm_(self.model.model.parameters(), 3.0)
#
# ~/Desktop/delphi_/delphi/distributions/normal.py in train_step(self, i, batch)
#     159             batch (Iterable) : iterable of inputs that
#     160         '''
# --> 161         loss = CensoredMultivariateNormalNLL.apply(self.model.loc, self.model.covariance_matrix, *batch, self.phi)
#     162         return loss, None, None
#     163
#
# ~/Desktop/delphi_/delphi/grad.py in forward(ctx, v, T, S, S_grad, phi)
#      31         # reparameterize distribution
#      32         z = Tensor([])
# ---> 33         M = MultivariateNormal(mu, sigma)
#      34         # import pdb; pdb.set_trace()
#      35         while z.size(0) < S.size(0):
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/distributions/multivariate_normal.py in __init__(self, loc, covariance_matrix, precision_matrix, scale_tril, validate_args)
#     144
#     145         event_shape = self.loc.shape[-1:]
# --> 146         super(MultivariateNormal, self).__init__(batch_shape, event_shape, validate_args=validate_args)
#     147
#     148         if scale_tril is not None:
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/distributions/distribution.py in __init__(self, batch_shape, event_shape, validate_args)
#      54                 if not valid.all():
#      55                     raise ValueError(
# ---> 56                         f"Expected parameter {param} "
#      57                         f"({type(value).__name__} of shape {tuple(value.shape)}) "
#      58                         f"of distribution {repr(self)} "
#
# ValueError: Expected parameter covariance_matrix (Tensor of shape (2, 2)) of distribution MultivariateNormal(loc: torch.Size([2]), covariance_matrix: torch.Size([2, 2])) to satisfy the constraint PositiveDefinite(), but found invalid values:
# tensor([[ 0.9288, -1.1786],
#         [ 1.1786, -8.1460]])

# %%
kl_divergence(gt_dist, censor_dist)
# Out:
# tensor([0.4818, 0.3010])

# %%
gt_dist, censor_dist
# Out:
# (MultivariateNormal(loc: torch.Size([2]), covariance_matrix: torch.Size([2, 2])),
#  MultivariateNormal(loc: torch.Size([2, 2]), covariance_matrix: torch.Size([2, 2, 2])))

# %%
censor_dist.covariance_matrix
# Out:
# tensor([[[0.4665, 0.0800],
#          [0.0800, 0.7655]],
#
#         [[0.4665, 0.0800],
#          [0.0800, 0.7655]]])
